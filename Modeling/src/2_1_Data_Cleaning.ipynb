# %% [markdown]
# # Task 2.2.1: Data Cleaning for Reference Matching
#
# ## Problem: Match BibTeX Entries to References.json
# Identify which extracted BibTeX entry corresponds to which arXiv ID in references.json.
#
# **Data Cleaning Strategy:**
# - Create hierarchical text versions: original → cleaned → no_stopwords
# - Normalize authors: Parse names, extract last names, create searchable strings
# - Extract temporal data: Year from BibTeX and references
# - Structure metadata: ArXiv IDs, entry types, cleaned title variants
#
# **Output:** cleaned_data.json for each paper with all hierarchy levels

# %% [markdown]
# ### Import Libraries and Setup

# %%
import os
import re
import json
from pathlib import Path
from typing import Dict, List, Any, Set, Tuple, Optional
from collections import defaultdict
import logging
import unicodedata

# For text processing
import string
from difflib import SequenceMatcher

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Configure Paths

# %%
# Project paths
import os
current_dir = Path(os.getcwd())

# If running from src/ directory, go up one level
if current_dir.name == 'src':
    BASE_DIR = current_dir.parent
else:
    # Otherwise assume we're already in the project root
    BASE_DIR = current_dir
PAPERS_DIR = BASE_DIR / "papers"
OUTPUT_DIR = BASE_DIR / "bibtex"
STUDENT_ID = "23127088"
PROCESSED_DIR = OUTPUT_DIR / STUDENT_ID

# %% [markdown]
# ### Define DataLoader Class

# %%
class DataLoader:
    """Loads BibTeX entries and references.json data"""
    
    def __init__(self, papers_dir: Path, processed_dir: Path):
        self.papers_dir = papers_dir
        self.processed_dir = processed_dir
    
    def load_bibtex_from_file(self, bib_file: Path) -> Dict[str, Dict[str, str]]:
        """Parse a .bib file and extract entries"""
        entries = {}
        
        try:
            content = bib_file.read_text(encoding='utf-8', errors='ignore')
            
            # Pattern to match BibTeX entries
            entry_pattern = re.compile(
                r'@(\w+)\{([^,]+),([^@]+)\}',
                re.DOTALL
            )
            
            for match in entry_pattern.finditer(content):
                entry_type = match.group(1)
                entry_key = match.group(2).strip()
                entry_fields = match.group(3)
                
                # Parse fields
                fields = {'entry_type': entry_type}
                field_pattern = re.compile(r'(\w+)\s*=\s*\{([^}]+)\}')
                
                for field_match in field_pattern.finditer(entry_fields):
                    field_name = field_match.group(1)
                    field_value = field_match.group(2).strip()
                    fields[field_name] = field_value
                
                entries[entry_key] = fields
        
        except Exception as e:
            logger.error(f"Error loading BibTeX file {bib_file}: {e}")
        
        return entries
    
    def load_references_json(self, json_file: Path) -> List[Dict[str, Any]]:
        """Load references.json file"""
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
                # references.json is a dict with arxiv_id as keys
                # Convert to list and add arxiv_id to each entry
                references = []
                for arxiv_id, ref_data in data.items():
                    ref_entry = ref_data.copy()
                    ref_entry['arxiv_id'] = arxiv_id
                    references.append(ref_entry)
                return references
        except Exception as e:
            logger.error(f"Error loading references JSON {json_file}: {e}")
            return []
    
    def load_paper_data(self, paper_id: str) -> Tuple[Dict, List]:
        """Load both BibTeX and references.json for a paper"""
        # Load processed BibTeX
        bib_file = self.processed_dir / paper_id / 'refs.bib'
        bibtex_entries = {}
        if bib_file.exists():
            bibtex_entries = self.load_bibtex_from_file(bib_file)
        
        # Load references.json
        ref_file = self.papers_dir / paper_id / 'references.json'
        references = []
        if ref_file.exists():
            references = self.load_references_json(ref_file)
        
        return bibtex_entries, references
    
    def get_all_papers(self) -> List[str]:
        """Get list of all processed papers"""
        papers = []
        if self.processed_dir.exists():
            papers = [d.name for d in self.processed_dir.iterdir() if d.is_dir()]
        return sorted(papers)

# %%
# Common English stop words (subset - focusing on words that don't help matching)
STOP_WORDS = set([
    'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from', 'has', 'he',
    'in', 'is', 'it', 'its', 'of', 'on', 'that', 'the', 'to', 'was', 'will', 'with'
])

class TextCleaner:
    """Cleans and normalizes text for matching"""
    
    @staticmethod
    def normalize_unicode(text: str) -> str:
        """Convert Unicode to ASCII (handle accented characters)"""
        # Normalize to NFKD form and encode to ASCII
        normalized = unicodedata.normalize('NFKD', text)
        ascii_text = normalized.encode('ascii', 'ignore').decode('ascii')
        return ascii_text
    
    @staticmethod
    def remove_latex_commands(text: str) -> str:
        """Remove remaining LaTeX commands from text"""
        # Remove \command{content} but keep content
        text = re.sub(r'\\\w+\{([^}]*)\}', r'\1', text)
        # Remove standalone commands
        text = re.sub(r'\\\w+', '', text)
        # Remove curly braces
        text = re.sub(r'[{}]', '', text)
        return text
    
    @staticmethod
    def clean_title(title: str, remove_stopwords: bool = True) -> str:
        """Clean and normalize title text"""
        if not title:
            return ""
        
        # Remove LaTeX commands
        title = TextCleaner.remove_latex_commands(title)
        
        # Normalize Unicode
        title = TextCleaner.normalize_unicode(title)
        
        # Lowercase
        title = title.lower()
        
        # Remove punctuation except hyphens (important for compound words)
        title = re.sub(r'[^\w\s-]', ' ', title)
        
        # Normalize whitespace
        title = re.sub(r'\s+', ' ', title).strip()
        
        # Remove stop words if requested
        if remove_stopwords:
            words = title.split()
            words = [w for w in words if w not in STOP_WORDS]
            title = ' '.join(words)
        
        return title
    
    @staticmethod
    def normalize_author_name(author: str) -> str:
        """Normalize author name to standard format"""
        if not author:
            return ""
        
        # Normalize Unicode
        author = TextCleaner.normalize_unicode(author)
        
        # Lowercase
        author = author.lower()

        # Remove all the word "and"
        author = re.sub(r'\band\b', ' ', author)
        
        # Remove periods and commas
        author = re.sub(r'[.,]', ' ', author)
        
        # Normalize whitespace
        author = re.sub(r'\s+', ' ', author).strip()
        
        return author
    
    @staticmethod
    def extract_author_last_names(author_string: str) -> List[str]:
        """Extract last names from author string"""
        if not author_string:
            return []
        
        # Normalize first
        author_string = TextCleaner.normalize_author_name(author_string)
        
        # Split by 'and' or commas
        authors = re.split(r'\band\b|,', author_string)
        
        last_names = []
        for author in authors:
            author = author.strip()
            if not author:
                continue
            
            # Try to extract last name (usually first word or last word)
            words = author.split()
            if words:
                # If format is "Last, First" or "Last First", take first word
                # If format is "First Last", take last word
                # Heuristic: if first word has multiple chars, it's likely the last name
                if len(words[0]) > 2:
                    last_names.append(words[0])
                elif len(words) > 1:
                    last_names.append(words[-1])
        
        return last_names
    
    @staticmethod
    def extract_year(text: str) -> Optional[int]:
        """Extract year from text"""
        if not text:
            return None
        
        # Look for 4-digit year
        year_match = re.search(r'\b(19|20)\d{2}\b', str(text))
        if year_match:
            return int(year_match.group(0))
        return None
    
    @staticmethod
    def clean_arxiv_id(arxiv_id: str) -> str:
        """Normalize arXiv ID format"""
        if not arxiv_id:
            return ""
        
        # Remove 'arXiv:' prefix if present
        arxiv_id = re.sub(r'^arxiv:\s*', '', arxiv_id, flags=re.IGNORECASE)
        
        # Normalize whitespace
        arxiv_id = arxiv_id.strip()
        
        return arxiv_id

# %% [markdown]
# ### Define ReferenceDataCleaner Class
#
# Hierarchical text cleaning pipeline:
# 1. **Original**: Raw text as-is
# 2. **Cleaned**: Lowercase, remove punctuation, normalize unicode
# 3. **No stopwords**: Remove common words (the, a, an, etc.)
#
# Also handles author normalization and year extraction.

# %%
class ReferenceDataCleaner:
    """Main processor for cleaning reference data"""
    
    def __init__(self):
        self.cleaner = TextCleaner()
    
    def clean_bibtex_entry(self, key: str, entry: Dict[str, str]) -> Dict[str, Any]:
        """Clean a single BibTeX entry"""
        cleaned = {
            'original_key': key,
            'entry_type': entry.get('entry_type', 'unknown'),
        }
        
        # Clean title
        if 'title' in entry:
            cleaned['title_original'] = entry['title']
            cleaned['title_cleaned'] = self.cleaner.clean_title(entry['title'], remove_stopwords=False)
            cleaned['title_no_stopwords'] = self.cleaner.clean_title(entry['title'], remove_stopwords=True)
        
        if 'author' in entry:
            cleaned['author_original'] = entry['author'] 
            cleaned['author_normalized'] = self.cleaner.normalize_author_name(entry['author'])
            cleaned['author_last_names'] = self.cleaner.extract_author_last_names(entry['author'])
        
        # Extract year
        year = None
        if 'year' in entry:
            year = self.cleaner.extract_year(entry['year'])
        if not year and 'note' in entry:
            year = self.cleaner.extract_year(entry['note'])
        cleaned['year'] = year
        
        # Keep other useful fields for matching
        for field in ['journal', 'booktitle', 'volume', 'pages']:
            if field in entry:
                cleaned[field] = entry[field]
        
        return cleaned
    
    def clean_reference_entry(self, ref: Dict[str, Any]) -> Dict[str, Any]:
        """Clean a reference from references.json"""
        cleaned = {}
        
        # ArXiv ID (primary key)
        if 'arxiv_id' in ref:
            cleaned['arxiv_id'] = ref['arxiv_id']  # Already extracted from dict key
        
        # Clean title (field is 'paper_title' in references.json)
        if 'paper_title' in ref:
            cleaned['title_original'] = ref['paper_title']
            cleaned['title_cleaned'] = self.cleaner.clean_title(ref['paper_title'], remove_stopwords=False)
            cleaned['title_no_stopwords'] = self.cleaner.clean_title(ref['paper_title'], remove_stopwords=True)
        
        # Clean authors
        if 'authors' in ref and isinstance(ref['authors'], list):
            cleaned['authors_original'] = ref['authors']
            # Create normalized author string with 'and' preserved
            author_string = ' and '.join(ref['authors'])
            cleaned['author_normalized'] = self.cleaner.normalize_author_name(author_string)
            cleaned['author_last_names'] = self.cleaner.extract_author_last_names(author_string)
        
        # Extract year from submission_date
        year = None
        if 'submission_date' in ref:
            year = self.cleaner.extract_year(ref['submission_date'])
        cleaned['year'] = year
        
        # Keep semantic scholar ID if present
        if 'semantic_scholar_id' in ref:
            cleaned['semantic_scholar_id'] = ref['semantic_scholar_id']
        
        return cleaned
    
    def process_paper(self, paper_id: str, bibtex_entries: Dict, references: List) -> Dict:
        """Process all data for a single paper"""
        result = {
            'paper_id': paper_id,
            'bibtex_cleaned': [],
            'references_cleaned': [],
            'statistics': {}
        }
        
        # Clean BibTeX entries
        for key, entry in bibtex_entries.items():
            cleaned = self.clean_bibtex_entry(key, entry)
            result['bibtex_cleaned'].append(cleaned)
        
        # Clean references
        for ref in references:
            cleaned = self.clean_reference_entry(ref)
            result['references_cleaned'].append(cleaned)
        
        # Statistics
        result['statistics'] = {
            'num_bibtex': len(result['bibtex_cleaned']),
            'num_references': len(result['references_cleaned']),
            'bibtex_with_title': sum(1 for b in result['bibtex_cleaned'] if b.get('title_cleaned')),
            'bibtex_with_author': sum(1 for b in result['bibtex_cleaned'] if b.get('author_normalized')),
            'references_with_title': sum(1 for r in result['references_cleaned'] if r.get('title_cleaned')),
            'references_with_author': sum(1 for r in result['references_cleaned'] if r.get('author_normalized')),
        }
        
        return result

# %%
# Initialize
loader = DataLoader(PAPERS_DIR, PROCESSED_DIR)
cleaner = ReferenceDataCleaner()

# Get available papers
all_papers = loader.get_all_papers()
print(f"Total papers available: {len(all_papers)}")
print(f"First 10 papers: {all_papers[:10]}")
# Out:
# Total papers available: 3180
# First 10 papers: ['2312-15844', '2312-15845', '2312-15846', '2312-15847', '2312-15848', '2312-15851', '2312-15853', '2312-15855', '2312-15856', '2312-15857']

# %% [markdown]
# ### Test Processing on Sample Paper

# %%
# Process first paper as example
if all_papers:
    test_paper_id = all_papers[0]
    print(f"\nProcessing test paper: {test_paper_id}")
    
    # Load data
    bibtex_entries, references = loader.load_paper_data(test_paper_id)
    
    print(f"\nLoaded:")
    print(f"  - BibTeX entries: {len(bibtex_entries)}")
    print(f"  - References: {len(references)}")
    
    # Clean data
    cleaned_data = cleaner.process_paper(test_paper_id, bibtex_entries, references)
    
    print(f"\nCleaning Statistics:")
    for key, value in cleaned_data['statistics'].items():
        print(f"  - {key}: {value}")
# Out:
# Processing test paper: 2312-15844
#
# Loaded:
#   - BibTeX entries: 49
#   - References: 32
#
# Cleaning Statistics:
#   - num_bibtex: 49
#   - num_references: 32
#   - bibtex_with_title: 49
#   - bibtex_with_author: 48
#   - references_with_title: 32
#   - references_with_author: 32

# %% [markdown]
# ### Examine Sample BibTeX Entry Hierarchy

# %%
# Show example BibTeX cleaning
if cleaned_data['bibtex_cleaned']:
    print("=" * 80)
    print("EXAMPLE: BibTeX Entry Cleaning")
    print("=" * 80)
    
    example = cleaned_data['bibtex_cleaned'][0]
    
    print(f"\nOriginal Key: {example.get('original_key')}")
    print(f"Entry Type: {example.get('entry_type')}")
    
    if 'title_original' in example:
        print(f"\nTitle (Original):")
        print(f"  {example['title_original']}")
        print(f"\nTitle (Cleaned):")
        print(f"  {example['title_cleaned']}")
        print(f"\nTitle (No Stopwords):")
        print(f"  {example['title_no_stopwords']}")
    
    if 'author_original' in example:
        print(f"\nAuthor (Original):")
        print(f"  {example['author_original']}")
        print(f"\nAuthor (Normalized):")
        print(f"  {example['author_normalized']}")
        print(f"\nAuthor Last Names:")
        print(f"  {example['author_last_names']}")
    
    if example.get('year'):
        print(f"\nYear Extracted: {example['year']}")
    
    if example.get('arxiv_id'):
        print(f"ArXiv ID Found: {example['arxiv_id']}")
# Out:
# ================================================================================
# EXAMPLE: BibTeX Entry Cleaning
# ================================================================================
#
# Original Key: ishiguro2021realisation
# Entry Type: article
#
# Title (Original):
#   {The Realisation of an Avatar-Symbiotic Society where Everyone can Perform Active Roles without Constraint
#
# Title (Cleaned):
#   the realisation of an avatar-symbiotic society where everyone can perform active roles without constraint
#
# Title (No Stopwords):
#   realisation avatar-symbiotic society where everyone can perform active roles without constraint
#
# Author (Original):
#   Ishiguro, Hiroshi
#
# Author (Normalized):
#   ishiguro hiroshi
#
# Author Last Names:
#   ['ishiguro']
#
# Year Extracted: 2021

# %% [markdown]
# ### Examine Sample Reference Hierarchy

# %%
# Show example reference cleaning
if cleaned_data['references_cleaned']:
    print("\n" + "=" * 80)
    print("EXAMPLE: Reference Entry Cleaning")
    print("=" * 80)
    
    example = cleaned_data['references_cleaned'][0]
    
    print(f"\nArXiv ID: {example.get('arxiv_id')}")
    
    if 'title_original' in example:
        print(f"\nTitle (Original):")
        print(f"  {example['title_original']}")
        print(f"\nTitle (Cleaned):")
        print(f"  {example['title_cleaned']}")
        print(f"\nTitle (No Stopwords):")
        print(f"  {example['title_no_stopwords']}")
    
    if 'authors_original' in example:
        print(f"\nAuthors (Original):")
        print(f"  {example['authors_original']}")
        print(f"\nAuthor (Normalized):")
        print(f"  {example['author_normalized']}")
        print(f"\nAuthor Last Names:")
        print(f"  {example['author_last_names']}")
    
    if example.get('year'):
        print(f"\nYear Extracted: {example['year']}")
# Out:
# ================================================================================
# EXAMPLE: Reference Entry Cleaning
# ================================================================================
#
# ArXiv ID: 2309-05551
#
# Title (Original):
#   OpenFashionCLIP: Vision-and-Language Contrastive Learning with Open-Source Fashion Data
#
# Title (Cleaned):
#   openfashionclip vision-and-language contrastive learning with open-source fashion data
#
# Title (No Stopwords):
#   openfashionclip vision-and-language contrastive learning open-source fashion data
#
# Authors (Original):
#   ['Giuseppe Cartella', 'Alberto Baldrati', 'Davide Morelli', 'Marcella Cornia', 'Marco Bertini', 'R. Cucchiara']
#
# Author (Normalized):
#   giuseppe cartella alberto baldrati davide morelli marcella cornia marco bertini r cucchiara
#
# Author Last Names:
#   ['giuseppe']
#
# Year Extracted: 2023

# %%
def process_paper(paper_id: str):
    """Process a single paper and return cleaned data"""
    try:
        # Load data
        bibtex_entries, references = loader.load_paper_data(paper_id)
        
        # Clean data
        cleaned_data = cleaner.process_paper(paper_id, bibtex_entries, references)
        
        # Save individual paper data in bibtex/{paperid}/ folder
        output_folder = PROCESSED_DIR / paper_id
        output_folder.mkdir(parents=True, exist_ok=True)
        output_file = output_folder / "cleaned_data.json"
        
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(cleaned_data, f, indent=2, ensure_ascii=False)
        
        print(f"✓ ({cleaned_data['statistics']['num_bibtex']} BibTeX, {cleaned_data['statistics']['num_references']} refs)")
    
    except Exception as e:
        print(f"✗ Error: {e}")
        logger.error(f"Error processing {paper_id}: {e}")
    

def process_all_papers(limit: Optional[int] = None):
    """Process all papers and save cleaned data"""
    papers_to_process = all_papers[:limit] if limit else all_papers
    
    results = []
    total = len(papers_to_process)
    
    print(f"Processing {total} papers...\n")
    
    for i, paper_id in enumerate(papers_to_process, 1):
        print(f"[{i}/{total}] Processing {paper_id}...", end=" ")
        
        try:
            # Load data
            bibtex_entries, references = loader.load_paper_data(paper_id)
            
            # Clean data
            cleaned_data = cleaner.process_paper(paper_id, bibtex_entries, references)
            results.append(cleaned_data)
            
            # Save individual paper data in bibtex/{paperid}/ folder
            output_folder = PROCESSED_DIR / paper_id
            output_folder.mkdir(parents=True, exist_ok=True)
            output_file = output_folder / "cleaned_data.json"
            
            with open(output_file, 'w', encoding='utf-8') as f:
                json.dump(cleaned_data, f, indent=2, ensure_ascii=False)
            
            print(f"✓ ({cleaned_data['statistics']['num_bibtex']} BibTeX, {cleaned_data['statistics']['num_references']} refs)")
        
        except Exception as e:
            print(f"✗ Error: {e}")
            logger.error(f"Error processing {paper_id}: {e}")
    
    summary = {
        'total_papers': len(results),
        'total_bibtex': sum(r['statistics']['num_bibtex'] for r in results),
        'total_references': sum(r['statistics']['num_references'] for r in results),
        'papers': [r['paper_id'] for r in results]
    }
    
    print(f"\n{'='*80}")
    print(f"Processing Complete!")
    print(f"  - Papers processed: {summary['total_papers']}")
    print(f"  - Total BibTeX entries: {summary['total_bibtex']}")
    print(f"  - Total references: {summary['total_references']}")
    print(f"  - Output directory: {PROCESSED_DIR}")
    
    return results

# %%
# Process individual paper
# results = process_paper('2312-15844')

# %% [markdown]
# ### Process All Papers

# %%
# Re-process all papers with fixed cleaning
all_results = process_all_papers(limit=500)
# Out:
# Processing 500 papers...
#
# [1/500] Processing 2312-15844... ✓ (49 BibTeX, 32 refs)
# [2/500] Processing 2312-15845... ✓ (29 BibTeX, 18 refs)
# [3/500] Processing 2312-15846... ✓ (72 BibTeX, 59 refs)
# [4/500] Processing 2312-15847... ✓ (303 BibTeX, 25 refs)
# [5/500] Processing 2312-15848... ✓ (190 BibTeX, 47 refs)
# [6/500] Processing 2312-15851... ✓ (154 BibTeX, 29 refs)
# [7/500] Processing 2312-15853... ✓ (228 BibTeX, 20 refs)
# [8/500] Processing 2312-15855... ✓ (298 BibTeX, 34 refs)
# [9/500] Processing 2312-15856... ✓ (192 BibTeX, 68 refs)
# [10/500] Processing 2312-15857... ✓ (23 BibTeX, 6 refs)
# [11/500] Processing 2312-15858... ✓ (234 BibTeX, 22 refs)
# [12/500] Processing 2312-15861... ✓ (17 BibTeX, 10 refs)
# [13/500] Processing 2312-15863... ✓ (109 BibTeX, 30 refs)
# [14/500] Processing 2312-15864... ✓ (73 BibTeX, 4 refs)
# [15/500] Processing 2312-15867... ✓ (31 BibTeX, 20 refs)
# [16/500] Processing 2312-15868... ✓ (60 BibTeX, 0 refs)
# [17/500] Processing 2312-15869... ✓ (34 BibTeX, 19 refs)
# [18/500] Processing 2312-15870... ✓ (40 BibTeX, 16 refs)
# [19/500] Processing 2312-15871... ✓ (75 BibTeX, 50 refs)
# [20/500] Processing 2312-15872... ✓ (155 BibTeX, 33 refs)
# [21/500] Processing 2312-15873... ✓ (28 BibTeX, 3 refs)
# [22/500] Processing 2312-15874... ✓ (64 BibTeX, 11 refs)
# [23/500] Processing 2312-15875... ✓ (31 BibTeX, 7 refs)
# [24/500] Processing 2312-15877... ✓ (136 BibTeX, 6 refs)
# [25/500] Processing 2312-15878... ✓ (54 BibTeX, 41 refs)
# [26/500] Processing 2312-15879... ✓ (8 BibTeX, 1 refs)
# [27/500] Processing 2312-15880... ✓ (41 BibTeX, 29 refs)
# [28/500] Processing 2312-15881... ✓ (61 BibTeX, 30 refs)
# [29/500] Processing 2312-15882... ✓ (34 BibTeX, 4 refs)
# [30/500] Processing 2312-15883... ✓ (632 BibTeX, 51 refs)
# [31/500] Processing 2312-15885... ✓ (27 BibTeX, 0 refs)
# [32/500] Processing 2312-15889... ✓ (74 BibTeX, 10 refs)
# [33/500] Processing 2312-15890... ✓ (22 BibTeX, 14 refs)
# [34/500] Processing 2312-15892... ✓ (19 BibTeX, 10 refs)
# [35/500] Processing 2312-15894... ✓ (39 BibTeX, 15 refs)
# [36/500] Processing 2312-15895... ✓ (158 BibTeX, 39 refs)
# [37/500] Processing 2312-15898... ✓ (94 BibTeX, 75 refs)
# [38/500] Processing 2312-15900... ✓ (188 BibTeX, 22 refs)
# [39/500] Processing 2312-15901...
# ✓ (84442 BibTeX, 27 refs)
# [40/500] Processing 2312-15902... ✓ (119 BibTeX, 28 refs)
# [41/500] Processing 2312-15903... ✓ (34 BibTeX, 20 refs)
# [42/500] Processing 2312-15904... ✓ (1155 BibTeX, 13 refs)
# [43/500] Processing 2312-15906... ✓ (54 BibTeX, 30 refs)
# [44/500] Processing 2312-15907... ✓ (78023 BibTeX, 42 refs)
# [45/500] Processing 2312-15908... ✓ (100 BibTeX, 18 refs)
# [46/500] Processing 2312-15909... ✓ (36 BibTeX, 21 refs)
# [47/500] Processing 2312-15910... ✓ (73 BibTeX, 26 refs)
# [48/500] Processing 2312-15911... ✓ (132 BibTeX, 28 refs)
# [49/500] Processing 2312-15912... ✓ (6 BibTeX, 0 refs)
# [50/500] Processing 2312-15914... ✓ (12 BibTeX, 2 refs)
# [51/500] Processing 2312-15915... ✓ (91 BibTeX, 76 refs)
# [52/500] Processing 2312-15916... ✓ (37 BibTeX, 23 refs)
# [53/500] Processing 2312-15918... ✓ (218 BibTeX, 56 refs)
# [54/500] Processing 2312-15921... ✓ (159 BibTeX, 39 refs)
# [55/500] Processing 2312-15922... ✓ (29 BibTeX, 20 refs)
# [56/500] Processing 2312-15923... ✓ (119 BibTeX, 22 refs)
# [57/500] Processing 2312-15925... ✓ (80 BibTeX, 0 refs)
# [58/500] Processing 2312-15926... ✓ (44 BibTeX, 24 refs)
# [59/500] Processing 2312-15927... ✓ (71 BibTeX, 37 refs)
# [60/500] Processing 2312-15928... ✓ (98 BibTeX, 3 refs)
# [61/500] Processing 2312-15929... ✓ (62 BibTeX, 2 refs)
# [62/500] Processing 2312-15936... ✓ (31 BibTeX, 0 refs)
# [63/500] Processing 2312-15940... ✓ (31 BibTeX, 1 refs)
# [64/500] Processing 2312-15941... ✓ (46 BibTeX, 15 refs)
# [65/500] Processing 2312-15944... ✓ (53 BibTeX, 24 refs)
# [66/500] Processing 2312-15946... ✓ (48 BibTeX, 28 refs)
# [67/500] Processing 2312-15948... ✓ (49 BibTeX, 0 refs)
# [68/500] Processing 2312-15949... ✓ (68 BibTeX, 38 refs)
# [69/500] Processing 2312-15954... ✓ (9 BibTeX, 1 refs)
# [70/500] Processing 2312-15955... ✓ (373 BibTeX, 34 refs)
# [71/500] Processing 2312-15956... ✓ (26 BibTeX, 17 refs)
# [72/500] Processing 2312-15957... ✓ (294 BibTeX, 127 refs)
# [73/500] Processing 2312-15958... ✓ (73 BibTeX, 58 refs)
# [74/500] Processing 2312-15959... ✓ (86 BibTeX, 18 refs)
# [75/500] Processing 2312-15960... ✓ (325 BibTeX, 62 refs)
# [76/500] Processing 2312-15962... ✓ (12 BibTeX, 4 refs)
# [77/500] Processing 2312-15963... ✓ (22 BibTeX, 5 refs)
# [78/500] Processing 2312-15964... ✓ (56 BibTeX, 45 refs)
# [79/500] Processing 2312-15965... ✓ (83 BibTeX, 27 refs)
# [80/500] Processing 2312-15966... ✓ (362 BibTeX, 26 refs)
# [81/500] Processing 2312-15968... ✓ (25 BibTeX, 2 refs)
# [82/500] Processing 2312-15971... ✓ (35 BibTeX, 17 refs)
# [83/500] Processing 2312-15973... ✓ (41 BibTeX, 6 refs)
# [84/500] Processing 2312-15974... ✓ (16 BibTeX, 2 refs)
# [85/500] Processing 2312-15975... ✓ (57 BibTeX, 22 refs)
# [86/500] Processing 2312-15979... ✓ (60 BibTeX, 24 refs)
# [87/500] Processing 2312-15980... ✓ (119 BibTeX, 79 refs)
# [88/500] Processing 2312-15982... ✓ (39 BibTeX, 2 refs)
# [89/500] Processing 2312-15983... ✓ (74 BibTeX, 35 refs)
# [90/500] Processing 2312-15984... ✓ (70 BibTeX, 4 refs)
# [91/500] Processing 2312-15985... ✓ (50 BibTeX, 20 refs)
# [92/500] Processing 2312-15986... ✓ (28 BibTeX, 0 refs)
# [93/500] Processing 2312-15987... ✓ (819 BibTeX, 8 refs)
# [94/500] Processing 2312-15990... ✓ (13 BibTeX, 1 refs)
# [95/500] Processing 2312-15994... ✓ (42 BibTeX, 11 refs)
# [96/500] Processing 2312-15995... ✓ (97 BibTeX, 53 refs)
# [97/500] Processing 2312-15996... ✓ (16 BibTeX, 15 refs)
# [98/500] Processing 2312-15997... ✓ (80520 BibTeX, 30 refs)
# [99/500] Processing 2312-15998... ✓ (150 BibTeX, 0 refs)
# [100/500] Processing 2312-15999... ✓ (127 BibTeX, 17 refs)
# [101/500] Processing 2312-16000... ✓ (78 BibTeX, 16 refs)
# [102/500] Processing 2312-16001... ✓ (82 BibTeX, 60 refs)
# [103/500] Processing 2312-16002... ✓ (11 BibTeX, 8 refs)
# [104/500] Processing 2312-16003... ✓ (23 BibTeX, 4 refs)
# [105/500] Processing 2312-16004... ✓ (35 BibTeX, 1 refs)
# [106/500] Processing 2312-16006... ✓ (15 BibTeX, 5 refs)
# [107/500] Processing 2312-16007... ✓ (48 BibTeX, 3 refs)
# [108/500] Processing 2312-16008... ✓ (19 BibTeX, 10 refs)
# [109/500] Processing 2312-16010... ✓ (9 BibTeX, 3 refs)
# [110/500] Processing 2312-16014... ✓ (100 BibTeX, 38 refs)
# [111/500] Processing 2312-16015... ✓ (49 BibTeX, 11 refs)
# [112/500] Processing 2312-16016... ✓ (90 BibTeX, 25 refs)
# [113/500] Processing 2312-16018... ✓ (204 BibTeX, 65 refs)
# [114/500] Processing 2312-16019... ✓ (93 BibTeX, 25 refs)
# [115/500] Processing 2312-16020... ✓ (21 BibTeX, 21 refs)
# [116/500] Processing 2312-16022... ✓ (18 BibTeX, 15 refs)
# [117/500] Processing 2312-16023... ✓ (66 BibTeX, 16 refs)
# [118/500] Processing 2312-16024... ✓ (78 BibTeX, 14 refs)
# [119/500] Processing 2312-16025... ✓ (69309 BibTeX, 19 refs)
# [120/500] Processing 2312-16026... ✓ (47 BibTeX, 1 refs)
# [121/500] Processing 2312-16027... ✓ (133 BibTeX, 44 refs)
# [122/500] Processing 2312-16028... ✓ (78 BibTeX, 0 refs)
# [123/500] Processing 2312-16029... ✓ (81 BibTeX, 58 refs)
# [124/500] Processing 2312-16031... ✓ (10 BibTeX, 0 refs)
# [125/500] Processing 2312-16032... ✓ (98 BibTeX, 3 refs)
# [126/500] Processing 2312-16033... ✓ (29 BibTeX, 2 refs)
# [127/500] Processing 2312-16034... ✓ (139 BibTeX, 22 refs)
# [128/500] Processing 2312-16036... ✓ (33 BibTeX, 3 refs)
# [129/500] Processing 2312-16037... ✓ (78 BibTeX, 3 refs)
# [130/500] Processing 2312-16038... ✓ (66 BibTeX, 40 refs)
# [131/500] Processing 2312-16039... ✓ (74 BibTeX, 26 refs)
# [132/500] Processing 2312-16040... ✓ (255 BibTeX, 9 refs)
# [133/500] Processing 2312-16041... ✓ (71 BibTeX, 23 refs)
# [134/500] Processing 2312-16042... ✓ (82 BibTeX, 61 refs)
# [135/500] Processing 2312-16043... ✓ (60 BibTeX, 25 refs)
# [136/500] Processing 2312-16044... ✓ (62 BibTeX, 22 refs)
# [137/500] Processing 2312-16045... ✓ (24 BibTeX, 20 refs)
# [138/500] Processing 2312-16046... ✓ (51 BibTeX, 18 refs)
# [139/500] Processing 2312-16047... ✓ (29 BibTeX, 20 refs)
# [140/500] Processing 2312-16048... ✓ (31 BibTeX, 2 refs)
# [141/500] Processing 2312-16050... ✓ (87 BibTeX, 43 refs)
# [142/500] Processing 2312-16051... ✓ (117 BibTeX, 69 refs)
# [143/500] Processing 2312-16052... ✓ (44 BibTeX, 20 refs)
# [144/500] Processing 2312-16053... ✓ (114 BibTeX, 2 refs)
# [145/500] Processing 2312-16054... ✓ (414 BibTeX, 7 refs)
# [146/500] Processing 2312-16055... ✓ (116 BibTeX, 63 refs)
# [147/500] Processing 2312-16056... ✓ (96 BibTeX, 40 refs)
# [148/500] Processing 2312-16057... ✓ (81 BibTeX, 18 refs)
# [149/500] Processing 2312-16059... ✓ (12 BibTeX, 15 refs)
# [150/500] Processing 2312-16060... ✓ (15 BibTeX, 0 refs)
# [151/500] Processing 2312-16061... ✓ (47 BibTeX, 27 refs)
# [152/500] Processing 2312-16062... ✓ (99 BibTeX, 32 refs)
# [153/500] Processing 2312-16063... ✓ (48 BibTeX, 3 refs)
# [154/500] Processing 2312-16064... ✓ (20 BibTeX, 7 refs)
# [155/500] Processing 2312-16065... ✓ (62 BibTeX, 19 refs)
# [156/500] Processing 2312-16066... ✓ (109 BibTeX, 38 refs)
# [157/500] Processing 2312-16067... ✓ (66 BibTeX, 4 refs)
# [158/500] Processing 2312-16069... ✓ (37 BibTeX, 0 refs)
# [159/500] Processing 2312-16071... ✓ (139 BibTeX, 28 refs)
# [160/500] Processing 2312-16073... ✓ (52 BibTeX, 20 refs)
# [161/500] Processing 2312-16074... ✓ (43 BibTeX, 9 refs)
# [162/500] Processing 2312-16075... ✓ (162 BibTeX, 61 refs)
# [163/500] Processing 2312-16077... ✓ (18 BibTeX, 6 refs)
# [164/500] Processing 2312-16078... ✓ (87 BibTeX, 22 refs)
# [165/500] Processing 2312-16080... ✓ (65 BibTeX, 3 refs)
# [166/500] Processing 2312-16081... ✓ (124 BibTeX, 40 refs)
# [167/500] Processing 2312-16082... ✓ (70 BibTeX, 45 refs)
# [168/500] Processing 2312-16083... ✓ (229 BibTeX, 14 refs)
# [169/500] Processing 2312-16084... ✓ (56 BibTeX, 49 refs)
# [170/500] Processing 2312-16086... ✓ (35 BibTeX, 0 refs)
# [171/500] Processing 2312-16088... ✓ (47 BibTeX, 44 refs)
# [172/500] Processing 2312-16092... ✓ (104 BibTeX, 5 refs)
# [173/500] Processing 2312-16093... ✓ (105 BibTeX, 10 refs)
# [174/500] Processing 2312-16095... ✓ (51 BibTeX, 19 refs)
# [175/500] Processing 2312-16096... ✓ (146 BibTeX, 56 refs)
# [176/500] Processing 2312-16100... ✓ (182 BibTeX, 11 refs)
# [177/500] Processing 2312-16101... ✓ (103 BibTeX, 65 refs)
# [178/500] Processing 2312-16102... ✓ (140 BibTeX, 10 refs)
# [179/500] Processing 2312-16104... ✓ (81 BibTeX, 21 refs)
# [180/500] Processing 2312-16106... ✓ (265 BibTeX, 10 refs)
# [181/500] Processing 2312-16107... ✓ (38 BibTeX, 7 refs)
# [182/500] Processing 2312-16108... ✓ (310 BibTeX, 29 refs)
# [183/500] Processing 2312-16109... ✓ (103 BibTeX, 29 refs)
# [184/500] Processing 2312-16110... ✓ (287 BibTeX, 43 refs)
# [185/500] Processing 2312-16113... ✓ (574 BibTeX, 12 refs)
# [186/500] Processing 2312-16114... ✓ (402 BibTeX, 14 refs)
# [187/500] Processing 2312-16115... ✓ (35 BibTeX, 4 refs)
# [188/500] Processing 2312-16116... ✓ (34 BibTeX, 7 refs)
# [189/500] Processing 2312-16118... ✓ (72 BibTeX, 20 refs)
# [190/500] Processing 2312-16119... ✓ (20 BibTeX, 7 refs)
# [191/500] Processing 2312-16122... ✓ (50 BibTeX, 7 refs)
# [192/500] Processing 2312-16123... ✓ (46 BibTeX, 26 refs)
# [193/500] Processing 2312-16124... ✓ (69 BibTeX, 16 refs)
# [194/500] Processing 2312-16125... ✓ (9 BibTeX, 1 refs)
# [195/500] Processing 2312-16126... ✓ (134 BibTeX, 1 refs)
# [196/500] Processing 2312-16127... ✓ (119 BibTeX, 34 refs)
# [197/500] Processing 2312-16129... ✓ (162 BibTeX, 1 refs)
# [198/500] Processing 2312-16131... ✓ (81 BibTeX, 16 refs)
# [199/500] Processing 2312-16132... ✓ (39 BibTeX, 26 refs)
# [200/500] Processing 2312-16135... ✓ (32 BibTeX, 17 refs)
# [201/500] Processing 2312-16139... ✓ (19 BibTeX, 0 refs)
# [202/500] Processing 2312-16141... ✓ (42 BibTeX, 23 refs)
# [203/500] Processing 2312-16142... ✓ (70 BibTeX, 16 refs)
# [204/500] Processing 2312-16143... ✓ (675 BibTeX, 0 refs)
# [205/500] Processing 2312-16144... ✓ (45 BibTeX, 13 refs)
# [206/500] Processing 2312-16145... ✓ (69 BibTeX, 46 refs)
# [207/500] Processing 2312-16147... ✓ (468 BibTeX, 0 refs)
# [208/500] Processing 2312-16149... ✓ (207 BibTeX, 31 refs)
# [209/500] Processing 2312-16150... ✓ (73 BibTeX, 0 refs)
# [210/500] Processing 2312-16151... ✓ (173 BibTeX, 57 refs)
# [211/500] Processing 2312-16154... ✓ (19 BibTeX, 2 refs)
# [212/500] Processing 2312-16156... ✓ (150 BibTeX, 47 refs)
# [213/500] Processing 2312-16157... ✓ (47 BibTeX, 0 refs)
# [214/500] Processing 2312-16161... ✓ (151 BibTeX, 0 refs)
# [215/500] Processing 2312-16162... ✓ (66 BibTeX, 6 refs)
# [216/500] Processing 2312-16163... ✓ (76 BibTeX, 27 refs)
# [217/500] Processing 2312-16164... ✓ (118 BibTeX, 30 refs)
# [218/500] Processing 2312-16165... ✓ (115 BibTeX, 52 refs)
# [219/500] Processing 2312-16166... ✓ (43 BibTeX, 52 refs)
# [220/500] Processing 2312-16168... ✓ (87 BibTeX, 37 refs)
# [221/500] Processing 2312-16170... ✓ (152 BibTeX, 57 refs)
# [222/500] Processing 2312-16171... ✓ (62 BibTeX, 16 refs)
# [223/500] Processing 2312-16174... ✓ (388 BibTeX, 22 refs)
# [224/500] Processing 2312-16175... ✓ (36 BibTeX, 5 refs)
# [225/500] Processing 2312-16176... ✓ (39 BibTeX, 16 refs)
# [226/500] Processing 2312-16177... ✓ (55 BibTeX, 6 refs)
# [227/500] Processing 2312-16179... ✓ (159 BibTeX, 3 refs)
# [228/500] Processing 2312-16180... ✓ (44 BibTeX, 10 refs)
# [229/500] Processing 2312-16181... ✓ (2 BibTeX, 0 refs)
# [230/500] Processing 2312-16182... ✓ (105 BibTeX, 23 refs)
# [231/500] Processing 2312-16183... ✓ (5 BibTeX, 5 refs)
# [232/500] Processing 2312-16184... ✓ (200 BibTeX, 14 refs)
# [233/500] Processing 2312-16185... ✓ (57 BibTeX, 12 refs)
# [234/500] Processing 2312-16186... ✓ (90 BibTeX, 37 refs)
# [235/500] Processing 2312-16187... ✓ (6 BibTeX, 0 refs)
# [236/500] Processing 2312-16188... ✓ (3 BibTeX, 1 refs)
# [237/500] Processing 2312-16189... ✓ (46 BibTeX, 26 refs)
# [238/500] Processing 2312-16190... ✓ (31 BibTeX, 8 refs)
# [239/500] Processing 2312-16192... ✓ (24 BibTeX, 6 refs)
# [240/500] Processing 2312-16193... ✓ (240 BibTeX, 7 refs)
# [241/500] Processing 2312-16196... ✓ (104 BibTeX, 9 refs)
# [242/500] Processing 2312-16197... ✓ (94 BibTeX, 54 refs)
# [243/500] Processing 2312-16198... ✓ (44 BibTeX, 21 refs)
# [244/500] Processing 2312-16199... ✓ (72 BibTeX, 34 refs)
# [245/500] Processing 2312-16201... ✓ (24 BibTeX, 6 refs)
# [246/500] Processing 2312-16202... ✓ (15 BibTeX, 13 refs)
# [247/500] Processing 2312-16204... ✓ (67 BibTeX, 32 refs)
# [248/500] Processing 2312-16206... ✓ (51 BibTeX, 41 refs)
# [249/500] Processing 2312-16209... ✓ (98 BibTeX, 0 refs)
# [250/500] Processing 2312-16210... ✓ (48 BibTeX, 10 refs)
# [251/500] Processing 2312-16211... ✓ (53 BibTeX, 16 refs)
# [252/500] Processing 2312-16212... ✓ (130 BibTeX, 69 refs)
# [253/500] Processing 2312-16214... ✓ (1506 BibTeX, 0 refs)
# [254/500] Processing 2312-16215... ✓ (61 BibTeX, 26 refs)
# [255/500] Processing 2312-16216... ✓ (37 BibTeX, 3 refs)
# [256/500] Processing 2312-16217... ✓ (74 BibTeX, 33 refs)
# [257/500] Processing 2312-16218... ✓ (52 BibTeX, 40 refs)
# [258/500] Processing 2312-16220... ✓ (109 BibTeX, 41 refs)
# [259/500] Processing 2312-16221... ✓ (88 BibTeX, 47 refs)
# [260/500] Processing 2312-16222... ✓ (101 BibTeX, 70 refs)
# [261/500] Processing 2312-16223... ✓ (32 BibTeX, 5 refs)
# [262/500] Processing 2312-16224... ✓ (83 BibTeX, 1 refs)
# [263/500] Processing 2312-16227... ✓ (36 BibTeX, 5 refs)
# [264/500] Processing 2312-16228... ✓ (55 BibTeX, 43 refs)
# [265/500] Processing 2312-16230... ✓ (19 BibTeX, 5 refs)
# [266/500] Processing 2312-16231... ✓ (42 BibTeX, 20 refs)
# [267/500] Processing 2312-16232... ✓ (23 BibTeX, 6 refs)
# [268/500] Processing 2312-16233... ✓ (30 BibTeX, 15 refs)
# [269/500] Processing 2312-16237... ✓ (137 BibTeX, 27 refs)
# [270/500] Processing 2312-16240... ✓ (57 BibTeX, 29 refs)
# [271/500] Processing 2312-16241... ✓ (58 BibTeX, 0 refs)
# [272/500] Processing 2312-16242... ✓ (90 BibTeX, 49 refs)
# [273/500] Processing 2312-16243... ✓ (62 BibTeX, 39 refs)
# [274/500] Processing 2312-16244... ✓ (115 BibTeX, 33 refs)
# [275/500] Processing 2312-16245... ✓ (53 BibTeX, 42 refs)
# [276/500] Processing 2312-16246... ✓ (164 BibTeX, 28 refs)
# [277/500] Processing 2312-16247... ✓ (170 BibTeX, 38 refs)
# [278/500] Processing 2312-16248... ✓ (36 BibTeX, 21 refs)
# [279/500] Processing 2312-16249... ✓ (24 BibTeX, 0 refs)
# [280/500] Processing 2312-16250... ✓ (62 BibTeX, 27 refs)
# [281/500] Processing 2312-16251... ✓ (46 BibTeX, 28 refs)
# [282/500] Processing 2312-16252... ✓ (37 BibTeX, 1 refs)
# [283/500] Processing 2312-16253... ✓ (203 BibTeX, 10 refs)
# [284/500] Processing 2312-16255... ✓ (31 BibTeX, 11 refs)
# [285/500] Processing 2312-16257... ✓ (62566 BibTeX, 20 refs)
# [286/500] Processing 2312-16258... ✓ (39 BibTeX, 1 refs)
# [287/500] Processing 2312-16260... ✓ (32 BibTeX, 3 refs)
# [288/500] Processing 2312-16262... ✓ (68 BibTeX, 35 refs)
# [289/500] Processing 2312-16263... ✓ (26 BibTeX, 0 refs)
# [290/500] Processing 2312-16264... ✓ (42 BibTeX, 25 refs)
# [291/500] Processing 2312-16265... ✓ (1551 BibTeX, 0 refs)
# [292/500] Processing 2312-16266... ✓ (485 BibTeX, 0 refs)
# [293/500] Processing 2312-16267... ✓ (3 BibTeX, 13 refs)
# [294/500] Processing 2312-16268... ✓ (44 BibTeX, 27 refs)
# [295/500] Processing 2312-16270... ✓ (74 BibTeX, 46 refs)
# [296/500] Processing 2312-16272... ✓ (88 BibTeX, 48 refs)
# [297/500] Processing 2312-16274... ✓ (47 BibTeX, 38 refs)
# [298/500] Processing 2312-16275... ✓ (231 BibTeX, 44 refs)
# [299/500] Processing 2312-16276... ✓ (27 BibTeX, 4 refs)
# [300/500] Processing 2312-16278... ✓ (51 BibTeX, 0 refs)
# [301/500] Processing 2312-16279... ✓ (83 BibTeX, 43 refs)
# [302/500] Processing 2312-16280... ✓ (315 BibTeX, 70 refs)
# [303/500] Processing 2312-16282... ✓ (61 BibTeX, 0 refs)
# [304/500] Processing 2312-16285... ✓ (884 BibTeX, 89 refs)
# [305/500] Processing 2312-16286... ✓ (637 BibTeX, 83 refs)
# [306/500] Processing 2312-16289... ✓ (88 BibTeX, 1 refs)
# [307/500] Processing 2312-16292... ✓ (179 BibTeX, 0 refs)
# [308/500] Processing 2312-16295... ✓ (38 BibTeX, 27 refs)
# [309/500] Processing 2312-16296... ✓ (124 BibTeX, 10 refs)
# [310/500] Processing 2312-16297... ✓ (572 BibTeX, 8 refs)
# [311/500] Processing 2312-16301... ✓ (143 BibTeX, 14 refs)
# [312/500] Processing 2312-16302... ✓ (8 BibTeX, 2 refs)
# [313/500] Processing 2312-16305... ✓ (90 BibTeX, 74 refs)
# [314/500] Processing 2312-16307... ✓ (51 BibTeX, 19 refs)
# [315/500] Processing 2312-16308... ✓ (22 BibTeX, 19 refs)
# [316/500] Processing 2312-16312... ✓ (23 BibTeX, 5 refs)
# [317/500] Processing 2312-16313... ✓ (184 BibTeX, 47 refs)
# [318/500] Processing 2312-16318... ✓ (63 BibTeX, 8 refs)
# [319/500] Processing 2312-16322... ✓ (52 BibTeX, 1 refs)
# [320/500] Processing 2312-16323... ✓ (109 BibTeX, 15 refs)
# [321/500] Processing 2312-16324... ✓ (205 BibTeX, 30 refs)
# [322/500] Processing 2312-16325... ✓ (43 BibTeX, 4 refs)
# [323/500] Processing 2312-16335... ✓ (109 BibTeX, 36 refs)
# [324/500] Processing 2312-16336... ✓ (20 BibTeX, 6 refs)
# [325/500] Processing 2312-16337... ✓ (91 BibTeX, 29 refs)
# [326/500] Processing 2312-16338... ✓ (108 BibTeX, 12 refs)
# [327/500] Processing 2312-16339... ✓ (33 BibTeX, 23 refs)
# [328/500] Processing 2312-16340... ✓ (225 BibTeX, 17 refs)
# [329/500] Processing 2312-16341... ✓ (113 BibTeX, 75 refs)
# [330/500] Processing 2312-16342... ✓ (187 BibTeX, 51 refs)
# [331/500] Processing 2312-16343... ✓ (91 BibTeX, 24 refs)
# [332/500] Processing 2312-16345... ✓ (33 BibTeX, 1 refs)
# [333/500] Processing 2312-16346... ✓ (34 BibTeX, 5 refs)
# [334/500] Processing 2312-16347... ✓ (49 BibTeX, 28 refs)
# [335/500] Processing 2312-16348... ✓ (31 BibTeX, 18 refs)
# [336/500] Processing 2312-16351... ✓ (71 BibTeX, 18 refs)
# [337/500] Processing 2312-16352... ✓ (789 BibTeX, 3 refs)
# [338/500] Processing 2312-16353... ✓ (24 BibTeX, 5 refs)
# [339/500] Processing 2312-16355... ✓ (68 BibTeX, 8 refs)
# [340/500] Processing 2312-16356... ✓ (569 BibTeX, 8 refs)
# [341/500] Processing 2312-16358... ✓ (49 BibTeX, 43 refs)
# [342/500] Processing 2312-16360... ✓ (64 BibTeX, 42 refs)
# [343/500] Processing 2312-16363... ✓ (20 BibTeX, 0 refs)
# [344/500] Processing 2312-16364... ✓ (23 BibTeX, 12 refs)
# [345/500] Processing 2312-16370... ✓ (48 BibTeX, 8 refs)
# [346/500] Processing 2312-16371... ✓ (15 BibTeX, 4 refs)
# [347/500] Processing 2312-16372... ✓ (43 BibTeX, 9 refs)
# [348/500] Processing 2312-16373... ✓ (23 BibTeX, 12 refs)
# [349/500] Processing 2312-16374... ✓ (53 BibTeX, 27 refs)
# [350/500] Processing 2312-16376... ✓ (56 BibTeX, 8 refs)
# [351/500] Processing 2312-16377... ✓ (61 BibTeX, 14 refs)
# [352/500] Processing 2312-16378... ✓ (25 BibTeX, 4 refs)
# [353/500] Processing 2312-16380... ✓ (238 BibTeX, 26 refs)
# [354/500] Processing 2312-16381... ✓ (33 BibTeX, 12 refs)
# [355/500] Processing 2312-16382... ✓ (98 BibTeX, 0 refs)
# [356/500] Processing 2312-16383... ✓ (27 BibTeX, 12 refs)
# [357/500] Processing 2312-16385... ✓ (45 BibTeX, 16 refs)
# [358/500] Processing 2312-16386... ✓ (48 BibTeX, 1 refs)
# [359/500] Processing 2312-16387... ✓ (38 BibTeX, 3 refs)
# [360/500] Processing 2312-16388... ✓ (79 BibTeX, 29 refs)
# [361/500] Processing 2312-16389... ✓ (21 BibTeX, 0 refs)
# [362/500] Processing 2312-16391... ✓ (61 BibTeX, 3 refs)
# [363/500] Processing 2312-16392... ✓ (153 BibTeX, 54 refs)
# [364/500] Processing 2312-16394... ✓ (7 BibTeX, 1 refs)
# [365/500] Processing 2312-16396... ✓ (133 BibTeX, 0 refs)
# [366/500] Processing 2312-16397... ✓ (71 BibTeX, 16 refs)
# [367/500] Processing 2312-16400... ✓ (61 BibTeX, 29 refs)
# [368/500] Processing 2312-16401... ✓ (31 BibTeX, 17 refs)
# [369/500] Processing 2312-16403... ✓ (43 BibTeX, 25 refs)
# [370/500] Processing 2312-16405... ✓ (20 BibTeX, 0 refs)
# [371/500] Processing 2312-16406... ✓ (18 BibTeX, 8 refs)
# [372/500] Processing 2312-16407... ✓ (20 BibTeX, 20 refs)
# [373/500] Processing 2312-16409... ✓ (53 BibTeX, 14 refs)
# [374/500] Processing 2312-16410... ✓ (12 BibTeX, 4 refs)
# [375/500] Processing 2312-16412... ✓ (55 BibTeX, 5 refs)
# [376/500] Processing 2312-16414... ✓ (38 BibTeX, 26 refs)
# [377/500] Processing 2312-16415... ✓ (12 BibTeX, 5 refs)
# [378/500] Processing 2312-16418... ✓ (87 BibTeX, 29 refs)
# [379/500] Processing 2312-16420... ✓ (132 BibTeX, 1 refs)
# [380/500] Processing 2312-16422... ✓ (72 BibTeX, 36 refs)
# [381/500] Processing 2312-16423... ✓ (63 BibTeX, 12 refs)
# [382/500] Processing 2312-16424... ✓ (91 BibTeX, 38 refs)
# [383/500] Processing 2312-16425... ✓ (72 BibTeX, 29 refs)
# [384/500] Processing 2312-16426... ✓ (38 BibTeX, 7 refs)
# [385/500] Processing 2312-16427... ✓ (103 BibTeX, 36 refs)
# [386/500] Processing 2312-16428... ✓ (124 BibTeX, 15 refs)
# [387/500] Processing 2312-16429... ✓ (81 BibTeX, 48 refs)
# [388/500] Processing 2312-16430... ✓ (36 BibTeX, 25 refs)
# [389/500] Processing 2312-16431... ✓ (64 BibTeX, 28 refs)
# [390/500] Processing 2312-16432... ✓ (189 BibTeX, 0 refs)
# [391/500] Processing 2312-16433... ✓ (59 BibTeX, 48 refs)
# [392/500] Processing 2312-16435... ✓ (76 BibTeX, 69 refs)
# [393/500] Processing 2312-16436... ✓ (207 BibTeX, 19 refs)
# [394/500] Processing 2312-16437... ✓ (34 BibTeX, 0 refs)
# [395/500] Processing 2312-16439... ✓ (63 BibTeX, 0 refs)
# [396/500] Processing 2312-16441... ✓ (102 BibTeX, 0 refs)
# [397/500] Processing 2312-16442... ✓ (17 BibTeX, 0 refs)
# [398/500] Processing 2312-16443... ✓ (46 BibTeX, 14 refs)
# [399/500] Processing 2312-16445... ✓ (27 BibTeX, 2 refs)
# [400/500] Processing 2312-16448... ✓ (89 BibTeX, 11 refs)
# [401/500] Processing 2312-16450... ✓ (139 BibTeX, 29 refs)
# [402/500] Processing 2312-16451... ✓ (51 BibTeX, 23 refs)
# [403/500] Processing 2312-16453... ✓ (163 BibTeX, 9 refs)
# [404/500] Processing 2312-16455... ✓ (107 BibTeX, 28 refs)
# [405/500] Processing 2312-16456... ✓ (93 BibTeX, 48 refs)
# [406/500] Processing 2312-16457... ✓ (60 BibTeX, 39 refs)
# [407/500] Processing 2312-16459... ✓ (23 BibTeX, 6 refs)
# [408/500] Processing 2312-16460... ✓ (62 BibTeX, 29 refs)
# [409/500] Processing 2312-16463... ✓ (71 BibTeX, 57 refs)
# [410/500] Processing 2312-16466... ✓ (38 BibTeX, 0 refs)
# [411/500] Processing 2312-16467... ✓ (76 BibTeX, 25 refs)
# [412/500] Processing 2312-16468... ✓ (41 BibTeX, 1 refs)
# [413/500] Processing 2312-16470... ✓ (37 BibTeX, 16 refs)
# [414/500] Processing 2312-16475... ✓ (205 BibTeX, 92 refs)
# [415/500] Processing 2312-16476... ✓ (63 BibTeX, 38 refs)
# [416/500] Processing 2312-16477... ✓ (106 BibTeX, 30 refs)
# [417/500] Processing 2312-16478... ✓ (40 BibTeX, 22 refs)
# [418/500] Processing 2312-16479... ✓ (49 BibTeX, 52 refs)
# [419/500] Processing 2312-16480... ✓ (38 BibTeX, 5 refs)
# [420/500] Processing 2312-16483... ✓ (63 BibTeX, 33 refs)
# [421/500] Processing 2312-16485... ✓ (41 BibTeX, 4 refs)
# [422/500] Processing 2312-16486... ✓ (95 BibTeX, 40 refs)
# [423/500] Processing 2312-16487... ✓ (28 BibTeX, 2 refs)
# [424/500] Processing 2312-16488... ✓ (45 BibTeX, 7 refs)
# [425/500] Processing 2312-16490... ✓ (438 BibTeX, 37 refs)
# [426/500] Processing 2312-16491... ✓ (129 BibTeX, 21 refs)
# [427/500] Processing 2312-16493... ✓ (55 BibTeX, 3 refs)
# [428/500] Processing 2312-16495... ✓ (11 BibTeX, 3 refs)
# [429/500] Processing 2312-16496... ✓ (27 BibTeX, 11 refs)
# [430/500] Processing 2312-16498... ✓ (49 BibTeX, 20 refs)
# [431/500] Processing 2312-16499... ✓ (31 BibTeX, 9 refs)
# [432/500] Processing 2312-16501... ✓ (55 BibTeX, 5 refs)
# [433/500] Processing 2312-16502... ✓ (75 BibTeX, 5 refs)
# [434/500] Processing 2312-16503... ✓ (81 BibTeX, 10 refs)
# [435/500] Processing 2312-16504... ✓ (37 BibTeX, 16 refs)
# [436/500] Processing 2312-16505... ✓ (51 BibTeX, 3 refs)
# [437/500] Processing 2312-16508... ✓ (110 BibTeX, 26 refs)
# [438/500] Processing 2312-16509... ✓ (44 BibTeX, 13 refs)
# [439/500] Processing 2312-16512... ✓ (413 BibTeX, 29 refs)
# [440/500] Processing 2312-16513... ✓ (144 BibTeX, 9 refs)
# [441/500] Processing 2312-16516... ✓ (32 BibTeX, 12 refs)
# [442/500] Processing 2312-16517... ✓ (24 BibTeX, 9 refs)
# [443/500] Processing 2312-16521... ✓ (85 BibTeX, 0 refs)
# [444/500] Processing 2312-16524... ✓ (46 BibTeX, 4 refs)
# [445/500] Processing 2312-16525... ✓ (44 BibTeX, 5 refs)
# [446/500] Processing 2312-16529... ✓ (8 BibTeX, 3 refs)
# [447/500] Processing 2312-16532... ✓ (32 BibTeX, 0 refs)
# [448/500] Processing 2312-16533... ✓ (106 BibTeX, 24 refs)
# [449/500] Processing 2312-16534... ✓ (70 BibTeX, 10 refs)
# [450/500] Processing 2312-16535... ✓ (35 BibTeX, 9 refs)
# [451/500] Processing 2312-16536... ✓ (24 BibTeX, 1 refs)
# [452/500] Processing 2312-16537... ✓ (11 BibTeX, 8 refs)
# [453/500] Processing 2312-16540... ✓ (14 BibTeX, 4 refs)
# [454/500] Processing 2312-16541... ✓ (28 BibTeX, 20 refs)
# [455/500] Processing 2312-16542... ✓ (63 BibTeX, 22 refs)
# [456/500] Processing 2312-16544... ✓ (41 BibTeX, 10 refs)
# [457/500] Processing 2312-16545... ✓ (47 BibTeX, 0 refs)
# [458/500] Processing 2312-16547... ✓ (69 BibTeX, 13 refs)
# [459/500] Processing 2312-16549... ✓ (41 BibTeX, 9 refs)
# [460/500] Processing 2312-16551... ✓ (239 BibTeX, 33 refs)
# [461/500] Processing 2312-16552... ✓ (37 BibTeX, 16 refs)
# [462/500] Processing 2312-16553... ✓ (70 BibTeX, 0 refs)
# [463/500] Processing 2312-16554... ✓ (62 BibTeX, 29 refs)
# [464/500] Processing 2312-16556... ✓ (71 BibTeX, 92 refs)
# [465/500] Processing 2312-16557... ✓ (44 BibTeX, 0 refs)
# [466/500] Processing 2312-16558... ✓ (33 BibTeX, 7 refs)
# [467/500] Processing 2312-16559... ✓ (104 BibTeX, 22 refs)
# [468/500] Processing 2312-16560... ✓ (99 BibTeX, 76 refs)
# [469/500] Processing 2312-16561... ✓ (411 BibTeX, 14 refs)
# [470/500] Processing 2312-16562... ✓ (60 BibTeX, 36 refs)
# [471/500] Processing 2312-16563... ✓ (178 BibTeX, 53 refs)
# [472/500] Processing 2312-16564... ✓ (67 BibTeX, 5 refs)
# [473/500] Processing 2312-16565... ✓ (104 BibTeX, 9 refs)
# [474/500] Processing 2312-16566... ✓ (30 BibTeX, 8 refs)
# [475/500] Processing 2312-16567... ✓ (32 BibTeX, 9 refs)
# [476/500] Processing 2312-16569... ✓ (86 BibTeX, 22 refs)
# [477/500] Processing 2312-16571... ✓ (74 BibTeX, 41 refs)
# [478/500] Processing 2312-16572... ✓ (53 BibTeX, 13 refs)
# [479/500] Processing 2312-16574... ✓ (46 BibTeX, 8 refs)
# [480/500] Processing 2312-16577... ✓ (28 BibTeX, 13 refs)
# [481/500] Processing 2312-16578... ✓ (68 BibTeX, 25 refs)
# [482/500] Processing 2312-16580... ✓ (52 BibTeX, 24 refs)
# [483/500] Processing 2312-16581... ✓ (73 BibTeX, 30 refs)
# [484/500] Processing 2312-16582... ✓ (46 BibTeX, 12 refs)
# [485/500] Processing 2312-16583... ✓ (77 BibTeX, 74 refs)
# [486/500] Processing 2312-16584... ✓ (232 BibTeX, 5 refs)
# [487/500] Processing 2312-16585... ✓ (84 BibTeX, 18 refs)
# [488/500] Processing 2312-16587... ✓ (131 BibTeX, 61 refs)
# [489/500] Processing 2312-16591... ✓ (80 BibTeX, 4 refs)
# [490/500] Processing 2312-16592... ✓ (11 BibTeX, 6 refs)
# [491/500] Processing 2312-16595... ✓ (5 BibTeX, 1 refs)
# [492/500] Processing 2312-16596... ✓ (50 BibTeX, 6 refs)
# [493/500] Processing 2312-16597... ✓ (107 BibTeX, 4 refs)
# [494/500] Processing 2312-16598... ✓ (162 BibTeX, 3 refs)
# [495/500] Processing 2312-16599... ✓ (42 BibTeX, 5 refs)
# [496/500] Processing 2312-16600... ✓ (48 BibTeX, 7 refs)
# [497/500] Processing 2312-16603... ✓ (19 BibTeX, 11 refs)
# [498/500] Processing 2312-16604... ✓ (47 BibTeX, 17 refs)
# [499/500] Processing 2312-16605... ✓ (91 BibTeX, 75 refs)
# [500/500] Processing 2312-16606... ✓ (9 BibTeX, 0 refs)
#
# ================================================================================
# Processing Complete!
#   - Papers processed: 500
#   - Total BibTeX entries: 424474
#   - Total references: 10267
#   - Output directory: /mnt/d/Programming/School/NMKHDL/Lab2/bibtex/23127088

# %% [markdown]
# ## Summary
#
#  **Task 2.2.1 - Data Cleaning Pipeline Complete**:
# 1. Loaded BibTeX entries and references.json data
# 2. Applied comprehensive text normalization
# 3. Standardized titles, authors, and metadata
# 4. Extracted key matching features (year, arXiv ID, last names)
# 5. Saved cleaned data in `bibtex/{paper_id}/cleaned_data.json` for each paper
#
# ### Cleaning Justifications:
#
# | Cleaning Step | Reason | Example |
# |---------------|--------|----------|
# | Lowercasing | Case-insensitive matching | "Deep Learning" → "deep learning" |
# | Unicode normalization | Handle accents/special chars | "Müller" → "Muller" |
# | Punctuation removal | Standardize format | "Smith, J." → "smith j" |
# | Stop word removal | Focus on meaningful words | "The Art of Programming" → "art programming" |
# | Author name extraction | Match by last name | "Smith, J., Jones, K." → ["smith", "jones"] |
# | Year extraction | Temporal matching | "Published 2020" → 2020 |
#
# ### Output Structure:
#
# Each paper's cleaned data is saved as:
# ```
# bibtex/
#   23127088/
#     2312-15857/
#       refs.bib
#       cleaned_data.json  ← New cleaned data file
#     2312-15858/
#       refs.bib
#       cleaned_data.json
#     ...
# ```
#
# ### Next Steps:
#
# Continue to **Task 2.2.2 - Data Labelling** in the next notebook ([2_2_2_Data_Labelling.ipynb](2_2_2_Data_Labelling.ipynb))
