# %%
# Setup and Installation
# !pip install arxiv requests psutil
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.

# %%
from pathlib import Path
import os

BASE_DIR = Path("/content/arxiv_scraper")
BASE_DIR.mkdir(exist_ok=True)
os.chdir(BASE_DIR)

# Create subdirectories
for dir_name in ["lib", "data", "logs", "data/papers", "data/temp", "data/statistics"]:
    (BASE_DIR / dir_name).mkdir(parents=True, exist_ok=True)

print("Directory structure created")
# Out:
# Directory structure created

# %%
# %%writefile config.py
from pathlib import Path

# Project paths
BASE_DIR = Path(__file__).parent
DATA_DIR = BASE_DIR / "data"
PAPERS_DIR = DATA_DIR / "papers"
TEMP_DIR = DATA_DIR / "temp"
LOGS_DIR = BASE_DIR / "logs"
STATS_DIR = DATA_DIR / "statistics"

# Create directories if they don't exist
for directory in [PAPERS_DIR, TEMP_DIR, LOGS_DIR, STATS_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

# arXiv settings
ARXIV_ID_RANGES = [
    ("2312", 15844, 16343), # Take only 500 papers for report
    # ("2312", 15844, 99999),
    # ("2401", 0, 3095),
]

# API settings
SEMANTIC_SCHOLAR_API_BASE = "https://api.semanticscholar.org/graph/v1"
REQUEST_DELAY = 3  # Delay between reference API calls
MAX_RETRIES = 7
RETRY_DELAY = 3.0


# arXiv API settings
ARXIV_MAX_RESULTS = 100
ARXIV_DELAY = 3.0
ARXIV_BATCH_SIZE = 100

# Download settings
PAPER_DOWNLOAD_BATCH_SIZE = 5  # Concurrent papers to download (main parallel)
REFERENCE_BATCH_SIZE = 2  # Concurrent reference API calls

# Figure extensions to remove
FIGURE_EXTENSIONS = ['.png', '.jpg', '.jpeg', '.pdf', '.eps', '.ps', '.gif', '.svg', '.bmp']

# File size limits
MAX_FILE_SIZE = 100 * 1024 * 1024

# Stats settings
STATS_SAVE_INTERVAL = 10

# Cleanup settings
DELETE_RAW_AFTER_EXTRACT = True
DELETE_TEMP_AFTER_COPY = True




# Semantic Scholar fields
SEMANTIC_SCHOLAR_FIELDS = "references,references.title,references.authors,references.year,references.paperId,references.externalIds"
SEMANTIC_KEY_API = "FkKyqq5p9R96KizMlPWBwa0YtPjCvyq24ddno82O"
# Out:
# Writing config.py

# %%
# %%writefile lib/statistics_tracker.py
import psutil
import time
import json
from pathlib import Path
from datetime import datetime, timedelta
from typing import Dict, Any, Optional
import logging
import config

logger = logging.getLogger(__name__)


class StatisticsTracker:
    """Track and report statistics for the scraping process."""

    def __init__(self):
        self.stats = {
            'start_time': None,
            'end_time': None,
            'total_duration': 0,

            # Paper statistics
            'papers': {
                'total_identified': 0,
                'total_attempted': 0,
                'successfully_downloaded': 0,
                'failed_downloads': 0,
                'download_success_rate': 0,
            },

            # Version statistics
            'versions': {
                'total_versions': 0,
                'successfully_processed': 0,
                'failed_versions': 0,
            },

            # File size statistics
            'file_sizes': {
                'raw_sizes': [],  # Size before removing figures
                'extracted_sizes': [],  # Size after removing figures
                'total_raw_size': 0,
                'total_extracted_size': 0,
                'average_raw_size': 0,
                'average_extracted_size': 0,
                'space_saved_by_figure_removal': 0,
                'figures_removed': 0,
            },

            # Reference statistics
            'references': {
                'papers_with_references': 0,
                'papers_without_references': 0,
                'total_references': 0,
                'average_references_per_paper': 0,
                'reference_success_rate': 0,
            },

            # Performance metrics
            'performance': {
                'phase_times': {},  # Time for each phase
                'paper_processing_times': [],
                'average_time_per_paper': 0,
                'fastest_paper_time': float('inf'),
                'slowest_paper_time': 0,
            },

            # Memory statistics
            'memory': {
                'initial_ram_mb': 0,
                'peak_ram_mb': 0,
                'average_ram_mb': 0,
                'ram_samples': [],
                'initial_disk_gb': 0,
                'final_disk_gb': 0,
                'disk_space_used_gb': 0,
            },

            # Errors
            'errors': {
                'total_errors': 0,
                'error_types': {},
            }
        }

        self.process = psutil.Process()
        self.current_phase = None
        self.phase_start_time = None
        self.papers_processed_since_save = 0
        self.save_interval = config.STATS_SAVE_INTERVAL

    def start(self):
        """Start tracking."""
        self.stats['start_time'] = datetime.now()
        self.stats['memory']['initial_ram_mb'] = self.process.memory_info().rss / (1024 * 1024)
        self.stats['memory']['initial_disk_gb'] = self._get_disk_usage()
        logger.info("Statistics tracking started")

        # Try to load existing stats if resuming
        self.load_checkpoint()

    def end(self):
        """End tracking and calculate final statistics."""
        self.stats['end_time'] = datetime.now()
        self.stats['total_duration'] = (self.stats['end_time'] - self.stats['start_time']).total_seconds()

        # Calculate final memory stats
        self.stats['memory']['final_disk_gb'] = self._get_disk_usage()
        self.stats['memory']['disk_space_used_gb'] = (
            self.stats['memory']['final_disk_gb'] - self.stats['memory']['initial_disk_gb']
        )

        if self.stats['memory']['ram_samples']:
            self.stats['memory']['average_ram_mb'] = sum(self.stats['memory']['ram_samples']) / len(self.stats['memory']['ram_samples'])

        # Calculate success rates
        if self.stats['papers']['total_attempted'] > 0:
            self.stats['papers']['download_success_rate'] = (
                self.stats['papers']['successfully_downloaded'] / self.stats['papers']['total_attempted']
            ) * 100

        # Calculate reference success rate
        total_ref_attempts = (
            self.stats['references']['papers_with_references'] +
            self.stats['references']['papers_without_references']
        )
        if total_ref_attempts > 0:
            self.stats['references']['reference_success_rate'] = (
                self.stats['references']['papers_with_references'] / total_ref_attempts
            ) * 100

        # Calculate average references per paper
        if self.stats['references']['papers_with_references'] > 0:
            self.stats['references']['average_references_per_paper'] = (
                self.stats['references']['total_references'] /
                self.stats['references']['papers_with_references']
            )

        # Calculate file size averages
        if self.stats['file_sizes']['raw_sizes']:
            self.stats['file_sizes']['average_raw_size'] = (
                sum(self.stats['file_sizes']['raw_sizes']) / len(self.stats['file_sizes']['raw_sizes'])
            )
            self.stats['file_sizes']['total_raw_size'] = sum(self.stats['file_sizes']['raw_sizes'])

        if self.stats['file_sizes']['extracted_sizes']:
            self.stats['file_sizes']['average_extracted_size'] = (
                sum(self.stats['file_sizes']['extracted_sizes']) / len(self.stats['file_sizes']['extracted_sizes'])
            )
            self.stats['file_sizes']['total_extracted_size'] = sum(self.stats['file_sizes']['extracted_sizes'])

        self.stats['file_sizes']['space_saved_by_figure_removal'] = (
            self.stats['file_sizes']['total_raw_size'] - self.stats['file_sizes']['total_extracted_size']
        )

        # Calculate average time per paper
        if self.stats['performance']['paper_processing_times']:
            self.stats['performance']['average_time_per_paper'] = (
                sum(self.stats['performance']['paper_processing_times']) /
                len(self.stats['performance']['paper_processing_times'])
            )
            self.stats['performance']['fastest_paper_time'] = min(self.stats['performance']['paper_processing_times'])
            self.stats['performance']['slowest_paper_time'] = max(self.stats['performance']['paper_processing_times'])

        logger.info("Statistics tracking completed")

    def start_phase(self, phase_name: str):
        """Start tracking a processing phase."""
        self.current_phase = phase_name
        self.phase_start_time = time.time()
        logger.info(f"Started phase: {phase_name}")

    def end_phase(self):
        """End tracking current phase."""
        if self.current_phase and self.phase_start_time:
            duration = time.time() - self.phase_start_time
            self.stats['performance']['phase_times'][self.current_phase] = duration
            logger.info(f"Completed phase '{self.current_phase}' in {duration:.2f}s")
            self.current_phase = None
            self.phase_start_time = None

    def record_paper_identified(self):
        """Record a paper was identified."""
        self.stats['papers']['total_identified'] += 1

    def record_paper_attempt(self):
        """Record a paper download attempt."""
        self.stats['papers']['total_attempted'] += 1

    def record_paper_success(self, processing_time: float):
        """Record successful paper processing."""
        self.stats['papers']['successfully_downloaded'] += 1
        self.stats['performance']['paper_processing_times'].append(processing_time)

    def record_paper_failure(self):
        """Record failed paper processing."""
        self.stats['papers']['failed_downloads'] += 1

    def record_version(self, success: bool = True):
        """Record version processing."""
        self.stats['versions']['total_versions'] += 1
        if success:
            self.stats['versions']['successfully_processed'] += 1
        else:
            self.stats['versions']['failed_versions'] += 1

    def record_file_sizes(self, raw_size: int, extracted_size: int, figures_removed: int = 0):
        """Record file sizes before and after figure removal."""
        self.stats['file_sizes']['raw_sizes'].append(raw_size)
        self.stats['file_sizes']['extracted_sizes'].append(extracted_size)
        self.stats['file_sizes']['figures_removed'] += figures_removed

    def record_references(self, reference_count: int):
        """Record reference extraction."""
        if reference_count > 0:
            self.stats['references']['papers_with_references'] += 1
            self.stats['references']['total_references'] += reference_count
        else:
            self.stats['references']['papers_without_references'] += 1

    def record_error(self, error_type: str):
        """Record an error."""
        self.stats['errors']['total_errors'] += 1
        if error_type not in self.stats['errors']['error_types']:
            self.stats['errors']['error_types'][error_type] = 0
        self.stats['errors']['error_types'][error_type] += 1

    def sample_memory(self):
        """Sample current memory usage."""
        current_ram_mb = self.process.memory_info().rss / (1024 * 1024)
        self.stats['memory']['ram_samples'].append(current_ram_mb)

        if current_ram_mb > self.stats['memory']['peak_ram_mb']:
            self.stats['memory']['peak_ram_mb'] = current_ram_mb

    def _get_disk_usage(self) -> float:
        """Get current disk usage of data directory in GB."""
        total_size = 0
        try:
            for path in config.DATA_DIR.rglob('*'):
                if path.is_file():
                    total_size += path.stat().st_size
        except Exception as e:
            logger.warning(f"Error calculating disk usage: {e}")
        return total_size / (1024 ** 3)  # Convert to GB

    def get_summary(self) -> Dict[str, Any]:
        """Get statistics summary."""
        return self.stats

    def save_to_file(self, output_path: Optional[Path] = None):
        """Save statistics to JSON file."""
        if output_path is None:
            output_path = config.DATA_DIR / 'statistics.json'

        # Convert datetime objects to strings
        stats_copy = self._serialize_stats(self.stats)

        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(stats_copy, f, indent=2)

        logger.info(f"Statistics saved to {output_path}")

    def save_checkpoint(self):
        """Save incremental checkpoint."""
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        checkpoint_file = config.STATS_DIR / f'checkpoint_{timestamp}.json'

        # Also save to latest checkpoint
        latest_file = config.STATS_DIR / 'checkpoint_latest.json'

        stats_copy = self._serialize_stats(self.stats)

        for file_path in [checkpoint_file, latest_file]:
            try:
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(stats_copy, f, indent=2)
            except Exception as e:
                logger.error(f"Error saving checkpoint to {file_path}: {e}")

        logger.info(f"Checkpoint saved to {checkpoint_file}")
        self.papers_processed_since_save = 0

    def load_checkpoint(self):
        """Load latest checkpoint if exists."""
        latest_file = config.STATS_DIR / 'checkpoint_latest.json'

        if latest_file.exists():
            try:
                with open(latest_file, 'r', encoding='utf-8') as f:
                    loaded_stats = json.load(f)

                # Merge loaded stats with current stats
                # Convert string dates back to datetime
                if 'start_time' in loaded_stats and loaded_stats['start_time']:
                    self.stats['start_time'] = datetime.fromisoformat(loaded_stats['start_time'])

                # Merge other stats
                for key in loaded_stats:
                    if key not in ['start_time', 'end_time']:
                        if isinstance(loaded_stats[key], dict):
                            self.stats[key].update(loaded_stats[key])
                        else:
                            self.stats[key] = loaded_stats[key]

                logger.info(f"Resumed from checkpoint: {latest_file}")
            except Exception as e:
                logger.warning(f"Could not load checkpoint: {e}")

    def maybe_save_checkpoint(self):
        """Save checkpoint if interval reached."""
        self.papers_processed_since_save += 1

        if self.papers_processed_since_save >= self.save_interval:
            self.save_checkpoint()

    def _serialize_stats(self, obj):
        """Serialize datetime objects for JSON."""
        if isinstance(obj, datetime):
            return obj.isoformat()
        elif isinstance(obj, dict):
            return {k: self._serialize_stats(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [self._serialize_stats(item) for item in obj]
        return obj

    def print_summary(self):
        """Print formatted statistics summary."""
        print("\n" + "=" * 80)
        print("SCRAPING STATISTICS REPORT")
        print("=" * 80)

        # Time information
        print(f"\nTIME INFORMATION:")
        print(f"  Start Time: {self.stats['start_time']}")
        print(f"  End Time: {self.stats['end_time']}")
        print(f"  Total Duration: {timedelta(seconds=int(self.stats['total_duration']))}")

        # Phase times
        print(f"\nPHASE DURATIONS:")
        for phase, duration in self.stats['performance']['phase_times'].items():
            print(f"  {phase}: {timedelta(seconds=int(duration))}")

        # Paper statistics
        print(f"\nPAPER STATISTICS:")
        print(f"  Total Identified: {self.stats['papers']['total_identified']}")
        print(f"  Total Attempted: {self.stats['papers']['total_attempted']}")
        print(f"  Successfully Downloaded: {self.stats['papers']['successfully_downloaded']}")
        print(f"  Failed Downloads: {self.stats['papers']['failed_downloads']}")
        print(f"  Success Rate: {self.stats['papers']['download_success_rate']:.2f}%")

        # Version statistics
        print(f"\nVERSION STATISTICS:")
        print(f"  Total Versions: {self.stats['versions']['total_versions']}")
        print(f"  Successfully Processed: {self.stats['versions']['successfully_processed']}")
        print(f"  Failed Versions: {self.stats['versions']['failed_versions']}")

        # Performance
        print(f"\nPERFORMANCE METRICS:")
        if self.stats['performance']['paper_processing_times']:
            print(f"  Average Time per Paper: {self.stats['performance']['average_time_per_paper']:.2f}s")
            print(f"  Fastest Paper: {self.stats['performance']['fastest_paper_time']:.2f}s")
            print(f"  Slowest Paper: {self.stats['performance']['slowest_paper_time']:.2f}s")

        # File sizes
        print(f"\nFILE SIZE STATISTICS:")
        print(f"  Average Size Before Figure Removal: {self._format_bytes(self.stats['file_sizes']['average_raw_size'])}")
        print(f"  Average Size After Figure Removal: {self._format_bytes(self.stats['file_sizes']['average_extracted_size'])}")
        print(f"  Total Raw Size: {self._format_bytes(self.stats['file_sizes']['total_raw_size'])}")
        print(f"  Total Extracted Size: {self._format_bytes(self.stats['file_sizes']['total_extracted_size'])}")
        print(f"  Space Saved: {self._format_bytes(self.stats['file_sizes']['space_saved_by_figure_removal'])}")
        print(f"  Figures Removed: {self.stats['file_sizes']['figures_removed']}")

        # References
        print(f"\nREFERENCE STATISTICS:")
        print(f"  Papers with References: {self.stats['references']['papers_with_references']}")
        print(f"  Papers without References: {self.stats['references']['papers_without_references']}")
        print(f"  Total References: {self.stats['references']['total_references']}")
        print(f"  Average References per Paper: {self.stats['references']['average_references_per_paper']:.2f}")
        print(f"  Reference Success Rate: {self.stats['references']['reference_success_rate']:.2f}%")

        # Memory
        print(f"\nMEMORY USAGE:")
        print(f"  Initial RAM: {self.stats['memory']['initial_ram_mb']:.2f} MB")
        print(f"  Peak RAM: {self.stats['memory']['peak_ram_mb']:.2f} MB")
        print(f"  Average RAM: {self.stats['memory']['average_ram_mb']:.2f} MB")
        print(f"  Initial Disk Usage: {self.stats['memory']['initial_disk_gb']:.2f} GB")
        print(f"  Final Disk Usage: {self.stats['memory']['final_disk_gb']:.2f} GB")
        print(f"  Disk Space Used: {self.stats['memory']['disk_space_used_gb']:.2f} GB")

        # Errors
        if self.stats['errors']['total_errors'] > 0:
            print(f"\nERROR STATISTICS:")
            print(f"  Total Errors: {self.stats['errors']['total_errors']}")
            print(f"  Error Types:")
            for error_type, count in self.stats['errors']['error_types'].items():
                print(f"    {error_type}: {count}")

        print("\n" + "=" * 80)

    def _format_bytes(self, bytes_value: float) -> str:
        """Format bytes to human readable format."""
        for unit in ['B', 'KB', 'MB', 'GB']:
            if bytes_value < 1024.0:
                return f"{bytes_value:.2f} {unit}"
            bytes_value /= 1024.0
        return f"{bytes_value:.2f} TB"
# Out:
# Writing lib/statistics_tracker.py

# %%
# %%writefile lib/paper_organizer.py
import logging
import json
import shutil
from pathlib import Path
from typing import Dict
from datetime import datetime
import sys
sys.path.insert(0, str(Path(__file__).parent.parent))
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'organizer.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class PaperOrganizer:
    """Organize papers in the new required structure."""

    def __init__(self):
        self.papers_dir = config.PAPERS_DIR
        self.temp_dir = config.TEMP_DIR

    def format_arxiv_id(self, arxiv_id: str) -> str:
        """Convert arxiv ID '2312.12345' -> '2312-12345'"""
        return arxiv_id.replace('.', '-')

    def get_paper_dir(self, arxiv_id: str) -> Path:
        """Get the directory for a paper."""
        formatted_id = self.format_arxiv_id(arxiv_id)
        return self.papers_dir / formatted_id

    def create_paper_structure(self, arxiv_id: str) -> Dict[str, Path]:
        """Create the directory structure for a paper."""
        paper_dir = self.get_paper_dir(arxiv_id)
        tex_dir = paper_dir / "tex"

        paper_dir.mkdir(parents=True, exist_ok=True)
        tex_dir.mkdir(exist_ok=True)

        return {
            'paper_dir': paper_dir,
            'tex_dir': tex_dir,
            'metadata_file': paper_dir / 'metadata.json',
            'references_file': paper_dir / 'references.json',
        }

    def save_metadata(self, arxiv_id: str, paper_data: Dict):
        """Save paper metadata in ISO format."""
        paths = self.create_paper_structure(arxiv_id)

        # format dates to ISO format
        published = paper_data.get('published', '')
        updated = paper_data.get('updated', '')

        # parse and convert to ISO format
        try:
            if isinstance(published, str):
                pub_date = datetime.fromisoformat(published.replace('Z', '+00:00'))
                published_iso = pub_date.date().isoformat()
            else:
                published_iso = str(published)
        except:
            published_iso = str(published)

        # get all revision dates from version_dates if available
        revised_dates = []

        metadata = {
            'title': paper_data.get('title', 'Unknown'),
            'authors': paper_data.get('authors', []),
            'submission_date': published_iso,
            'revised_dates': revised_dates,
            'categories': paper_data.get('categories', []),
            'abstract': paper_data.get('abstract', ''),
            'arxiv_id': arxiv_id,
            'versions': paper_data.get('versions', []),
            'comments': paper_data.get('comments', ''),
            'license': paper_data.get('license', ''),
        }

        with open(paths['metadata_file'], 'w', encoding='utf-8') as f:
            json.dump(metadata, f, indent=2, ensure_ascii=False)

        logger.info(f"Saved metadata for {arxiv_id}")

    def save_references(self, arxiv_id: str, ref_data: Dict):
        """
        Save references in required format with yyyymm-id keys.

        Expected format:
        {
            "1706-03762": {
                "paper_title": "...",
                "authors": [...],
                "submission_date": "2017-06-12",
                "semantic_scholar_id": "..."
            }
        }
        """
        paths = self.create_paper_structure(arxiv_id)

        references = {}

        if 'references' in ref_data:
            for ref in ref_data['references']:
                # try to extract arXiv ID from externalIds
                ref_arxiv_id = None

                if ref.get('externalIds'):
                    external_ids = ref['externalIds']
                    if 'ArXiv' in external_ids:
                        ref_arxiv_id = external_ids['ArXiv']

                # only include references that have arXiv IDs
                # otherwise skip
                if ref_arxiv_id:
                    formatted_ref_id = self.format_arxiv_id(ref_arxiv_id)

                    # extract authors, only get names
                    authors = []
                    if ref.get('authors'):
                        authors = [author.get('name', 'Unknown') for author in ref['authors']]

                    # parse submission date from year
                    submission_date = ''
                    if ref.get('year'):
                        submission_date = f"{ref['year']}-01-01"

                    references[formatted_ref_id] = {
                        'paper_title': ref.get('title', 'Unknown'),
                        'authors': authors,
                        'submission_date': submission_date,
                        'semantic_scholar_id': ref.get('paperId', '')
                    }

        with open(paths['references_file'], 'w', encoding='utf-8') as f:
            json.dump(references, f, indent=2, ensure_ascii=False)

        logger.info(f"Saved {len(references)} arXiv references for {arxiv_id}")

    def copy_source_files(self, arxiv_id: str, version: str, source_dir: Path):
        """
        Copy .tex files to tex folder and .bib files to paper folder.
        Delete temp directory after copying.
        """
        paths = self.create_paper_structure(arxiv_id)
        tex_dir = paths['tex_dir']
        paper_dir = paths['paper_dir']

        if not source_dir.exists():
            logger.warning(f"Source directory does not exist: {source_dir}")
            return

        tex_count = 0
        bib_count = 0

        for file_path in source_dir.rglob('*'):
            if file_path.is_file():
                file_ext = file_path.suffix.lower()

                if file_ext == '.tex':
                    # Copy .tex files to tex folder, maintaining structure
                    rel_path = file_path.relative_to(source_dir)
                    dest_path = tex_dir / version / rel_path
                    dest_path.parent.mkdir(parents=True, exist_ok=True)

                    try:
                        shutil.copy2(file_path, dest_path)
                        tex_count += 1
                    except Exception as e:
                        logger.debug(f"Could not copy {file_path.name}: {e}")

                elif file_ext == '.bib':
                    dest_path = tex_dir / version / file_path.name
                    dest_path.parent.mkdir(parents=True, exist_ok=True)

                    try:
                        shutil.copy2(file_path, dest_path)
                        bib_count += 1
                    except Exception as e:
                        logger.debug(f"Could not copy {file_path.name}: {e}")

        logger.info(f"Copied {tex_count} .tex files and {bib_count} .bib files for {arxiv_id}")

        # Delete temp directory if configured
        if config.DELETE_TEMP_AFTER_COPY:
            try:
                shutil.rmtree(source_dir)
                logger.debug(f"Deleted temp directory: {source_dir}")
            except Exception as e:
                logger.debug(f"Could not delete temp directory: {e}")


    def is_paper_complete(self, arxiv_id: str) -> bool:
        """Check if a paper has been fully processed."""
        paths = self.create_paper_structure(arxiv_id)

        # check if all required files exist
        has_metadata = paths['metadata_file'].exists()
        has_tex = paths['tex_dir'].exists() and any(paths['tex_dir'].rglob('*.tex'))
        has_references = paths['references_file'].exists()

        return has_metadata and has_tex and has_references
# Out:
# Writing lib/paper_organizer.py

# %%
# %%writefile lib/source_identifier.py
import logging
import time
import arxiv
from typing import List, Dict, Optional
import json
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'arxiv_harvester.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class ArxivHarvester:
    """Harvest metadata from arXiv using the arxiv Python API."""

    def __init__(self, id_ranges: List[tuple], checkpoint_interval: int = 10):
        """
        Initialize the harvester.
        ----------
        Params:
            id_ranges: List of (YYMM, start_id, end_id) tuples
                      e.g., [("2312", 15844, 99999), ("2401", 0, 3095)]
            checkpoint_interval: Save checkpoint every N batches
        """
        self.id_ranges = id_ranges
        self.checkpoint_interval = checkpoint_interval
        self.client = arxiv.Client(
            page_size=config.ARXIV_MAX_RESULTS,
            delay_seconds=config.ARXIV_DELAY,
            num_retries=config.MAX_RETRIES
        )
        self.checkpoint_file = config.DATA_DIR / 'harvest_checkpoint.json'
        self.failed_batches_file = config.DATA_DIR / 'failed_batches.json'

    def generate_arxiv_ids(self, yymm: str, start_id: int, end_id: int) -> List[str]:
        """
        Generate arXiv IDs for a given range.
        ----------
        Params:
            yymm: Year-month string (e.g., "2312")
            start_id: Starting ID number
            end_id: Ending ID number

        Returns:
            List of arXiv IDs (e.g., ["2312.15844", "2312.15845", ...])
        """
        return [f"{yymm}.{str(i).zfill(5)}" for i in range(start_id, end_id + 1)]

    def fetch_paper_batch(self, arxiv_ids: List[str], yymm: str) -> tuple[List[Dict], Optional[str]]:
        """
        Fetch metadata for a batch of arXiv IDs.
        ----------
        Params:
            arxiv_ids: List of arXiv IDs
            yymm: Year-month string for error tracking

        Returns:
            Tuple of (list of paper metadata dictionaries, error_type if failed)
        """
        papers = []
        error_type = None

        try:
            search = arxiv.Search(id_list=arxiv_ids)
            results = self.client.results(search)

            for paper in results:
                try:
                    paper_data = self._parse_paper(paper)
                    if paper_data:
                        papers.append(paper_data)
                except Exception as e:
                    logger.error(f"Error parsing paper: {e}")
                    continue

        except Exception as e:
            error_msg = str(e).lower()
            if '429' in error_msg or 'rate limit' in error_msg or 'too many requests' in error_msg:
                error_type = '429_rate_limit'
                logger.error(f"Rate limit error (429): {e}")
            else:
                error_type = 'other_error'
                logger.error(f"Error fetching batch: {e}")

        return papers, error_type

    def _parse_paper(self, paper: arxiv.Result) -> Optional[Dict]:
        """
        Parse an arxiv.Result object into our metadata format.
        ----------
        Params:
            paper: arxiv.Result object

        Returns:
            Dictionary with paper metadata
        """
        try:
            # Extract base arXiv ID (without version)
            arxiv_id = paper.entry_id.split('/')[-1].split('v')[0]

            # Get version from entry_id - the API returns the latest version
            entry_with_version = paper.entry_id.split('/')[-1]
            if 'v' in entry_with_version:
                latest_version = int(entry_with_version.split('v')[-1])
                versions = [f"{arxiv_id}v{i}" for i in range(1, latest_version + 1)]
            else:
                versions = [f"{arxiv_id}v1"]

            # Format dates
            published = paper.published.date().isoformat()
            updated = paper.updated.date().isoformat()

            # Extract authors
            authors = [author.name for author in paper.authors]

            # Extract categories
            categories = [paper.primary_category] + paper.categories
            categories = list(set(categories))  # Remove duplicates

            paper_data = {
                'arxiv_id': arxiv_id,
                'title': paper.title.strip(),
                'authors': authors,
                'categories': categories,
                'abstract': paper.summary.strip().replace('\n', ' '),
                'published': published,
                'updated': updated,
                'comments': paper.comment if paper.comment else '',
                'license': paper.journal_ref if paper.journal_ref else '',
                'versions': versions,
                'pdf_url': paper.pdf_url,
                'entry_id': paper.entry_id
            }

            return paper_data

        except Exception as e:
            logger.error(f"Error parsing paper: {e}")
            return None

    def harvest_all_papers(self) -> List[Dict]:
        """
        Harvest all papers across the specified ID ranges and Date ranges.

        Returns:
            List of paper metadata dictionaries
        """

        all_papers = []
        processed_ranges = {}

        # Process each range
        for yymm, start_id, end_id in self.id_ranges:
            range_key = f"{yymm}_{start_id}_{end_id}"

            logger.info(f"Processing range: {yymm}.{start_id} to {yymm}.{end_id}")

            # Generate all IDs
            all_ids = self.generate_arxiv_ids(yymm, start_id, end_id)
            logger.info(f"Generated {len(all_ids)} potential IDs")

            # Split into batches
            batch_size = config.ARXIV_BATCH_SIZE
            batches = [all_ids[i:min(i + batch_size, len(all_ids))] for i in range(0, len(all_ids), batch_size)]

            # Resume from last batch if exists
            start_batch = 0

            papers_in_range = []
            consecutive_no_paper_count = 0

            # Process batches sequentially (to respect rate limits)
            for i in range(start_batch, len(batches)):
                batch = batches[i]
                logger.info(f"Batch {i+1}/{len(batches)}: fetching {len(batch)} IDs")

                papers, error = self.fetch_paper_batch(batch, yymm)

                if papers:
                    papers_in_range.extend(papers)
                    all_papers.extend(papers)
                    consecutive_no_paper_count = 0
                    logger.info(f"Found {len(papers)} papers (range: {len(papers_in_range)}, total: {len(all_papers)})")
                else:
                    consecutive_no_paper_count += 1
                    logger.info(f"No papers found in this batch (consecutive: {consecutive_no_paper_count})")

                    # If too many consecutive empty batches, assume no more papers
                    if consecutive_no_paper_count >= 2:
                        logger.info("No more papers found in recent batches, stopping early for this range.")
                        break

                # Rate limiting
                time.sleep(config.ARXIV_DELAY)

            # Mark range as complete
            logger.info(f"Completed {yymm}: found {len(papers_in_range)} papers\n")
            processed_ranges[range_key] = True

        logger.info(f"="*80)
        logger.info(f"Harvesting complete! Total papers: {len(all_papers)}")
        logger.info(f"="*80)

        return all_papers
# Out:
# Writing lib/source_identifier.py

# %%
# %%writefile lib/reference_extractor.py
import requests
import logging
import json
import time
from pathlib import Path
from typing import Dict, Optional
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'references.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class ReferenceExtractor:
    """Extract reference information using Semantic Scholar API."""

    def __init__(self, stats_tracker=None):
        self.api_base = config.SEMANTIC_SCHOLAR_API_BASE
        self.max_retries = config.MAX_RETRIES
        self.retry_delay = config.RETRY_DELAY
        self.stats = stats_tracker

    def fetch_references(self, arxiv_id: str) -> Optional[Dict]:
        """
        Fetch reference information for a paper from Semantic Scholar.
        --------
        Params:
            arxiv_id: arXiv identifier of the paper

        Returns:
            Dictionary with reference data or None if not found/error
        """
        url = f"{self.api_base}/paper/arXiv:{arxiv_id}"
        # add key to headers
        headers = {
            'x-api-key': config.SEMANTIC_KEY_API
        }
        params = {
            'fields': config.SEMANTIC_SCHOLAR_FIELDS
        }

        for attempt in range(self.max_retries):
            try:
                logger.info(f"Fetching references for arXiv:{arxiv_id} (attempt {attempt + 1})")

                response = requests.get(
                    url,
                    headers=headers,
                    params=params,
                    timeout=30
                )

                if response.status_code == 200:
                    data = response.json()
                    logger.info(f"Successfully fetched references for {arxiv_id}")
                    return data

                elif response.status_code == 404:
                    logger.warning(f"Paper not found in Semantic Scholar: {arxiv_id}")
                    if self.stats:
                        self.stats.record_error("Reference not found (404)")
                    return None

                elif response.status_code == 429:
                    wait_time = self.retry_delay
                    logger.warning(f"Rate limited. Waiting {wait_time}s...")
                    time.sleep(wait_time)
                    continue

                else:
                    logger.error(f"Error {response.status_code}: {response.text[:200]}")
                    if attempt < self.max_retries - 1:
                        time.sleep(self.retry_delay)
                        continue
                    if self.stats:
                        self.stats.record_error(f"HTTP {response.status_code}")
                    return None

            except requests.exceptions.RequestException as e:
                logger.error(f"Request error for {arxiv_id}: {e}")
                if attempt < self.max_retries - 1:
                    time.sleep(self.retry_delay)
                    continue
                if self.stats:
                    self.stats.record_error(f"Request error: {type(e).__name__}")
                return None

        return None
# Out:
# Writing lib/reference_extractor.py

# %%
# %%writefile lib/source_downloader.py
import tarfile
import gzip
import logging
import shutil
from pathlib import Path
from typing import List, Optional, Tuple
import config
import requests

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'downloader.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class SourceDownloader:
    """Download and extract arXiv paper sources with figure removal."""

    def __init__(self, stats_tracker=None, paper_organizer=None):
        self.temp_dir = config.TEMP_DIR
        self.figure_extensions = config.FIGURE_EXTENSIONS
        self.stats = stats_tracker
        self.organizer = paper_organizer

    def download_paper_source(self, arxiv_id: str, version: str) -> Optional[Path]:
        """
        Download source files for a specific paper version.
        --------
        Params:
            arxiv_id: arXiv identifier (e.g., "2312.15844")
            version: Version string (e.g., "2312.15844v1")

        Returns:
            Path to the downloaded .tar.gz file, or None on failure.
        """
        try:
            # Create temporary directory for this version
            version_temp_dir = self.temp_dir / arxiv_id / version
            tar_path = version_temp_dir / f"{version}.tar.gz"

            logger.info(f"Downloading source for {version}")
            version_temp_dir.mkdir(parents=True, exist_ok=True)

            # Download source for the specific version
            # Construct the source URL manually for the specific version
            source_url = f"https://arxiv.org/e-print/{version}"

            try:
                response = requests.get(source_url, timeout=30)
                response.raise_for_status()

                # Save the downloaded content
                with open(tar_path, 'wb') as f:
                    f.write(response.content)

                logger.info(f"Downloaded {version}")
                return tar_path

            except requests.exceptions.RequestException as e:
                logger.error(f"Error downloading from {source_url}: {e}")
                if self.stats:
                    self.stats.record_error(f"Download request error: {type(e).__name__}")
                return None

        except StopIteration:
            logger.warning(f"Paper {version} not found in arXiv")
            if self.stats:
                self.stats.record_error("Paper not found")
            return None
        except Exception as e:
            logger.error(f"Error downloading {version}: {e}")
            if self.stats:
                self.stats.record_error(f"Download error: {type(e).__name__}")
            return None

    def get_directory_size(self, directory: Path) -> int:
        """
        Get total size of directory in bytes.
        --------
        Params:
            directory: Path to the directory

        Returns:
            Total size in bytes
        """
        total_size = 0
        try:
            for path in directory.rglob('*'):
                if path.is_file():
                    total_size += path.stat().st_size
        except Exception as e:
            logger.error(f"Error calculating directory size: {e}")
        return total_size

    def remove_figures_from_directory(self, directory: Path) -> int:
        """
        Remove figure files from a directory.
        --------
        Params:
            directory: Path to the directory

        Returns:
            Number of figure files removed
        """
        removed_count = 0

        try:
            for file_path in directory.rglob('*'):
                if file_path.is_file():
                    if any(file_path.suffix.lower() == ext for ext in self.figure_extensions):
                        try:
                            file_path.unlink()
                            removed_count += 1
                            logger.debug(f"Removed figure: {file_path.name}")
                        except Exception as e:
                            logger.debug(f"Could not remove {file_path.name}: {e}")

            if removed_count > 0:
                logger.info(f"Removed {removed_count} figure files from {directory.name}")

        except Exception as e:
            logger.error(f"Error removing figures from {directory}: {e}")
            if self.stats:
                self.stats.record_error(f"Figure removal error: {type(e).__name__}")

        return removed_count

    def extract_nested_archives(self, directory: Path, depth: int = 0, max_depth: int = 3):
        """
        Recursively extract nested tar/tar.gz files.
        --------
        Params:
            directory: Directory to search for archives
            depth: Current recursion depth
            max_depth: Maximum recursion depth to prevent infinite loops

        Returns:
            None
        """
        if depth >= max_depth:
            logger.warning(f"Maximum extraction depth ({max_depth}) reached")
            return

        archive_extensions = ['.tar', '.tar.gz', '.tgz', '.gz']

        for file_path in list(directory.rglob('*')):
            if not file_path.is_file():
                continue

            # Check if it's an archive
            is_archive = any(
                str(file_path).endswith(ext) for ext in archive_extensions
            )

            if not is_archive:
                continue

            try:
                extract_subdir = file_path.parent / file_path.stem
                extract_subdir.mkdir(exist_ok=True)

                logger.debug(f"Extracting nested archive: {file_path.name}")

                # Try different extraction methods
                extracted = False

                # Method 1: tar.gz
                if str(file_path).endswith(('.tar.gz', '.tgz')):
                    try:
                        with tarfile.open(file_path, 'r:gz') as tar:
                            tar.extractall(path=extract_subdir)
                        extracted = True
                    except Exception:
                        pass

                # Method 2: plain tar
                if not extracted and str(file_path).endswith('.tar'):
                    try:
                        with tarfile.open(file_path, 'r:') as tar:
                            tar.extractall(path=extract_subdir)
                        extracted = True
                    except Exception:
                        pass

                # Method 3: plain gzip (decompress to single file)
                if not extracted and str(file_path).endswith('.gz'):
                    try:
                        output_file = extract_subdir.parent / file_path.stem
                        with gzip.open(file_path, 'rb') as f_in:
                            with open(output_file, 'wb') as f_out:
                                shutil.copyfileobj(f_in, f_out)
                        extracted = True
                        # If it's a .tar after decompression, extract it
                        if output_file.suffix == '.tar':
                            try:
                                with tarfile.open(output_file, 'r:') as tar:
                                    tar.extractall(path=extract_subdir)
                                output_file.unlink()
                            except Exception:
                                pass
                    except Exception:
                        pass

                if extracted:
                    # Remove the archive file after successful extraction
                    file_path.unlink()
                    logger.debug(f"Extracted and removed: {file_path.name}")

                    # Recursively extract nested archives
                    self.extract_nested_archives(extract_subdir, depth + 1, max_depth)
                else:
                    logger.debug(f"Could not extract: {file_path.name}")

            except Exception as e:
                logger.debug(f"Error extracting nested archive {file_path.name}: {e}")

    def extract_tarball(self, tar_path: Path, arxiv_id: str, version: str) -> Tuple[Optional[Path], int, int, int]:
        """
        Extract a .tar.gz file and remove figures.
        --------
        Params:
            tar_path: Path to the .tar.gz file
            arxiv_id: arXiv identifier
            version: Version string

        Returns:
            Tuple of (extract_dir, raw_size, extracted_size, figures_removed)
        """
        if not tar_path or not tar_path.exists():
            logger.warning(f"Tar file not found: {tar_path}")
            return None, 0, 0, 0

        extract_dir = self.temp_dir / arxiv_id / version / "extracted"
        try:
            extract_dir.mkdir(parents=True, exist_ok=True)

            # Get raw size
            raw_size = tar_path.stat().st_size

            logger.info(f"Extracting {tar_path.name} ({raw_size} bytes)")

            extracted = False

            # Try multiple extraction methods
            # Method 1: tar.gz
            try:
                with tarfile.open(tar_path, 'r:gz') as tar:
                    tar.extractall(path=extract_dir)
                extracted = True
                logger.debug("Extracted as tar.gz")
            except (tarfile.ReadError, gzip.BadGzipFile) as e:
                logger.debug(f"Not a gzipped tar: {e}")

            # Method 2: plain tar
            if not extracted:
                try:
                    with tarfile.open(tar_path, 'r:') as tar:
                        tar.extractall(path=extract_dir)
                    extracted = True
                    logger.debug("Extracted as plain tar")
                except tarfile.ReadError as e:
                    logger.debug(f"Not a plain tar: {e}")

            # Method 3: gzip only (decompress then check if tar)
            if not extracted:
                try:
                    decompressed_path = extract_dir / "decompressed.tar"
                    with gzip.open(tar_path, 'rb') as f_in:
                        with open(decompressed_path, 'wb') as f_out:
                            shutil.copyfileobj(f_in, f_out)

                    # Try to open as tar
                    try:
                        with tarfile.open(decompressed_path, 'r:') as tar:
                            tar.extractall(path=extract_dir)
                        decompressed_path.unlink()
                        extracted = True
                        logger.debug("Extracted as gzip -> tar")
                    except tarfile.ReadError:
                        # It's just a gzipped file, not a tar
                        extracted = True
                        logger.debug("Extracted as plain gzip")

                except (gzip.BadGzipFile, OSError) as e:
                    logger.debug(f"Not gzipped: {e}")

            # Method 4: Copy as-is (might be a single .tex file)
            if not extracted:
                logger.warning(f"Could not extract {tar_path.name}, copying as-is")
                shutil.copy(tar_path, extract_dir / tar_path.name)
                extracted = True

            # Extract any nested archives (tar/tar.gz inside)
            logger.debug("Checking for nested archives...")
            self.extract_nested_archives(extract_dir)

            # Remove figures
            figures_removed = self.remove_figures_from_directory(extract_dir)

            # Delete raw file if configured
            if config.DELETE_RAW_AFTER_EXTRACT:
                try:
                    tar_path.unlink()
                    logger.debug(f"Deleted raw file: {tar_path.name}")
                except Exception as e:
                    logger.debug(f"Could not delete raw file: {e}")

            # Get size after figure removal (only .tex and .bib files)
            extracted_size = 0
            tex_bib_files = []
            for file_path in extract_dir.rglob('*'):
                if file_path.is_file():
                    if file_path.suffix.lower() in ['.tex', '.bib', '.sty', '.cls', '.bst']:
                        extracted_size += file_path.stat().st_size
                        tex_bib_files.append(file_path.name)

            if tex_bib_files:
                logger.info(f"Found {len(tex_bib_files)} LaTeX files")
            else:
                logger.warning(f"No LaTeX files found in {version}")

            logger.info(f"Extracted {version}: {raw_size} -> {extracted_size} bytes ({figures_removed} figures removed)")

            return extract_dir, raw_size, extracted_size, figures_removed

        except Exception as e:
            logger.error(f"Error extracting {tar_path}: {e}")
            if self.stats:
                self.stats.record_error(f"Extraction error: {type(e).__name__}")
            return None, 0, 0, 0

    def download_and_extract_version(self, arxiv_id: str, version: str) -> bool:
        """
        Download and extract a single version.
        --------
        Params:
            arxiv_id: arXiv identifier
            version: Version string

        Returns:
            True on success, False on failure
        """
        try:
            # Download
            tar_path = self.download_paper_source(arxiv_id, version)

            if not tar_path:
                if self.stats:
                    self.stats.record_version(success=False)
                return False

            # Extract
            extract_dir, raw_size, extracted_size, figures_removed = self.extract_tarball(
                tar_path, arxiv_id, version
            )

            if extract_dir:
                # Copy extracted files to organized structure
                if self.organizer:
                    try:
                        self.organizer.copy_source_files(arxiv_id, version, extract_dir)
                        logger.info(f"Success: Organized {version}")
                    except Exception as e:
                        logger.error(f"Error organizing files: {e}")

                if self.stats:
                    self.stats.record_file_sizes(raw_size, extracted_size, figures_removed)
                    self.stats.record_version(success=True)

                # Clean up temp directory if configured
                if config.DELETE_TEMP_AFTER_COPY:
                    try:
                        shutil.rmtree(extract_dir)
                        logger.debug(f"Cleaned up temp dir for {version}")
                    except Exception as e:
                        logger.debug(f"Could not clean up temp: {e}")

                return True
            else:
                if self.stats:
                    self.stats.record_version(success=False)
                return False

        except Exception as e:
            logger.error(f"Error processing {version}: {e}")
            if self.stats:
                self.stats.record_error(f"Processing error: {type(e).__name__}")
                self.stats.record_version(success=False)
            return False
# Out:
# Writing lib/source_downloader.py

# %%
# %%writefile lib/metadata_updater.py
"""
Script to update metadata.json with actual file modification dates from .tex files
and remove papers that don't have any LaTeX source files.
"""

import json
import logging
from pathlib import Path
from datetime import datetime
from typing import Dict, List, Optional
import shutil
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'update_metadata.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class MetadataUpdater:
    """Update metadata.json files with actual file dates and clean up empty papers."""

    def __init__(self, papers_dir: Path):
        self.papers_dir = papers_dir
        self.stats = {
            'total_papers': 0,
            'updated_papers': 0,
            'deleted_papers': 0,
            'papers_without_tex': 0,
            'errors': 0
        }

    def get_tex_file_dates(self, tex_dir: Path) -> Dict[str, str]:
        """
        Get modification dates of .tex files in each version directory.

        Args:
            tex_dir: Path to the tex folder (contains v1/, v2/, etc.)

        Returns:
            Dictionary mapping version to date (e.g., {"v1": "2023-12-15", "v2": "2023-12-18"})
        """
        version_dates = {}

        # Find all version directories (v1, v2, v3, etc.)
        version_dirs = sorted([d for d in tex_dir.iterdir() if d.is_dir()])

        if not version_dirs:
            logger.debug(f"No version directories found in {tex_dir}")
            return version_dates

        for version_dir in version_dirs:
            version_name = version_dir.name  # e.g., "v1", "v2"

            # Find all .tex files in this version
            tex_files = list(version_dir.glob('*.tex'))

            if not tex_files:
                logger.debug(f"No .tex files in {version_dir}")
                continue

            # Get the latest modification time among all .tex files
            latest_mtime = max(f.stat().st_mtime for f in tex_files)

            # Convert to ISO date format
            date = datetime.fromtimestamp(latest_mtime).date().isoformat()
            version_dates[version_name] = date

            logger.debug(f"  {version_name}: {date} (from {len(tex_files)} .tex files)")

        return version_dates

    def update_metadata(self, paper_dir: Path) -> bool:
        """
        Update metadata.json with actual file dates.

        Args:
            paper_dir: Path to the paper directory

        Returns:
            True if paper has .tex files, False if should be deleted
        """
        metadata_file = paper_dir / 'metadata.json'
        tex_dir = paper_dir / 'tex'

        # Check if metadata exists
        if not metadata_file.exists():
            logger.warning(f"No metadata.json in {paper_dir.name}")
            return False

        # If there is no folder or files, return empty
        if not tex_dir.exists() or not any(tex_dir.iterdir()):
            logger.info(f"No tex directory or files in {paper_dir.name} - marking for deletion")
            return False

        # Get version dates from actual files
        version_dates = self.get_tex_file_dates(tex_dir)

        if not version_dates:
            logger.info(f"No .tex files found in {paper_dir.name} - marking for deletion")
            return False

        # Load metadata
        try:
            with open(metadata_file, 'r', encoding='utf-8') as f:
                metadata = json.load(f)
        except Exception as e:
            logger.error(f"Error loading metadata from {paper_dir.name}: {e}")
            self.stats['errors'] += 1
            return True  # Keep the paper even if we can't read metadata

        # Update revised_dates (all dates except v1)
        sorted_versions = sorted(version_dates.keys())
        print(sorted_versions)
        sorted_versions = sorted(version_dates.keys(), key=lambda x: (x[1:]))
        if len(sorted_versions) > 1:
            metadata['revised_dates'] = [version_dates[v] for v in sorted_versions[1:]]
        else:
            metadata['revised_dates'] = []

        # Save updated metadata
        try:
            with open(metadata_file, 'w', encoding='utf-8') as f:
                json.dump(metadata, f, indent=2, ensure_ascii=False)

            # Log changes if dates were updated
            logger.info(f"✓ Updated {paper_dir.name}:")
            logger.info(f"    Versions: {len(version_dates)}")
            logger.info(f"    Dates: {version_dates}")
            self.stats['updated_papers'] += 1

            return True

        except Exception as e:
            logger.error(f"Error saving metadata for {paper_dir.name}: {e}")
            self.stats['errors'] += 1
            return True  # Keep the paper even if we can't save

    def delete_paper(self, paper_dir: Path):
        """Delete a paper directory that has no .tex files."""
        try:
            shutil.rmtree(paper_dir)
            logger.info(f"✗ Deleted {paper_dir.name} (no .tex files)")
            self.stats['deleted_papers'] += 1
        except Exception as e:
            logger.error(f"Error deleting {paper_dir.name}: {e}")
            self.stats['errors'] += 1

    def process_all_papers(self, delete_empty: bool = True):
        """
        Process all papers in the papers directory.

        Args:
            delete_empty: If True, delete papers without .tex files
        """
        if not self.papers_dir.exists():
            logger.error(f"Papers directory not found: {self.papers_dir}")
            return

        # Get all paper directories
        paper_dirs = sorted([d for d in self.papers_dir.iterdir() if d.is_dir()])
        self.stats['total_papers'] = len(paper_dirs)

        logger.info("="*80)
        logger.info(f"Processing {len(paper_dirs)} papers")
        logger.info(f"Delete empty papers: {delete_empty}")
        logger.info("="*80)

        papers_to_delete = []

        for i, paper_dir in enumerate(paper_dirs, 1):
            logger.info(f"\n[{i}/{len(paper_dirs)}] Processing {paper_dir.name}")

            has_tex = self.update_metadata(paper_dir)

            if not has_tex:
                papers_to_delete.append(paper_dir)
                self.stats['papers_without_tex'] += 1

        # Delete papers without .tex files
        if delete_empty and papers_to_delete:
            logger.info(f"\n{'='*80}")
            logger.info(f"Deleting {len(papers_to_delete)} papers without .tex files")
            logger.info(f"{'='*80}")

            for paper_dir in papers_to_delete:
                self.delete_paper(paper_dir)
        elif papers_to_delete:
            logger.info(f"\n{'='*80}")
            logger.info(f"Found {len(papers_to_delete)} papers without .tex files (not deleted)")
            logger.info(f"{'='*80}")
            for paper_dir in papers_to_delete:
                logger.info(f"  - {paper_dir.name}")

    def print_summary(self):
        """Print summary statistics."""
        logger.info(f"\n{'='*80}")
        logger.info("SUMMARY")
        logger.info(f"{'='*80}")
        logger.info(f"Total papers processed:       {self.stats['total_papers']}")
        logger.info(f"Papers with updated dates:    {self.stats['updated_papers']}")
        logger.info(f"Papers without .tex files:    {self.stats['papers_without_tex']}")
        logger.info(f"Papers deleted:               {self.stats['deleted_papers']}")
        logger.info(f"Errors:                       {self.stats['errors']}")
        logger.info(f"{'='*80}")

        remaining_papers = self.stats['total_papers'] - self.stats['deleted_papers']
        logger.info(f"\nRemaining papers: {remaining_papers}")

        if self.stats['deleted_papers'] > 0:
            deletion_rate = (self.stats['deleted_papers'] / self.stats['total_papers']) * 100
            logger.info(f"Deletion rate: {deletion_rate:.1f}%")
# Out:
# Writing lib/metadata_updater.py

# %%
# %%writefile main.py
import logging
import json
import time
import threading
import concurrent.futures

from lib.source_identifier import ArxivHarvester
from lib.source_downloader import SourceDownloader
from lib.reference_extractor import ReferenceExtractor
from lib.statistics_tracker import StatisticsTracker
from lib.paper_organizer import PaperOrganizer
from lib.metadata_updater import MetadataUpdater
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'main.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


def memory_monitor(stats, stop_event):
    """Background thread to monitor memory usage."""
    while not stop_event.is_set():
        stats.sample_memory()
        time.sleep(5)


def download_paper_sources(paper, downloader, organizer, stats):
    """
    Download all versions of a single paper.
    ----------
    Params
        paper: Paper metadata dictionary
        downloader: SourceDownloader instance
        organizer: PaperOrganizer instance
        stats: StatisticsTracker instance

    Returns:
        Tuple of (arxiv_id, success, processing_time)
    """
    arxiv_id = paper['arxiv_id']
    versions = paper['versions']

    start_time = time.time()

    try:
        logger.info(f"Downloading {arxiv_id} ({len(versions)} versions)")

        # Save metadata
        organizer.save_metadata(arxiv_id, paper)

        # Download and extract all versions
        for version in versions:
            success = downloader.download_and_extract_version(arxiv_id, version)
            if not success:
                logger.warning(f"Warning: Failed to download version {version['version']} of {arxiv_id}")

        processing_time = time.time() - start_time
        logger.info(f"Success: Downloaded {arxiv_id} in {processing_time:.2f}s")

        return arxiv_id, True, processing_time

    except Exception as e:
        logger.error(f"Error: Error downloading {arxiv_id}: {e}")
        import traceback
        traceback.print_exc()

        processing_time = time.time() - start_time
        stats.record_error(f"Download error: {type(e).__name__}")

        return arxiv_id, False, processing_time


def fetch_paper_references(arxiv_id, ref_extractor, organizer, stats):
    """
    Fetch references for a single paper.
    ----------
    Params
        arxiv_id: arXiv ID
        ref_extractor: ReferenceExtractor instance
        organizer: PaperOrganizer instance
        stats: StatisticsTracker instance

    Returns:
        Tuple of (arxiv_id, success, ref_count)
    """
    try:
        logger.info(f"Fetching references for {arxiv_id}")

        ref_data = ref_extractor.fetch_references(arxiv_id)

        if ref_data:
            organizer.save_references(arxiv_id, ref_data)
            ref_count = len(ref_data.get('references', []))
            stats.record_references(ref_count)
            logger.info(f"Success: Found {ref_count} references for {arxiv_id}")
            return arxiv_id, True, ref_count
        else:
            stats.record_references(0)
            logger.warning(f"Error: No references found for {arxiv_id}")
            return arxiv_id, False, 0

    except Exception as e:
        logger.error(f"Error: Error fetching references for {arxiv_id}: {e}")
        stats.record_error(f"Reference error: {type(e).__name__}")
        stats.record_references(0)
        return arxiv_id, False, 0


def main():
    """Main execution pipeline with optimized speed."""
    stats = StatisticsTracker()
    organizer = PaperOrganizer()
    stats.start()

    stop_monitoring = threading.Event()
    monitor_thread = threading.Thread(target=memory_monitor, args=(stats, stop_monitoring))
    monitor_thread.start()

    try:
        logger.info("=" * 80)
        logger.info("Starting arXiv Data Scraping")
        logger.info("=" * 80)

        # Step 1: Harvest metadata using arXiv API
        stats.start_phase("Metadata Harvesting (arXiv API)")
        logger.info("\n--- STEP 1: Harvesting metadata via arXiv API ---")

        paper_list_file = config.DATA_DIR / 'paper_list.json'

        if paper_list_file.exists():
            logger.info(f"Loading cached paper list from {paper_list_file}")
            with open(paper_list_file, 'r', encoding='utf-8') as f:
                papers = json.load(f)
            logger.info(f"Loaded {len(papers)} papers from cache")
        else:
            harvester = ArxivHarvester(
                id_ranges=config.ARXIV_ID_RANGES,
                checkpoint_interval=10  # Save every 10 batches
            )

            # Harvest papers with checkpoint support
            papers = harvester.harvest_all_papers()

            # Record identified papers
            for _ in papers:
                stats.record_paper_identified()

        # Save paper list
        with open(paper_list_file, 'w', encoding='utf-8') as f:
            json.dump(papers, f, indent=2, default=str)

        logger.info(f"Saved {len(papers)} papers to {paper_list_file}")

        stats.end_phase()
        stats.save_checkpoint()

        if not papers:
            logger.warning("No papers found. Exiting.")
            return

        logger.info(f"\n{'='*80}")
        logger.info(f"Found {len(papers)} papers to process")
        logger.info(f"{'='*80}\n")

        # Filter out already complete papers
        papers_to_process = []
        for paper in papers:
            arxiv_id = paper['arxiv_id']
            if organizer.is_paper_complete(arxiv_id):
                logger.info(f"Success: {arxiv_id} already complete, skipping")
                stats.record_paper_success(0)
            else:
                papers_to_process.append(paper)

        logger.info(f"\n{len(papers_to_process)} papers need processing\n")

        if not papers_to_process:
            logger.info("All papers already processed!")
            return

        # Step 2: Download all source papers concurrently
        stats.start_phase("Source Download (Parallel)")
        logger.info("\n--- STEP 2: Downloading all source papers (parallel) ---")
        logger.info(f"Max concurrent downloads: {config.PAPER_DOWNLOAD_BATCH_SIZE}")

        downloader = SourceDownloader(stats_tracker=stats, paper_organizer=organizer)

        download_results = {}
        downloaded_papers = []
        failed_downloads = []

        with concurrent.futures.ThreadPoolExecutor(max_workers=config.PAPER_DOWNLOAD_BATCH_SIZE) as executor:
            # Submit all download tasks
            future_to_paper = {
                executor.submit(download_paper_sources, paper, downloader, organizer, stats): paper
                for paper in papers_to_process
            }

            completed = 0
            total = len(papers_to_process)

            # Process completed downloads
            for future in concurrent.futures.as_completed(future_to_paper):
                paper = future_to_paper[future]
                completed += 1

                try:
                    arxiv_id, success, processing_time = future.result()
                    download_results[arxiv_id] = success

                    if success:
                        downloaded_papers.append(arxiv_id)
                        stats.record_paper_attempt()
                        logger.info(f"[{completed}/{total}] Success: {arxiv_id} - {processing_time:.2f}s")
                    else:
                        failed_downloads.append(arxiv_id)
                        stats.record_paper_attempt()
                        stats.record_paper_failure()
                        logger.warning(f"[{completed}/{total}] ✗ {arxiv_id} - Failed")

                    # Save checkpoint periodically
                    if completed % config.STATS_SAVE_INTERVAL == 0:
                        stats.save_checkpoint()
                        logger.info(f"--- Checkpoint: {completed}/{total} downloads completed ---")

                except Exception as e:
                    logger.error(f"[{completed}/{total}] ✗ Exception processing {paper['arxiv_id']}: {e}")
                    failed_downloads.append(paper['arxiv_id'])
                    stats.record_paper_attempt()
                    stats.record_paper_failure()

        stats.end_phase()
        stats.save_checkpoint()

        logger.info(f"\n{'='*80}")
        logger.info(f"Download phase completed!")
        logger.info(f"  Successful: {len(downloaded_papers)}/{total}")
        logger.info(f"  Failed: {len(failed_downloads)}/{total}")
        logger.info(f"{'='*80}\n")

        # Step 3: Fetch references for all downloaded papers
        stats.start_phase("Reference Extraction (Parallel)")
        logger.info("\n--- STEP 3: Fetching references for all papers (parallel) ---")
        logger.info(f"Max concurrent API calls: {config.REFERENCE_BATCH_SIZE}")

        ref_extractor = ReferenceExtractor(stats_tracker=stats)

        reference_results = {}
        papers_with_refs = []
        papers_without_refs = []

        with concurrent.futures.ThreadPoolExecutor(max_workers=config.REFERENCE_BATCH_SIZE) as executor:
            # Submit all reference fetching tasks
            future_to_arxiv_id = {
                executor.submit(fetch_paper_references, arxiv_id, ref_extractor, organizer, stats): arxiv_id
                for arxiv_id in downloaded_papers
            }

            completed = 0
            total = len(downloaded_papers)

            # Process completed reference fetches
            for future in concurrent.futures.as_completed(future_to_arxiv_id):
                arxiv_id = future_to_arxiv_id[future]
                completed += 1

                try:
                    arxiv_id_result, success, ref_count = future.result()
                    reference_results[arxiv_id_result] = (success, ref_count)

                    if success:
                        papers_with_refs.append(arxiv_id_result)
                        logger.info(f"[{completed}/{total}] Success: {arxiv_id_result} - {ref_count} refs")
                    else:
                        papers_without_refs.append(arxiv_id_result)
                        logger.warning(f"[{completed}/{total}] ✗ {arxiv_id_result} - No refs")

                    # Save checkpoint periodically
                    if completed % config.STATS_SAVE_INTERVAL == 0:
                        stats.save_checkpoint()
                        logger.info(f"--- Checkpoint: {completed}/{total} references fetched ---")

                    # Rate limiting - delay between API calls
                    time.sleep(config.REQUEST_DELAY)

                except Exception as e:
                    logger.error(f"[{completed}/{total}] ✗ Exception fetching refs for {arxiv_id}: {e}")
                    papers_without_refs.append(arxiv_id)

        stats.end_phase()
        stats.save_checkpoint()

        logger.info(f"\n{'='*80}")
        logger.info(f"Reference extraction completed!")
        logger.info(f"  With references: {len(papers_with_refs)}/{total}")
        logger.info(f"  Without references: {len(papers_without_refs)}/{total}")
        logger.info(f"{'='*80}\n")

        # Mark all successfully processed papers as complete
        for arxiv_id in downloaded_papers:
            if download_results.get(arxiv_id):
                # Mark as complete regardless of reference success
                # some papers legitimately have no references in Semantic Scholar
                # because they are very new or not indexed
                stats.record_paper_success(0)  # Time already recorded during download

        # Update metadata for all papers
        updater = MetadataUpdater(papers_dir=config.PAPERS_DIR)
        updater.process_all_papers(delete_empty=False)

        # Cleanup temp directory
        logger.info("\n--- Cleaning up temporary files ---")
        try:
            if config.TEMP_DIR.exists():
                import shutil
                shutil.rmtree(config.TEMP_DIR)
                config.TEMP_DIR.mkdir(parents=True, exist_ok=True)
                logger.info("Success: Cleaned up temp directory")
        except Exception as e:
            logger.warning(f"Could not clean temp directory: {e}")

        logger.info("\n" + "=" * 80)
        logger.info("Pipeline completed!")
        logger.info("=" * 80)
        logger.info(f"\nSummary:")
        logger.info(f"  Total papers: {len(papers)}")
        logger.info(f"  Already complete: {len(papers) - len(papers_to_process)}")
        logger.info(f"  Downloaded: {len(downloaded_papers)}")
        logger.info(f"  Failed downloads: {len(failed_downloads)}")
        logger.info(f"  With references: {len(papers_with_refs)}")
        logger.info(f"  Without references: {len(papers_without_refs)}")

    finally:
        stop_monitoring.set()
        monitor_thread.join()
        stats.end()
        stats.save_to_file(config.DATA_DIR / 'statistics_final.json')
        stats.save_checkpoint()
        stats.print_summary()
        logger.info(f"\nStatistics: {config.DATA_DIR / 'statistics_final.json'}")
        logger.info(f"Papers: {config.PAPERS_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Writing main.py

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-11-15 11:16:44,235 - INFO - [81/496] Success: 2312.15894 - 21 refs
# 2025-11-15 11:16:44,441 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:45,698 - INFO - Fetching references for arXiv:2312.16103 (attempt 6)
# 2025-11-15 11:16:46,028 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:47,235 - INFO - [82/496] Success: 2312.15868 - 0 refs
# 2025-11-15 11:16:47,441 - INFO - Fetching references for arXiv:2312.16143 (attempt 2)
# 2025-11-15 11:16:47,694 - INFO - Successfully fetched references for 2312.16143
# 2025-11-15 11:16:47,694 - INFO - Saved 0 arXiv references for 2312.16143
# 2025-11-15 11:16:47,695 - INFO - Success: Found 0 references for 2312.16143
# 2025-11-15 11:16:47,695 - INFO - Fetching references for 2312.16077
# 2025-11-15 11:16:47,695 - INFO - Fetching references for arXiv:2312.16077 (attempt 1)
# 2025-11-15 11:16:48,051 - INFO - Successfully fetched references for 2312.16077
# 2025-11-15 11:16:48,052 - INFO - Saved 6 arXiv references for 2312.16077
# 2025-11-15 11:16:48,052 - INFO - Success: Found 16 references for 2312.16077
# 2025-11-15 11:16:48,052 - INFO - Fetching references for 2312.16080
# 2025-11-15 11:16:48,053 - INFO - Fetching references for arXiv:2312.16080 (attempt 1)
# 2025-11-15 11:16:48,189 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:49,028 - INFO - Fetching references for arXiv:2312.16103 (attempt 7)
# 2025-11-15 11:16:49,660 - INFO - Successfully fetched references for 2312.16103
# 2025-11-15 11:16:49,661 - INFO - Saved 21 arXiv references for 2312.16103
# 2025-11-15 11:16:49,661 - INFO - Success: Found 32 references for 2312.16103
# 2025-11-15 11:16:49,661 - INFO - Fetching references for 2312.16049
# 2025-11-15 11:16:49,661 - INFO - Fetching references for arXiv:2312.16049 (attempt 1)
# 2025-11-15 11:16:50,077 - INFO - Successfully fetched references for 2312.16049
# 2025-11-15 11:16:50,079 - INFO - Saved 30 arXiv references for 2312.16049
# 2025-11-15 11:16:50,079 - INFO - Success: Found 38 references for 2312.16049
# 2025-11-15 11:16:50,079 - INFO - Fetching references for 2312.16091
# 2025-11-15 11:16:50,079 - INFO - Fetching references for arXiv:2312.16091 (attempt 1)
# 2025-11-15 11:16:50,236 - INFO - [83/496] Success: 2312.15913 - 7 refs
# 2025-11-15 11:16:50,698 - INFO - Successfully fetched references for 2312.16091
# 2025-11-15 11:16:50,700 - INFO - Saved 117 arXiv references for 2312.16091
# 2025-11-15 11:16:50,700 - INFO - Success: Found 156 references for 2312.16091
# 2025-11-15 11:16:50,701 - INFO - Fetching references for 2312.16060
# 2025-11-15 11:16:50,701 - INFO - Fetching references for arXiv:2312.16060 (attempt 1)
# 2025-11-15 11:16:51,101 - INFO - Successfully fetched references for 2312.16060
# 2025-11-15 11:16:51,102 - INFO - Saved 0 arXiv references for 2312.16060
# 2025-11-15 11:16:51,102 - INFO - Success: Found 16 references for 2312.16060
# 2025-11-15 11:16:51,103 - INFO - Fetching references for 2312.16139
# 2025-11-15 11:16:51,103 - INFO - Fetching references for arXiv:2312.16139 (attempt 1)
# 2025-11-15 11:16:51,189 - INFO - Fetching references for arXiv:2312.16080 (attempt 2)
# 2025-11-15 11:16:51,239 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:51,342 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:53,236 - INFO - [84/496] Success: 2312.15859 - 0 refs
# 2025-11-15 11:16:54,239 - INFO - Fetching references for arXiv:2312.16139 (attempt 2)
# 2025-11-15 11:16:54,342 - INFO - Fetching references for arXiv:2312.16080 (attempt 3)
# 2025-11-15 11:16:54,449 - INFO - Successfully fetched references for 2312.16139
# 2025-11-15 11:16:54,450 - INFO - Saved 0 arXiv references for 2312.16139
# 2025-11-15 11:16:54,450 - INFO - Success: Found 0 references for 2312.16139
# 2025-11-15 11:16:54,450 - INFO - Fetching references for 2312.16079
# 2025-11-15 11:16:54,450 - INFO - Fetching references for arXiv:2312.16079 (attempt 1)
# 2025-11-15 11:16:54,941 - INFO - Successfully fetched references for 2312.16080
# 2025-11-15 11:16:54,943 - INFO - Successfully fetched references for 2312.16079
# 2025-11-15 11:16:54,944 - INFO - Saved 3 arXiv references for 2312.16080
# 2025-11-15 11:16:54,944 - INFO - Success: Found 106 references for 2312.16080
# 2025-11-15 11:16:54,944 - INFO - Saved 0 arXiv references for 2312.16079
# 2025-11-15 11:16:54,945 - INFO - Fetching references for 2312.16097
# 2025-11-15 11:16:54,945 - INFO - Success: Found 48 references for 2312.16079
# 2025-11-15 11:16:54,945 - INFO - Fetching references for 2312.16067
# 2025-11-15 11:16:54,945 - INFO - Fetching references for arXiv:2312.16067 (attempt 1)
# 2025-11-15 11:16:54,945 - INFO - Fetching references for arXiv:2312.16097 (attempt 1)
# 2025-11-15 11:16:55,233 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:55,528 - INFO - Successfully fetched references for 2312.16067
# 2025-11-15 11:16:55,529 - INFO - Saved 4 arXiv references for 2312.16067
# 2025-11-15 11:16:55,529 - INFO - Success: Found 66 references for 2312.16067
# 2025-11-15 11:16:55,530 - INFO - Fetching references for 2312.16117
# 2025-11-15 11:16:55,530 - INFO - Fetching references for arXiv:2312.16117 (attempt 1)
# 2025-11-15 11:16:55,786 - INFO - Successfully fetched references for 2312.16117
# 2025-11-15 11:16:55,787 - INFO - Saved 0 arXiv references for 2312.16117
# 2025-11-15 11:16:55,787 - INFO - Success: Found 1 references for 2312.16117
# 2025-11-15 11:16:55,787 - INFO - Fetching references for 2312.16051
# 2025-11-15 11:16:55,787 - INFO - Fetching references for arXiv:2312.16051 (attempt 1)
# 2025-11-15 11:16:56,102 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:56,236 - INFO - [85/496] Success: 2312.15933 - 32 refs
# 2025-11-15 11:16:58,234 - INFO - Fetching references for arXiv:2312.16097 (attempt 2)
# 2025-11-15 11:16:58,438 - INFO - Successfully fetched references for 2312.16097
# 2025-11-15 11:16:58,438 - INFO - Saved 1 arXiv references for 2312.16097
# 2025-11-15 11:16:58,438 - INFO - Success: Found 11 references for 2312.16097
# 2025-11-15 11:16:58,439 - INFO - Fetching references for 2312.16131
# 2025-11-15 11:16:58,439 - INFO - Fetching references for arXiv:2312.16131 (attempt 1)
# 2025-11-15 11:16:58,760 - INFO - Successfully fetched references for 2312.16131
# 2025-11-15 11:16:58,761 - INFO - Saved 16 arXiv references for 2312.16131
# 2025-11-15 11:16:58,761 - INFO - Success: Found 40 references for 2312.16131
# 2025-11-15 11:16:58,761 - INFO - Fetching references for 2312.16107
# 2025-11-15 11:16:58,761 - INFO - Fetching references for arXiv:2312.16107 (attempt 1)
# 2025-11-15 11:16:59,102 - INFO - Fetching references for arXiv:2312.16051 (attempt 2)
# 2025-11-15 11:16:59,154 - INFO - Successfully fetched references for 2312.16107
# 2025-11-15 11:16:59,155 - INFO - Saved 7 arXiv references for 2312.16107
# 2025-11-15 11:16:59,155 - INFO - Success: Found 41 references for 2312.16107
# 2025-11-15 11:16:59,156 - INFO - Fetching references for 2312.16132
# 2025-11-15 11:16:59,156 - INFO - Fetching references for arXiv:2312.16132 (attempt 1)
# 2025-11-15 11:16:59,237 - INFO - [86/496] Success: 2312.15923 - 40 refs
# 2025-11-15 11:16:59,292 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:16:59,700 - INFO - Successfully fetched references for 2312.16051
# 2025-11-15 11:16:59,702 - INFO - Saved 69 arXiv references for 2312.16051
# 2025-11-15 11:16:59,703 - INFO - Success: Found 103 references for 2312.16051
# 2025-11-15 11:16:59,703 - INFO - Fetching references for 2312.16121
# 2025-11-15 11:16:59,703 - INFO - Fetching references for arXiv:2312.16121 (attempt 1)
# 2025-11-15 11:17:00,185 - INFO - Successfully fetched references for 2312.16121
# 2025-11-15 11:17:00,186 - INFO - Saved 5 arXiv references for 2312.16121
# 2025-11-15 11:17:00,187 - INFO - Success: Found 40 references for 2312.16121
# 2025-11-15 11:17:00,187 - INFO - Fetching references for 2312.16056
# 2025-11-15 11:17:00,187 - INFO - Fetching references for arXiv:2312.16056 (attempt 1)
# 2025-11-15 11:17:00,684 - INFO - Successfully fetched references for 2312.16056
# 2025-11-15 11:17:00,685 - INFO - Saved 40 arXiv references for 2312.16056
# 2025-11-15 11:17:00,685 - INFO - Success: Found 47 references for 2312.16056
# 2025-11-15 11:17:00,685 - INFO - Fetching references for 2312.16054
# 2025-11-15 11:17:00,685 - INFO - Fetching references for arXiv:2312.16054 (attempt 1)
# 2025-11-15 11:17:00,898 - INFO - Successfully fetched references for 2312.16054
# 2025-11-15 11:17:00,899 - INFO - Saved 7 arXiv references for 2312.16054
# 2025-11-15 11:17:00,899 - INFO - Success: Found 22 references for 2312.16054
# 2025-11-15 11:17:00,899 - INFO - Fetching references for 2312.16065
# 2025-11-15 11:17:00,899 - INFO - Fetching references for arXiv:2312.16065 (attempt 1)
# 2025-11-15 11:17:01,044 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:02,237 - INFO - [87/496] Success: 2312.15845 - 28 refs
# 2025-11-15 11:17:02,293 - INFO - Fetching references for arXiv:2312.16132 (attempt 2)
# 2025-11-15 11:17:02,435 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:04,045 - INFO - Fetching references for arXiv:2312.16065 (attempt 2)
# 2025-11-15 11:17:04,184 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:05,238 - INFO - [88/496] Success: 2312.15881 - 55 refs
# 2025-11-15 11:17:05,436 - INFO - Fetching references for arXiv:2312.16132 (attempt 3)
# 2025-11-15 11:17:05,738 - INFO - Successfully fetched references for 2312.16132
# 2025-11-15 11:17:05,740 - INFO - Saved 26 arXiv references for 2312.16132
# 2025-11-15 11:17:05,740 - INFO - Success: Found 33 references for 2312.16132
# 2025-11-15 11:17:05,740 - INFO - Fetching references for 2312.16072
# 2025-11-15 11:17:05,740 - INFO - Fetching references for arXiv:2312.16072 (attempt 1)
# 2025-11-15 11:17:06,086 - INFO - Successfully fetched references for 2312.16072
# 2025-11-15 11:17:06,087 - INFO - Saved 3 arXiv references for 2312.16072
# 2025-11-15 11:17:06,087 - INFO - Success: Found 17 references for 2312.16072
# 2025-11-15 11:17:06,087 - INFO - Fetching references for 2312.16046
# 2025-11-15 11:17:06,087 - INFO - Fetching references for arXiv:2312.16046 (attempt 1)
# 2025-11-15 11:17:06,392 - INFO - Successfully fetched references for 2312.16046
# 2025-11-15 11:17:06,393 - INFO - Saved 18 arXiv references for 2312.16046
# 2025-11-15 11:17:06,393 - INFO - Success: Found 39 references for 2312.16046
# 2025-11-15 11:17:06,394 - INFO - Fetching references for 2312.16076
# 2025-11-15 11:17:06,394 - INFO - Fetching references for arXiv:2312.16076 (attempt 1)
# 2025-11-15 11:17:06,535 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:07,185 - INFO - Fetching references for arXiv:2312.16065 (attempt 3)
# 2025-11-15 11:17:07,670 - INFO - Successfully fetched references for 2312.16065
# 2025-11-15 11:17:07,671 - INFO - Saved 19 arXiv references for 2312.16065
# 2025-11-15 11:17:07,672 - INFO - Success: Found 41 references for 2312.16065
# 2025-11-15 11:17:07,672 - INFO - Fetching references for 2312.16094
# 2025-11-15 11:17:07,672 - INFO - Fetching references for arXiv:2312.16094 (attempt 1)
# 2025-11-15 11:17:07,915 - INFO - Successfully fetched references for 2312.16094
# 2025-11-15 11:17:07,916 - INFO - Saved 5 arXiv references for 2312.16094
# 2025-11-15 11:17:07,916 - INFO - Success: Found 57 references for 2312.16094
# 2025-11-15 11:17:07,916 - INFO - Fetching references for 2312.16075
# 2025-11-15 11:17:07,916 - INFO - Fetching references for arXiv:2312.16075 (attempt 1)
# 2025-11-15 11:17:08,238 - INFO - [89/496] Success: 2312.15942 - 54 refs
# 2025-11-15 11:17:08,424 - INFO - Successfully fetched references for 2312.16075
# 2025-11-15 11:17:08,426 - INFO - Saved 61 arXiv references for 2312.16075
# 2025-11-15 11:17:08,426 - INFO - Success: Found 79 references for 2312.16075
# 2025-11-15 11:17:08,427 - INFO - Fetching references for 2312.16014
# 2025-11-15 11:17:08,427 - INFO - Fetching references for arXiv:2312.16014 (attempt 1)
# 2025-11-15 11:17:08,569 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:09,536 - INFO - Fetching references for arXiv:2312.16076 (attempt 2)
# 2025-11-15 11:17:10,218 - INFO - Successfully fetched references for 2312.16076
# 2025-11-15 11:17:10,220 - INFO - Saved 58 arXiv references for 2312.16076
# 2025-11-15 11:17:10,220 - INFO - Success: Found 73 references for 2312.16076
# 2025-11-15 11:17:10,220 - INFO - Fetching references for 2312.16095
# 2025-11-15 11:17:10,220 - INFO - Fetching references for arXiv:2312.16095 (attempt 1)
# 2025-11-15 11:17:10,366 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:11,239 - INFO - [90/496] Success: 2312.15883 - 86 refs
# 2025-11-15 11:17:11,242 - INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251115_111711.json
# 2025-11-15 11:17:11,242 - INFO - --- Checkpoint: 90/496 references fetched ---
# 2025-11-15 11:17:11,569 - INFO - Fetching references for arXiv:2312.16014 (attempt 2)
# 2025-11-15 11:17:12,255 - INFO - Successfully fetched references for 2312.16014
# 2025-11-15 11:17:12,257 - INFO - Saved 38 arXiv references for 2312.16014
# 2025-11-15 11:17:12,257 - INFO - Success: Found 62 references for 2312.16014
# 2025-11-15 11:17:12,257 - INFO - Fetching references for 2312.16142
# 2025-11-15 11:17:12,257 - INFO - Fetching references for arXiv:2312.16142 (attempt 1)
# 2025-11-15 11:17:12,397 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:13,366 - INFO - Fetching references for arXiv:2312.16095 (attempt 2)
# 2025-11-15 11:17:13,693 - INFO - Successfully fetched references for 2312.16095
# 2025-11-15 11:17:13,694 - INFO - Saved 19 arXiv references for 2312.16095
# 2025-11-15 11:17:13,694 - INFO - Success: Found 32 references for 2312.16095
# 2025-11-15 11:17:13,694 - INFO - Fetching references for 2312.16084
# 2025-11-15 11:17:13,694 - INFO - Fetching references for arXiv:2312.16084 (attempt 1)
# 2025-11-15 11:17:14,243 - INFO - [91/496] Success: 2312.15943 - 71 refs
# 2025-11-15 11:17:14,385 - INFO - Successfully fetched references for 2312.16084
# 2025-11-15 11:17:14,387 - INFO - Saved 49 arXiv references for 2312.16084
# 2025-11-15 11:17:14,387 - INFO - Success: Found 57 references for 2312.16084
# 2025-11-15 11:17:14,387 - INFO - Fetching references for 2312.16120
# 2025-11-15 11:17:14,387 - INFO - Fetching references for arXiv:2312.16120 (attempt 1)
# 2025-11-15 11:17:14,525 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:15,398 - INFO - Fetching references for arXiv:2312.16142 (attempt 2)
# 2025-11-15 11:17:16,273 - INFO - Successfully fetched references for 2312.16142
# 2025-11-15 11:17:16,275 - INFO - Saved 16 arXiv references for 2312.16142
# 2025-11-15 11:17:16,275 - INFO - Success: Found 49 references for 2312.16142
# 2025-11-15 11:17:16,275 - INFO - Fetching references for 2312.16115
# 2025-11-15 11:17:16,275 - INFO - Fetching references for arXiv:2312.16115 (attempt 1)
# 2025-11-15 11:17:16,900 - INFO - Successfully fetched references for 2312.16115
# 2025-11-15 11:17:16,901 - INFO - Saved 4 arXiv references for 2312.16115
# 2025-11-15 11:17:16,901 - INFO - Success: Found 34 references for 2312.16115
# 2025-11-15 11:17:16,901 - INFO - Fetching references for 2312.16108
# 2025-11-15 11:17:16,902 - INFO - Fetching references for arXiv:2312.16108 (attempt 1)
# 2025-11-15 11:17:17,209 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:17,243 - INFO - [92/496] Success: 2312.15849 - 44 refs
# 2025-11-15 11:17:17,525 - INFO - Fetching references for arXiv:2312.16120 (attempt 2)
# 2025-11-15 11:17:18,136 - INFO - Successfully fetched references for 2312.16120
# 2025-11-15 11:17:18,137 - INFO - Saved 49 arXiv references for 2312.16120
# 2025-11-15 11:17:18,137 - INFO - Success: Found 63 references for 2312.16120
# 2025-11-15 11:17:18,137 - INFO - Fetching references for 2312.16069
# 2025-11-15 11:17:18,138 - INFO - Fetching references for arXiv:2312.16069 (attempt 1)
# 2025-11-15 11:17:18,431 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:20,210 - INFO - Fetching references for arXiv:2312.16108 (attempt 2)
# 2025-11-15 11:17:20,244 - INFO - [93/496] Success: 2312.15905 - 69 refs
# 2025-11-15 11:17:21,196 - INFO - Successfully fetched references for 2312.16108
# 2025-11-15 11:17:21,197 - INFO - Saved 29 arXiv references for 2312.16108
# 2025-11-15 11:17:21,197 - INFO - Success: Found 35 references for 2312.16108
# 2025-11-15 11:17:21,197 - INFO - Fetching references for 2312.16130
# 2025-11-15 11:17:21,197 - INFO - Fetching references for arXiv:2312.16130 (attempt 1)
# 2025-11-15 11:17:21,431 - INFO - Fetching references for arXiv:2312.16069 (attempt 2)
# 2025-11-15 11:17:21,760 - INFO - Successfully fetched references for 2312.16069
# 2025-11-15 11:17:21,761 - INFO - Saved 0 arXiv references for 2312.16069
# 2025-11-15 11:17:21,761 - INFO - Success: Found 0 references for 2312.16069
# 2025-11-15 11:17:21,761 - INFO - Fetching references for 2312.16081
# 2025-11-15 11:17:21,761 - INFO - Fetching references for arXiv:2312.16081 (attempt 1)
# 2025-11-15 11:17:22,072 - INFO - Successfully fetched references for 2312.16130
# 2025-11-15 11:17:22,073 - INFO - Saved 2 arXiv references for 2312.16130
# 2025-11-15 11:17:22,073 - INFO - Success: Found 42 references for 2312.16130
# 2025-11-15 11:17:22,073 - INFO - Fetching references for 2312.16057
# 2025-11-15 11:17:22,073 - INFO - Fetching references for arXiv:2312.16057 (attempt 1)
# 2025-11-15 11:17:22,241 - INFO - Successfully fetched references for 2312.16081
# 2025-11-15 11:17:22,243 - INFO - Saved 40 arXiv references for 2312.16081
# 2025-11-15 11:17:22,243 - INFO - Success: Found 57 references for 2312.16081
# 2025-11-15 11:17:22,243 - INFO - Fetching references for 2312.16058
# 2025-11-15 11:17:22,243 - INFO - Fetching references for arXiv:2312.16058 (attempt 1)
# 2025-11-15 11:17:22,578 - INFO - Successfully fetched references for 2312.16057
# 2025-11-15 11:17:22,579 - INFO - Saved 18 arXiv references for 2312.16057
# 2025-11-15 11:17:22,579 - INFO - Success: Found 27 references for 2312.16057
# 2025-11-15 11:17:22,579 - INFO - Fetching references for 2312.16047
# 2025-11-15 11:17:22,579 - INFO - Fetching references for arXiv:2312.16047 (attempt 1)
# 2025-11-15 11:17:22,702 - INFO - Successfully fetched references for 2312.16058
# 2025-11-15 11:17:22,703 - INFO - Saved 8 arXiv references for 2312.16058
# 2025-11-15 11:17:22,703 - INFO - Success: Found 16 references for 2312.16058
# 2025-11-15 11:17:22,703 - INFO - Fetching references for 2312.16062
# 2025-11-15 11:17:22,703 - INFO - Fetching references for arXiv:2312.16062 (attempt 1)
# 2025-11-15 11:17:23,244 - INFO - [94/496] Success: 2312.15931 - 6 refs
# 2025-11-15 11:17:23,276 - INFO - Successfully fetched references for 2312.16062
# 2025-11-15 11:17:23,277 - INFO - Saved 32 arXiv references for 2312.16062
# 2025-11-15 11:17:23,277 - INFO - Success: Found 105 references for 2312.16062
# 2025-11-15 11:17:23,278 - INFO - Fetching references for 2312.16137
# 2025-11-15 11:17:23,278 - INFO - Fetching references for arXiv:2312.16137 (attempt 1)
# 2025-11-15 11:17:23,494 - INFO - Successfully fetched references for 2312.16047
# 2025-11-15 11:17:23,495 - INFO - Saved 20 arXiv references for 2312.16047
# 2025-11-15 11:17:23,495 - INFO - Success: Found 25 references for 2312.16047
# 2025-11-15 11:17:23,495 - INFO - Fetching references for 2312.16083
# 2025-11-15 11:17:23,496 - INFO - Fetching references for arXiv:2312.16083 (attempt 1)
# 2025-11-15 11:17:23,632 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:23,664 - INFO - Successfully fetched references for 2312.16137
# 2025-11-15 11:17:23,665 - INFO - Saved 10 arXiv references for 2312.16137
# 2025-11-15 11:17:23,665 - INFO - Success: Found 31 references for 2312.16137
# 2025-11-15 11:17:23,666 - INFO - Fetching references for 2312.16082
# 2025-11-15 11:17:23,666 - INFO - Fetching references for arXiv:2312.16082 (attempt 1)
# 2025-11-15 11:17:23,956 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:26,245 - INFO - [95/496] Success: 2312.15901 - 50 refs
# 2025-11-15 11:17:26,632 - INFO - Fetching references for arXiv:2312.16083 (attempt 2)
# 2025-11-15 11:17:26,768 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:26,956 - INFO - Fetching references for arXiv:2312.16082 (attempt 2)
# 2025-11-15 11:17:27,475 - INFO - Successfully fetched references for 2312.16082
# 2025-11-15 11:17:27,477 - INFO - Saved 45 arXiv references for 2312.16082
# 2025-11-15 11:17:27,477 - INFO - Success: Found 70 references for 2312.16082
# 2025-11-15 11:17:27,477 - INFO - Fetching references for 2312.16063
# 2025-11-15 11:17:27,477 - INFO - Fetching references for arXiv:2312.16063 (attempt 1)
# 2025-11-15 11:17:28,277 - INFO - Successfully fetched references for 2312.16063
# 2025-11-15 11:17:28,278 - INFO - Saved 3 arXiv references for 2312.16063
# 2025-11-15 11:17:28,278 - INFO - Success: Found 43 references for 2312.16063
# 2025-11-15 11:17:28,279 - INFO - Fetching references for 2312.16073
# 2025-11-15 11:17:28,279 - INFO - Fetching references for arXiv:2312.16073 (attempt 1)
# 2025-11-15 11:17:28,437 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:29,245 - INFO - [96/496] Success: 2312.15929 - 18 refs
# 2025-11-15 11:17:29,768 - INFO - Fetching references for arXiv:2312.16083 (attempt 3)
# 2025-11-15 11:17:29,906 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:31,437 - INFO - Fetching references for arXiv:2312.16073 (attempt 2)
# 2025-11-15 11:17:31,908 - INFO - Successfully fetched references for 2312.16073
# 2025-11-15 11:17:31,909 - INFO - Saved 20 arXiv references for 2312.16073
# 2025-11-15 11:17:31,909 - INFO - Success: Found 45 references for 2312.16073
# 2025-11-15 11:17:31,910 - INFO - Fetching references for 2312.16090
# 2025-11-15 11:17:31,910 - INFO - Fetching references for arXiv:2312.16090 (attempt 1)
# 2025-11-15 11:17:32,158 - INFO - Successfully fetched references for 2312.16090
# 2025-11-15 11:17:32,159 - INFO - Saved 1 arXiv references for 2312.16090
# 2025-11-15 11:17:32,159 - INFO - Success: Found 10 references for 2312.16090
# 2025-11-15 11:17:32,159 - INFO - Fetching references for 2312.16100
# 2025-11-15 11:17:32,159 - INFO - Fetching references for arXiv:2312.16100 (attempt 1)
# 2025-11-15 11:17:32,246 - INFO - [97/496] Success: 2312.15895 - 51 refs
# 2025-11-15 11:17:32,383 - INFO - Successfully fetched references for 2312.16100
# 2025-11-15 11:17:32,384 - INFO - Saved 11 arXiv references for 2312.16100
# 2025-11-15 11:17:32,384 - INFO - Success: Found 22 references for 2312.16100
# 2025-11-15 11:17:32,385 - INFO - Fetching references for 2312.16098
# 2025-11-15 11:17:32,385 - INFO - Fetching references for arXiv:2312.16098 (attempt 1)
# 2025-11-15 11:17:32,708 - INFO - Successfully fetched references for 2312.16098
# 2025-11-15 11:17:32,709 - INFO - Saved 20 arXiv references for 2312.16098
# 2025-11-15 11:17:32,710 - INFO - Success: Found 25 references for 2312.16098
# 2025-11-15 11:17:32,710 - INFO - Fetching references for 2312.16110
# 2025-11-15 11:17:32,710 - INFO - Fetching references for arXiv:2312.16110 (attempt 1)
# 2025-11-15 11:17:32,906 - INFO - Fetching references for arXiv:2312.16083 (attempt 4)
# 2025-11-15 11:17:33,155 - INFO - Successfully fetched references for 2312.16083
# 2025-11-15 11:17:33,156 - INFO - Saved 14 arXiv references for 2312.16083
# 2025-11-15 11:17:33,156 - INFO - Success: Found 29 references for 2312.16083
# 2025-11-15 11:17:33,156 - INFO - Fetching references for 2312.16061
# 2025-11-15 11:17:33,156 - INFO - Fetching references for arXiv:2312.16061 (attempt 1)
# 2025-11-15 11:17:33,182 - INFO - Successfully fetched references for 2312.16110
# 2025-11-15 11:17:33,183 - INFO - Saved 43 arXiv references for 2312.16110
# 2025-11-15 11:17:33,184 - INFO - Success: Found 57 references for 2312.16110
# 2025-11-15 11:17:33,184 - INFO - Fetching references for 2312.16105
# 2025-11-15 11:17:33,184 - INFO - Fetching references for arXiv:2312.16105 (attempt 1)
# 2025-11-15 11:17:33,322 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:33,686 - INFO - Successfully fetched references for 2312.16061
# 2025-11-15 11:17:33,688 - INFO - Saved 27 arXiv references for 2312.16061
# 2025-11-15 11:17:33,688 - INFO - Success: Found 58 references for 2312.16061
# 2025-11-15 11:17:33,688 - INFO - Fetching references for 2312.16093
# 2025-11-15 11:17:33,688 - INFO - Fetching references for arXiv:2312.16093 (attempt 1)
# 2025-11-15 11:17:33,983 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:35,246 - INFO - [98/496] Success: 2312.16033 - 21 refs
# 2025-11-15 11:17:36,322 - INFO - Fetching references for arXiv:2312.16105 (attempt 2)
# 2025-11-15 11:17:36,631 - INFO - Successfully fetched references for 2312.16105
# 2025-11-15 11:17:36,631 - INFO - Saved 0 arXiv references for 2312.16105
# 2025-11-15 11:17:36,631 - INFO - Success: Found 48 references for 2312.16105
# 2025-11-15 11:17:36,632 - INFO - Fetching references for 2312.16125
# 2025-11-15 11:17:36,632 - INFO - Fetching references for arXiv:2312.16125 (attempt 1)
# 2025-11-15 11:17:36,824 - INFO - Successfully fetched references for 2312.16125
# 2025-11-15 11:17:36,825 - INFO - Saved 1 arXiv references for 2312.16125
# 2025-11-15 11:17:36,825 - INFO - Success: Found 8 references for 2312.16125
# 2025-11-15 11:17:36,825 - INFO - Fetching references for 2312.16112
# 2025-11-15 11:17:36,825 - INFO - Fetching references for arXiv:2312.16112 (attempt 1)
# 2025-11-15 11:17:36,983 - INFO - Fetching references for arXiv:2312.16093 (attempt 2)
# 2025-11-15 11:17:37,040 - INFO - Successfully fetched references for 2312.16112
# 2025-11-15 11:17:37,041 - INFO - Saved 3 arXiv references for 2312.16112
# 2025-11-15 11:17:37,041 - INFO - Success: Found 12 references for 2312.16112
# 2025-11-15 11:17:37,041 - INFO - Fetching references for 2312.16045
# 2025-11-15 11:17:37,041 - INFO - Fetching references for arXiv:2312.16045 (attempt 1)
# 2025-11-15 11:17:37,190 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:37,251 - INFO - Successfully fetched references for 2312.16093
# 2025-11-15 11:17:37,252 - INFO - Saved 10 arXiv references for 2312.16093
# 2025-11-15 11:17:37,252 - INFO - Success: Found 32 references for 2312.16093
# 2025-11-15 11:17:37,252 - INFO - Fetching references for 2312.16141
# 2025-11-15 11:17:37,252 - INFO - Fetching references for arXiv:2312.16141 (attempt 1)
# 2025-11-15 11:17:37,553 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:38,246 - INFO - [99/496] Success: 2312.15978 - 32 refs
# 2025-11-15 11:17:40,190 - INFO - Fetching references for arXiv:2312.16045 (attempt 2)
# 2025-11-15 11:17:40,553 - INFO - Fetching references for arXiv:2312.16141 (attempt 2)
# 2025-11-15 11:17:40,674 - INFO - Successfully fetched references for 2312.16045
# 2025-11-15 11:17:40,676 - INFO - Saved 20 arXiv references for 2312.16045
# 2025-11-15 11:17:40,676 - INFO - Success: Found 41 references for 2312.16045
# 2025-11-15 11:17:40,676 - INFO - Fetching references for 2312.16066
# 2025-11-15 11:17:40,676 - INFO - Fetching references for arXiv:2312.16066 (attempt 1)
# 2025-11-15 11:17:40,829 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:40,874 - INFO - Successfully fetched references for 2312.16141
# 2025-11-15 11:17:40,876 - INFO - Saved 23 arXiv references for 2312.16141
# 2025-11-15 11:17:40,876 - INFO - Success: Found 34 references for 2312.16141
# 2025-11-15 11:17:40,876 - INFO - Fetching references for 2312.16085
# 2025-11-15 11:17:40,876 - INFO - Fetching references for arXiv:2312.16085 (attempt 1)
# 2025-11-15 11:17:41,163 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:41,247 - INFO - [100/496] Success: 2312.15904 - 33 refs
# 2025-11-15 11:17:41,251 - INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251115_111741.json
# 2025-11-15 11:17:41,251 - INFO - --- Checkpoint: 100/496 references fetched ---
# 2025-11-15 11:17:43,829 - INFO - Fetching references for arXiv:2312.16066 (attempt 2)
# 2025-11-15 11:17:44,164 - INFO - Fetching references for arXiv:2312.16085 (attempt 2)
# 2025-11-15 11:17:44,251 - INFO - [101/496] Success: 2312.15990 - 14 refs
# 2025-11-15 11:17:44,366 - INFO - Successfully fetched references for 2312.16066
# 2025-11-15 11:17:44,368 - INFO - Saved 38 arXiv references for 2312.16066
# 2025-11-15 11:17:44,368 - INFO - Success: Found 72 references for 2312.16066
# 2025-11-15 11:17:44,368 - INFO - Fetching references for 2312.16133
# 2025-11-15 11:17:44,368 - INFO - Fetching references for arXiv:2312.16133 (attempt 1)
# 2025-11-15 11:17:44,511 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:44,641 - INFO - Successfully fetched references for 2312.16085
# 2025-11-15 11:17:44,642 - INFO - Saved 9 arXiv references for 2312.16085
# 2025-11-15 11:17:44,643 - INFO - Success: Found 38 references for 2312.16085
# 2025-11-15 11:17:44,643 - INFO - Fetching references for 2312.16052
# 2025-11-15 11:17:44,643 - INFO - Fetching references for arXiv:2312.16052 (attempt 1)
# 2025-11-15 11:17:44,875 - INFO - Successfully fetched references for 2312.16052
# 2025-11-15 11:17:44,877 - INFO - Saved 20 arXiv references for 2312.16052
# 2025-11-15 11:17:44,877 - INFO - Success: Found 41 references for 2312.16052
# 2025-11-15 11:17:44,877 - INFO - Fetching references for 2312.16189
# 2025-11-15 11:17:44,878 - INFO - Fetching references for arXiv:2312.16189 (attempt 1)
# 2025-11-15 11:17:45,161 - INFO - Successfully fetched references for 2312.16189
# 2025-11-15 11:17:45,163 - INFO - Saved 26 arXiv references for 2312.16189
# 2025-11-15 11:17:45,163 - INFO - Success: Found 35 references for 2312.16189
# 2025-11-15 11:17:45,163 - INFO - Fetching references for 2312.16175
# 2025-11-15 11:17:45,163 - INFO - Fetching references for arXiv:2312.16175 (attempt 1)
# 2025-11-15 11:17:45,389 - INFO - Successfully fetched references for 2312.16175
# 2025-11-15 11:17:45,390 - INFO - Saved 5 arXiv references for 2312.16175
# 2025-11-15 11:17:45,390 - INFO - Success: Found 18 references for 2312.16175
# 2025-11-15 11:17:45,390 - INFO - Fetching references for 2312.16193
# 2025-11-15 11:17:45,390 - INFO - Fetching references for arXiv:2312.16193 (attempt 1)
# 2025-11-15 11:17:45,532 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:47,252 - INFO - [102/496] Success: 2312.15927 - 54 refs
# 2025-11-15 11:17:47,511 - INFO - Fetching references for arXiv:2312.16133 (attempt 2)
# 2025-11-15 11:17:47,700 - INFO - Successfully fetched references for 2312.16133
# 2025-11-15 11:17:47,700 - INFO - Saved 0 arXiv references for 2312.16133
# 2025-11-15 11:17:47,700 - INFO - Success: Found 10 references for 2312.16133
# 2025-11-15 11:17:47,701 - INFO - Fetching references for 2312.16044
# 2025-11-15 11:17:47,701 - INFO - Fetching references for arXiv:2312.16044 (attempt 1)
# 2025-11-15 11:17:48,003 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:48,532 - INFO - Fetching references for arXiv:2312.16193 (attempt 2)
# 2025-11-15 11:17:48,669 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:50,252 - INFO - [103/496] Success: 2312.15994 - 27 refs
# 2025-11-15 11:17:51,003 - INFO - Fetching references for arXiv:2312.16044 (attempt 2)
# 2025-11-15 11:17:51,317 - INFO - Successfully fetched references for 2312.16044
# 2025-11-15 11:17:51,319 - INFO - Saved 22 arXiv references for 2312.16044
# 2025-11-15 11:17:51,319 - INFO - Success: Found 61 references for 2312.16044
# 2025-11-15 11:17:51,319 - INFO - Fetching references for 2312.16207
# 2025-11-15 11:17:51,319 - INFO - Fetching references for arXiv:2312.16207 (attempt 1)
# 2025-11-15 11:17:51,483 - INFO - Successfully fetched references for 2312.16207
# 2025-11-15 11:17:51,484 - INFO - Saved 0 arXiv references for 2312.16207
# 2025-11-15 11:17:51,484 - INFO - Success: Found 1 references for 2312.16207
# 2025-11-15 11:17:51,485 - INFO - Fetching references for 2312.16212
# 2025-11-15 11:17:51,485 - INFO - Fetching references for arXiv:2312.16212 (attempt 1)
# 2025-11-15 11:17:51,669 - INFO - Fetching references for arXiv:2312.16193 (attempt 3)
# 2025-11-15 11:17:51,996 - INFO - Successfully fetched references for 2312.16212
# 2025-11-15 11:17:51,998 - INFO - Saved 69 arXiv references for 2312.16212
# 2025-11-15 11:17:51,998 - INFO - Success: Found 85 references for 2312.16212
# 2025-11-15 11:17:51,999 - INFO - Fetching references for 2312.16238
# 2025-11-15 11:17:51,999 - INFO - Fetching references for arXiv:2312.16238 (attempt 1)
# 2025-11-15 11:17:52,030 - INFO - Successfully fetched references for 2312.16193
# 2025-11-15 11:17:52,031 - INFO - Saved 7 arXiv references for 2312.16193
# 2025-11-15 11:17:52,031 - INFO - Success: Found 26 references for 2312.16193
# 2025-11-15 11:17:52,031 - INFO - Fetching references for 2312.16118
# 2025-11-15 11:17:52,031 - INFO - Fetching references for arXiv:2312.16118 (attempt 1)
# 2025-11-15 11:17:52,288 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:52,514 - INFO - Successfully fetched references for 2312.16118
# 2025-11-15 11:17:52,515 - INFO - Saved 20 arXiv references for 2312.16118
# 2025-11-15 11:17:52,515 - INFO - Success: Found 55 references for 2312.16118
# 2025-11-15 11:17:52,516 - INFO - Fetching references for 2312.16237
# 2025-11-15 11:17:52,516 - INFO - Fetching references for arXiv:2312.16237 (attempt 1)
# 2025-11-15 11:17:53,013 - INFO - Successfully fetched references for 2312.16237
# 2025-11-15 11:17:53,015 - INFO - Saved 27 arXiv references for 2312.16237
# 2025-11-15 11:17:53,015 - INFO - Success: Found 66 references for 2312.16237
# 2025-11-15 11:17:53,015 - INFO - Fetching references for 2312.16179
# 2025-11-15 11:17:53,015 - INFO - Fetching references for arXiv:2312.16179 (attempt 1)
# 2025-11-15 11:17:53,165 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:53,253 - INFO - [104/496] Success: 2312.15856 - 86 refs
# 2025-11-15 11:17:55,288 - INFO - Fetching references for arXiv:2312.16238 (attempt 2)
# 2025-11-15 11:17:55,466 - INFO - Successfully fetched references for 2312.16238
# 2025-11-15 11:17:55,467 - INFO - Saved 0 arXiv references for 2312.16238
# 2025-11-15 11:17:55,467 - INFO - Success: Found 4 references for 2312.16238
# 2025-11-15 11:17:55,467 - INFO - Fetching references for 2312.16210
# 2025-11-15 11:17:55,467 - INFO - Fetching references for arXiv:2312.16210 (attempt 1)
# 2025-11-15 11:17:55,766 - INFO - Successfully fetched references for 2312.16210
# 2025-11-15 11:17:55,767 - INFO - Saved 10 arXiv references for 2312.16210
# 2025-11-15 11:17:55,767 - INFO - Success: Found 35 references for 2312.16210
# 2025-11-15 11:17:55,768 - INFO - Fetching references for 2312.16215
# 2025-11-15 11:17:55,768 - INFO - Fetching references for arXiv:2312.16215 (attempt 1)
# 2025-11-15 11:17:56,140 - INFO - Successfully fetched references for 2312.16215
# 2025-11-15 11:17:56,142 - INFO - Saved 26 arXiv references for 2312.16215
# 2025-11-15 11:17:56,142 - INFO - Success: Found 59 references for 2312.16215
# 2025-11-15 11:17:56,142 - INFO - Fetching references for 2312.16168
# 2025-11-15 11:17:56,142 - INFO - Fetching references for arXiv:2312.16168 (attempt 1)
# 2025-11-15 11:17:56,165 - INFO - Fetching references for arXiv:2312.16179 (attempt 2)
# 2025-11-15 11:17:56,253 - INFO - [105/496] Success: 2312.15998 - 2 refs
# 2025-11-15 11:17:56,290 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:56,311 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:17:59,254 - INFO - [106/496] Success: 2312.15944 - 66 refs
# 2025-11-15 11:17:59,291 - INFO - Fetching references for arXiv:2312.16168 (attempt 2)
# 2025-11-15 11:17:59,311 - INFO - Fetching references for arXiv:2312.16179 (attempt 3)
# 2025-11-15 11:17:59,596 - INFO - Successfully fetched references for 2312.16168
# 2025-11-15 11:17:59,598 - INFO - Saved 37 arXiv references for 2312.16168
# 2025-11-15 11:17:59,598 - INFO - Success: Found 55 references for 2312.16168
# 2025-11-15 11:17:59,598 - INFO - Fetching references for 2312.16150
# 2025-11-15 11:17:59,598 - INFO - Fetching references for arXiv:2312.16150 (attempt 1)
# 2025-11-15 11:17:59,744 - INFO - Successfully fetched references for 2312.16179
# 2025-11-15 11:17:59,745 - INFO - Saved 3 arXiv references for 2312.16179
# 2025-11-15 11:17:59,745 - INFO - Success: Found 47 references for 2312.16179
# 2025-11-15 11:17:59,745 - INFO - Fetching references for 2312.16158
# 2025-11-15 11:17:59,745 - INFO - Fetching references for arXiv:2312.16158 (attempt 1)
# 2025-11-15 11:17:59,781 - INFO - Successfully fetched references for 2312.16150
# 2025-11-15 11:17:59,782 - INFO - Saved 0 arXiv references for 2312.16150
# 2025-11-15 11:17:59,782 - INFO - Success: Found 3 references for 2312.16150
# 2025-11-15 11:17:59,782 - INFO - Fetching references for 2312.16214
# 2025-11-15 11:17:59,782 - INFO - Fetching references for arXiv:2312.16214 (attempt 1)
# 2025-11-15 11:17:59,951 - INFO - Successfully fetched references for 2312.16214
# 2025-11-15 11:17:59,952 - INFO - Successfully fetched references for 2312.16158
# 2025-11-15 11:17:59,953 - INFO - Saved 0 arXiv references for 2312.16214
# 2025-11-15 11:17:59,953 - INFO - Success: Found 0 references for 2312.16214
# 2025-11-15 11:17:59,954 - INFO - Saved 0 arXiv references for 2312.16158
# 2025-11-15 11:17:59,954 - INFO - Fetching references for 2312.16161
# 2025-11-15 11:17:59,954 - INFO - Success: Found 15 references for 2312.16158
# 2025-11-15 11:17:59,954 - INFO - Fetching references for arXiv:2312.16161 (attempt 1)
# 2025-11-15 11:17:59,954 - INFO - Fetching references for 2312.16163
# 2025-11-15 11:17:59,956 - INFO - Fetching references for arXiv:2312.16163 (attempt 1)
# 2025-11-15 11:18:00,113 - INFO - Successfully fetched references for 2312.16161
# 2025-11-15 11:18:00,113 - INFO - Saved 0 arXiv references for 2312.16161
# 2025-11-15 11:18:00,113 - INFO - Success: Found 0 references for 2312.16161
# 2025-11-15 11:18:00,114 - INFO - Fetching references for 2312.16182
# 2025-11-15 11:18:00,114 - INFO - Fetching references for arXiv:2312.16182 (attempt 1)
# 2025-11-15 11:18:00,248 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:00,332 - INFO - Successfully fetched references for 2312.16163
# 2025-11-15 11:18:00,333 - INFO - Saved 27 arXiv references for 2312.16163
# 2025-11-15 11:18:00,333 - INFO - Success: Found 84 references for 2312.16163
# 2025-11-15 11:18:00,333 - INFO - Fetching references for 2312.16172
# 2025-11-15 11:18:00,333 - INFO - Fetching references for arXiv:2312.16172 (attempt 1)
# 2025-11-15 11:18:00,470 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:02,254 - INFO - [107/496] Success: 2312.16006 - 15 refs
# 2025-11-15 11:18:03,249 - INFO - Fetching references for arXiv:2312.16182 (attempt 2)
# 2025-11-15 11:18:03,394 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:03,471 - INFO - Fetching references for arXiv:2312.16172 (attempt 2)
# 2025-11-15 11:18:03,615 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:05,255 - INFO - [108/496] Success: 2312.16003 - 15 refs
# 2025-11-15 11:18:06,394 - INFO - Fetching references for arXiv:2312.16182 (attempt 3)
# 2025-11-15 11:18:06,615 - INFO - Fetching references for arXiv:2312.16172 (attempt 3)
# 2025-11-15 11:18:06,855 - INFO - Successfully fetched references for 2312.16182
# 2025-11-15 11:18:06,857 - INFO - Saved 23 arXiv references for 2312.16182
# 2025-11-15 11:18:06,858 - INFO - Success: Found 45 references for 2312.16182
# 2025-11-15 11:18:06,858 - INFO - Fetching references for 2312.16181
# 2025-11-15 11:18:06,858 - INFO - Fetching references for arXiv:2312.16181 (attempt 1)
# 2025-11-15 11:18:07,169 - INFO - Successfully fetched references for 2312.16181
# 2025-11-15 11:18:07,170 - INFO - Saved 0 arXiv references for 2312.16181
# 2025-11-15 11:18:07,171 - INFO - Success: Found 0 references for 2312.16181
# 2025-11-15 11:18:07,171 - INFO - Fetching references for 2312.16180
# 2025-11-15 11:18:07,171 - INFO - Fetching references for arXiv:2312.16180 (attempt 1)
# 2025-11-15 11:18:07,220 - INFO - Successfully fetched references for 2312.16172
# 2025-11-15 11:18:07,224 - INFO - Saved 55 arXiv references for 2312.16172
# 2025-11-15 11:18:07,224 - INFO - Success: Found 73 references for 2312.16172
# 2025-11-15 11:18:07,225 - INFO - Fetching references for 2312.16127
# 2025-11-15 11:18:07,225 - INFO - Fetching references for arXiv:2312.16127 (attempt 1)
# 2025-11-15 11:18:07,544 - INFO - Successfully fetched references for 2312.16127
# 2025-11-15 11:18:07,546 - INFO - Saved 34 arXiv references for 2312.16127
# 2025-11-15 11:18:07,546 - INFO - Success: Found 46 references for 2312.16127
# 2025-11-15 11:18:07,546 - INFO - Fetching references for 2312.16184
# 2025-11-15 11:18:07,546 - INFO - Fetching references for arXiv:2312.16184 (attempt 1)
# 2025-11-15 11:18:07,591 - INFO - Successfully fetched references for 2312.16180
# 2025-11-15 11:18:07,592 - INFO - Saved 10 arXiv references for 2312.16180
# 2025-11-15 11:18:07,592 - INFO - Success: Found 22 references for 2312.16180
# 2025-11-15 11:18:07,592 - INFO - Fetching references for 2312.16205
# 2025-11-15 11:18:07,592 - INFO - Fetching references for arXiv:2312.16205 (attempt 1)
# 2025-11-15 11:18:07,682 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:07,891 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:08,255 - INFO - [109/496] Success: 2312.15984 - 64 refs
# 2025-11-15 11:18:10,682 - INFO - Fetching references for arXiv:2312.16184 (attempt 2)
# 2025-11-15 11:18:10,830 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:10,891 - INFO - Fetching references for arXiv:2312.16205 (attempt 2)
# 2025-11-15 11:18:11,026 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:11,255 - INFO - [110/496] Success: 2312.16018 - 98 refs
# 2025-11-15 11:18:11,259 - INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251115_111811.json
# 2025-11-15 11:18:11,259 - INFO - --- Checkpoint: 110/496 references fetched ---
# 2025-11-15 11:18:13,830 - INFO - Fetching references for arXiv:2312.16184 (attempt 3)
# 2025-11-15 11:18:14,027 - INFO - Fetching references for arXiv:2312.16205 (attempt 3)
# 2025-11-15 11:18:14,211 - INFO - Successfully fetched references for 2312.16205
# 2025-11-15 11:18:14,212 - INFO - Saved 0 arXiv references for 2312.16205
# 2025-11-15 11:18:14,212 - INFO - Success: Found 0 references for 2312.16205
# 2025-11-15 11:18:14,212 - INFO - Fetching references for 2312.16183
# 2025-11-15 11:18:14,212 - INFO - Fetching references for arXiv:2312.16183 (attempt 1)
# 2025-11-15 11:18:14,259 - INFO - [111/496] Success: 2312.15991 - 24 refs
# 2025-11-15 11:18:14,371 - INFO - Successfully fetched references for 2312.16184
# 2025-11-15 11:18:14,373 - INFO - Saved 14 arXiv references for 2312.16184
# 2025-11-15 11:18:14,373 - INFO - Success: Found 39 references for 2312.16184
# 2025-11-15 11:18:14,373 - INFO - Fetching references for 2312.16195
# 2025-11-15 11:18:14,373 - INFO - Fetching references for arXiv:2312.16195 (attempt 1)
# 2025-11-15 11:18:14,538 - INFO - Successfully fetched references for 2312.16183
# 2025-11-15 11:18:14,538 - INFO - Saved 5 arXiv references for 2312.16183
# 2025-11-15 11:18:14,539 - INFO - Success: Found 5 references for 2312.16183
# 2025-11-15 11:18:14,539 - INFO - Fetching references for 2312.16216
# 2025-11-15 11:18:14,539 - INFO - Fetching references for arXiv:2312.16216 (attempt 1)
# 2025-11-15 11:18:14,659 - INFO - Successfully fetched references for 2312.16195
# 2025-11-15 11:18:14,660 - INFO - Saved 25 arXiv references for 2312.16195
# 2025-11-15 11:18:14,660 - INFO - Success: Found 40 references for 2312.16195
# 2025-11-15 11:18:14,661 - INFO - Fetching references for 2312.16226
# 2025-11-15 11:18:14,661 - INFO - Fetching references for arXiv:2312.16226 (attempt 1)
# 2025-11-15 11:18:15,004 - INFO - Successfully fetched references for 2312.16216
# 2025-11-15 11:18:15,005 - INFO - Saved 3 arXiv references for 2312.16216
# 2025-11-15 11:18:15,005 - INFO - Success: Found 45 references for 2312.16216
# 2025-11-15 11:18:15,005 - INFO - Fetching references for 2312.16235
# 2025-11-15 11:18:15,005 - INFO - Fetching references for arXiv:2312.16235 (attempt 1)
# 2025-11-15 11:18:15,314 - INFO - Successfully fetched references for 2312.16226
# 2025-11-15 11:18:15,315 - INFO - Saved 11 arXiv references for 2312.16226
# 2025-11-15 11:18:15,316 - INFO - Success: Found 68 references for 2312.16226
# 2025-11-15 11:18:15,316 - INFO - Fetching references for 2312.16164
# 2025-11-15 11:18:15,317 - INFO - Fetching references for arXiv:2312.16164 (attempt 1)
# 2025-11-15 11:18:15,316 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:15,544 - INFO - Successfully fetched references for 2312.16164
# 2025-11-15 11:18:15,546 - INFO - Saved 30 arXiv references for 2312.16164
# 2025-11-15 11:18:15,546 - INFO - Success: Found 38 references for 2312.16164
# 2025-11-15 11:18:15,546 - INFO - Fetching references for 2312.16209
# 2025-11-15 11:18:15,546 - INFO - Fetching references for arXiv:2312.16209 (attempt 1)
# 2025-11-15 11:18:15,690 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:17,260 - INFO - [112/496] Success: 2312.16008 - 17 refs
# 2025-11-15 11:18:18,318 - INFO - Fetching references for arXiv:2312.16235 (attempt 2)
# 2025-11-15 11:18:18,618 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:18,690 - INFO - Fetching references for arXiv:2312.16209 (attempt 2)
# 2025-11-15 11:18:18,857 - INFO - Successfully fetched references for 2312.16209
# 2025-11-15 11:18:18,858 - INFO - Saved 0 arXiv references for 2312.16209
# 2025-11-15 11:18:18,858 - INFO - Success: Found 2 references for 2312.16209
# 2025-11-15 11:18:18,859 - INFO - Fetching references for 2312.16225
# 2025-11-15 11:18:18,859 - INFO - Fetching references for arXiv:2312.16225 (attempt 1)
# 2025-11-15 11:18:18,998 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:20,260 - INFO - [113/496] Success: 2312.15962 - 11 refs
# 2025-11-15 11:18:21,618 - INFO - Fetching references for arXiv:2312.16235 (attempt 3)
# 2025-11-15 11:18:21,984 - INFO - Successfully fetched references for 2312.16235
# 2025-11-15 11:18:21,985 - INFO - Saved 2 arXiv references for 2312.16235
# 2025-11-15 11:18:21,985 - INFO - Success: Found 12 references for 2312.16235
# 2025-11-15 11:18:21,985 - INFO - Fetching references for 2312.16198
# 2025-11-15 11:18:21,985 - INFO - Fetching references for arXiv:2312.16198 (attempt 1)
# 2025-11-15 11:18:21,998 - INFO - Fetching references for arXiv:2312.16225 (attempt 2)
# 2025-11-15 11:18:22,326 - INFO - Successfully fetched references for 2312.16225
# 2025-11-15 11:18:22,327 - INFO - Saved 0 arXiv references for 2312.16225
# 2025-11-15 11:18:22,327 - INFO - Success: Found 0 references for 2312.16225
# 2025-11-15 11:18:22,327 - INFO - Fetching references for 2312.16240
# 2025-11-15 11:18:22,328 - INFO - Fetching references for arXiv:2312.16240 (attempt 1)
# 2025-11-15 11:18:22,417 - INFO - Successfully fetched references for 2312.16198
# 2025-11-15 11:18:22,419 - INFO - Saved 21 arXiv references for 2312.16198
# 2025-11-15 11:18:22,419 - INFO - Success: Found 40 references for 2312.16198
# 2025-11-15 11:18:22,419 - INFO - Fetching references for 2312.16156
# 2025-11-15 11:18:22,419 - INFO - Fetching references for arXiv:2312.16156 (attempt 1)
# 2025-11-15 11:18:22,626 - INFO - Successfully fetched references for 2312.16240
# 2025-11-15 11:18:22,628 - INFO - Saved 29 arXiv references for 2312.16240
# 2025-11-15 11:18:22,628 - INFO - Success: Found 43 references for 2312.16240
# 2025-11-15 11:18:22,628 - INFO - Fetching references for 2312.16213
# 2025-11-15 11:18:22,629 - INFO - Fetching references for arXiv:2312.16213 (attempt 1)
# 2025-11-15 11:18:22,788 - INFO - Successfully fetched references for 2312.16156
# 2025-11-15 11:18:22,789 - INFO - Saved 47 arXiv references for 2312.16156
# 2025-11-15 11:18:22,789 - INFO - Success: Found 100 references for 2312.16156
# 2025-11-15 11:18:22,790 - INFO - Fetching references for 2312.16230
# 2025-11-15 11:18:22,790 - INFO - Fetching references for arXiv:2312.16230 (attempt 1)
# 2025-11-15 11:18:22,919 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:23,088 - WARNING - Rate limited. Waiting 3.0s...
# 2025-11-15 11:18:23,261 - INFO - [114/496] Success: 2312.15953 - 9 refs
# 2025-11-15 11:18:25,919 - INFO - Fetching references for arXiv:2312.16213 (attempt 2)
# 2025-11-15 11:18:26,088 - INFO - Fetching references for arXiv:2312.16230 (attempt 2)
# 2025-11-15 11:18:26,175 - INFO - Successfully fetched references for 2312.16213
# 2025-11-15 11:18:26,176 - INFO - Saved 4 arXiv references for 2312.16213
# 2025-11-15 11:18:26,176 - INFO - Success: Found 28 references for 2312.16213
# 2025-11-15 11:18:26,176 - INFO - Fetching references for 2312.16228
# 2025-11-15 11:18:26,176 - INFO - Fetching references for arXiv:2312.16228 (attempt 1)
# 2025-11-15 11:18:26,261 - INFO - [115/496] Success: 2312.15954 - 9 refs
# ...
# 2025-11-15 11:37:33,481 - INFO -     Dates: {'2312.16308v1': '2023-12-26', '2312.16308v2': '2024-01-28'}
# 2025-11-15 11:37:33,481 - INFO -
# [466/500] Processing 2312-16309
# 2025-11-15 11:37:33,481 - INFO - No tex directory or files in 2312-16309 - marking for deletion
# 2025-11-15 11:37:33,481 - INFO -
# [467/500] Processing 2312-16310
# 2025-11-15 11:37:33,481 - INFO - No tex directory or files in 2312-16310 - marking for deletion
# 2025-11-15 11:37:33,481 - INFO -
# [468/500] Processing 2312-16311
# 2025-11-15 11:37:33,481 - INFO - No tex directory or files in 2312-16311 - marking for deletion
# 2025-11-15 11:37:33,482 - INFO -
# [469/500] Processing 2312-16312
# ['2312.16312v1']
# 2025-11-15 11:37:33,482 - INFO - ✓ Updated 2312-16312:
# 2025-11-15 11:37:33,482 - INFO -     Versions: 1
# 2025-11-15 11:37:33,482 - INFO -     Dates: {'2312.16312v1': '2023-12-26'}
# 2025-11-15 11:37:33,482 - INFO -
# [470/500] Processing 2312-16313
# ['2312.16313v1', '2312.16313v2', '2312.16313v3']
# 2025-11-15 11:37:33,483 - INFO - ✓ Updated 2312-16313:
# 2025-11-15 11:37:33,483 - INFO -     Versions: 3
# 2025-11-15 11:37:33,483 - INFO -     Dates: {'2312.16313v1': '2023-12-26', '2312.16313v2': '2024-01-19', '2312.16313v3': '2024-04-20'}
# 2025-11-15 11:37:33,483 - INFO -
# [471/500] Processing 2312-16314
# ['2312.16314v1', '2312.16314v2']
# 2025-11-15 11:37:33,484 - INFO - ✓ Updated 2312-16314:
# 2025-11-15 11:37:33,484 - INFO -     Versions: 2
# 2025-11-15 11:37:33,484 - INFO -     Dates: {'2312.16314v1': '2023-12-26', '2312.16314v2': '2024-02-04'}
# 2025-11-15 11:37:33,484 - INFO -
# [472/500] Processing 2312-16315
# 2025-11-15 11:37:33,484 - INFO - No tex directory or files in 2312-16315 - marking for deletion
# 2025-11-15 11:37:33,484 - INFO -
# [473/500] Processing 2312-16316
# ['2312.16316v1']
# 2025-11-15 11:37:33,485 - INFO - ✓ Updated 2312-16316:
# 2025-11-15 11:37:33,485 - INFO -     Versions: 1
# 2025-11-15 11:37:33,485 - INFO -     Dates: {'2312.16316v1': '2023-12-26'}
# 2025-11-15 11:37:33,485 - INFO -
# [474/500] Processing 2312-16317
# ['2312.16317v1', '2312.16317v2']
# 2025-11-15 11:37:33,486 - INFO - ✓ Updated 2312-16317:
# 2025-11-15 11:37:33,486 - INFO -     Versions: 2
# 2025-11-15 11:37:33,486 - INFO -     Dates: {'2312.16317v1': '2023-12-26', '2312.16317v2': '2024-07-23'}
# 2025-11-15 11:37:33,486 - INFO -
# [475/500] Processing 2312-16318
# ['2312.16318v1', '2312.16318v2']
# 2025-11-15 11:37:33,487 - INFO - ✓ Updated 2312-16318:
# 2025-11-15 11:37:33,487 - INFO -     Versions: 2
# 2025-11-15 11:37:33,487 - INFO -     Dates: {'2312.16318v1': '2023-07-29', '2312.16318v2': '2024-07-17'}
# 2025-11-15 11:37:33,487 - INFO -
# [476/500] Processing 2312-16319
# ['2312.16319v1', '2312.16319v2']
# 2025-11-15 11:37:33,488 - INFO - ✓ Updated 2312-16319:
# 2025-11-15 11:37:33,488 - INFO -     Versions: 2
# 2025-11-15 11:37:33,488 - INFO -     Dates: {'2312.16319v1': '2023-12-26', '2312.16319v2': '2024-06-30'}
# 2025-11-15 11:37:33,488 - INFO -
# [477/500] Processing 2312-16320
# 2025-11-15 11:37:33,488 - INFO - No tex directory or files in 2312-16320 - marking for deletion
# 2025-11-15 11:37:33,489 - INFO -
# [478/500] Processing 2312-16321
# 2025-11-15 11:37:33,489 - INFO - No tex directory or files in 2312-16321 - marking for deletion
# 2025-11-15 11:37:33,489 - INFO -
# [479/500] Processing 2312-16322
# ['2312.16322v1', '2312.16322v2']
# 2025-11-15 11:37:33,490 - INFO - ✓ Updated 2312-16322:
# 2025-11-15 11:37:33,490 - INFO -     Versions: 2
# 2025-11-15 11:37:33,490 - INFO -     Dates: {'2312.16322v1': '2023-12-26', '2312.16322v2': '2024-03-25'}
# 2025-11-15 11:37:33,490 - INFO -
# [480/500] Processing 2312-16323
# ['2312.16323v1']
# 2025-11-15 11:37:33,490 - INFO - ✓ Updated 2312-16323:
# 2025-11-15 11:37:33,491 - INFO -     Versions: 1
# 2025-11-15 11:37:33,491 - INFO -     Dates: {'2312.16323v1': '2023-12-26'}
# 2025-11-15 11:37:33,491 - INFO -
# [481/500] Processing 2312-16324
# ['2312.16324v1']
# 2025-11-15 11:37:33,491 - INFO - ✓ Updated 2312-16324:
# 2025-11-15 11:37:33,491 - INFO -     Versions: 1
# 2025-11-15 11:37:33,491 - INFO -     Dates: {'2312.16324v1': '2023-12-26'}
# 2025-11-15 11:37:33,492 - INFO -
# [482/500] Processing 2312-16325
# ['2312.16325v1']
# 2025-11-15 11:37:33,492 - INFO - ✓ Updated 2312-16325:
# 2025-11-15 11:37:33,492 - INFO -     Versions: 1
# 2025-11-15 11:37:33,492 - INFO -     Dates: {'2312.16325v1': '2023-12-26'}
# 2025-11-15 11:37:33,493 - INFO -
# [483/500] Processing 2312-16326
# 2025-11-15 11:37:33,493 - INFO - No tex directory or files in 2312-16326 - marking for deletion
# 2025-11-15 11:37:33,493 - INFO -
# [484/500] Processing 2312-16327
# 2025-11-15 11:37:33,493 - INFO - No tex directory or files in 2312-16327 - marking for deletion
# 2025-11-15 11:37:33,493 - INFO -
# [485/500] Processing 2312-16328
# 2025-11-15 11:37:33,494 - INFO - No tex directory or files in 2312-16328 - marking for deletion
# 2025-11-15 11:37:33,494 - INFO -
# [486/500] Processing 2312-16329
# 2025-11-15 11:37:33,494 - INFO - No tex directory or files in 2312-16329 - marking for deletion
# 2025-11-15 11:37:33,494 - INFO -
# [487/500] Processing 2312-16330
# 2025-11-15 11:37:33,494 - INFO - No tex directory or files in 2312-16330 - marking for deletion
# 2025-11-15 11:37:33,494 - INFO -
# [488/500] Processing 2312-16331
# ['2312.16331v1']
# 2025-11-15 11:37:33,495 - INFO - ✓ Updated 2312-16331:
# 2025-11-15 11:37:33,495 - INFO -     Versions: 1
# 2025-11-15 11:37:33,495 - INFO -     Dates: {'2312.16331v1': '2023-12-26'}
# 2025-11-15 11:37:33,495 - INFO -
# [489/500] Processing 2312-16332
# ['2312.16332v1']
# 2025-11-15 11:37:33,496 - INFO - ✓ Updated 2312-16332:
# 2025-11-15 11:37:33,496 - INFO -     Versions: 1
# 2025-11-15 11:37:33,496 - INFO -     Dates: {'2312.16332v1': '2023-12-26'}
# 2025-11-15 11:37:33,496 - INFO -
# [490/500] Processing 2312-16333
# ['2312.16333v1']
# 2025-11-15 11:37:33,497 - INFO - ✓ Updated 2312-16333:
# 2025-11-15 11:37:33,497 - INFO -     Versions: 1
# 2025-11-15 11:37:33,497 - INFO -     Dates: {'2312.16333v1': '2023-12-26'}
# 2025-11-15 11:37:33,497 - INFO -
# [491/500] Processing 2312-16334
# ['2312.16334v1', '2312.16334v2', '2312.16334v3']
# 2025-11-15 11:37:33,498 - INFO - ✓ Updated 2312-16334:
# 2025-11-15 11:37:33,499 - INFO -     Versions: 3
# 2025-11-15 11:37:33,499 - INFO -     Dates: {'2312.16334v1': '2023-12-26', '2312.16334v2': '2024-02-06', '2312.16334v3': '2025-11-05'}
# 2025-11-15 11:37:33,499 - INFO -
# [492/500] Processing 2312-16335
# ['2312.16335v1', '2312.16335v2']
# 2025-11-15 11:37:33,500 - INFO - ✓ Updated 2312-16335:
# 2025-11-15 11:37:33,500 - INFO -     Versions: 2
# 2025-11-15 11:37:33,500 - INFO -     Dates: {'2312.16335v1': '2023-12-26', '2312.16335v2': '2024-04-03'}
# 2025-11-15 11:37:33,500 - INFO -
# [493/500] Processing 2312-16336
# ['2312.16336v1']
# 2025-11-15 11:37:33,501 - INFO - ✓ Updated 2312-16336:
# 2025-11-15 11:37:33,501 - INFO -     Versions: 1
# 2025-11-15 11:37:33,501 - INFO -     Dates: {'2312.16336v1': '2023-12-26'}
# 2025-11-15 11:37:33,501 - INFO -
# [494/500] Processing 2312-16337
# ['2312.16337v1']
# 2025-11-15 11:37:33,544 - INFO - ✓ Updated 2312-16337:
# 2025-11-15 11:37:33,545 - INFO -     Versions: 1
# 2025-11-15 11:37:33,545 - INFO -     Dates: {'2312.16337v1': '2023-12-26'}
# 2025-11-15 11:37:33,545 - INFO -
# [495/500] Processing 2312-16338
# ['2312.16338v1']
# 2025-11-15 11:37:33,545 - INFO - ✓ Updated 2312-16338:
# 2025-11-15 11:37:33,546 - INFO -     Versions: 1
# 2025-11-15 11:37:33,546 - INFO -     Dates: {'2312.16338v1': '2023-12-26'}
# 2025-11-15 11:37:33,546 - INFO -
# [496/500] Processing 2312-16339
# ['2312.16339v1']
# 2025-11-15 11:37:33,546 - INFO - ✓ Updated 2312-16339:
# 2025-11-15 11:37:33,546 - INFO -     Versions: 1
# 2025-11-15 11:37:33,546 - INFO -     Dates: {'2312.16339v1': '2023-12-26'}
# 2025-11-15 11:37:33,547 - INFO -
# [497/500] Processing 2312-16340
# ['2312.16340v1', '2312.16340v2']
# 2025-11-15 11:37:33,547 - INFO - ✓ Updated 2312-16340:
# 2025-11-15 11:37:33,547 - INFO -     Versions: 2
# 2025-11-15 11:37:33,547 - INFO -     Dates: {'2312.16340v1': '2023-12-26', '2312.16340v2': '2025-05-16'}
# 2025-11-15 11:37:33,547 - INFO -
# [498/500] Processing 2312-16341
# ['2312.16341v1', '2312.16341v2']
# 2025-11-15 11:37:33,548 - INFO - ✓ Updated 2312-16341:
# 2025-11-15 11:37:33,548 - INFO -     Versions: 2
# 2025-11-15 11:37:33,548 - INFO -     Dates: {'2312.16341v1': '2023-12-26', '2312.16341v2': '2024-09-16'}
# 2025-11-15 11:37:33,548 - INFO -
# [499/500] Processing 2312-16342
# ['2312.16342v1', '2312.16342v2', '2312.16342v3', '2312.16342v4']
# 2025-11-15 11:37:33,550 - INFO - ✓ Updated 2312-16342:
# 2025-11-15 11:37:33,550 - INFO -     Versions: 4
# 2025-11-15 11:37:33,550 - INFO -     Dates: {'2312.16342v1': '2023-12-26', '2312.16342v2': '2023-12-29', '2312.16342v3': '2024-02-02', '2312.16342v4': '2025-05-27'}
# 2025-11-15 11:37:33,550 - INFO -
# [500/500] Processing 2312-16343
# ['2312.16343v1', '2312.16343v2']
# 2025-11-15 11:37:33,551 - INFO - ✓ Updated 2312-16343:
# 2025-11-15 11:37:33,551 - INFO -     Versions: 2
# 2025-11-15 11:37:33,551 - INFO -     Dates: {'2312.16343v1': '2023-12-26', '2312.16343v2': '2024-05-29'}
# 2025-11-15 11:37:33,551 - INFO -
# ================================================================================
# 2025-11-15 11:37:33,551 - INFO - Found 81 papers without .tex files (not deleted)
# 2025-11-15 11:37:33,551 - INFO - ================================================================================
# 2025-11-15 11:37:33,551 - INFO -   - 2312-15849
# 2025-11-15 11:37:33,551 - INFO -   - 2312-15850
# 2025-11-15 11:37:33,551 - INFO -   - 2312-15852
# 2025-11-15 11:37:33,551 - INFO -   - 2312-15862
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15865
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15876
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15884
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15886
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15887
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15888
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15899
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15913
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15917
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15919
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15920
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15930
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15933
# 2025-11-15 11:37:33,552 - INFO -   - 2312-15937
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15938
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15939
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15945
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15952
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15953
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15969
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15976
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15977
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15978
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15981
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15988
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15991
# 2025-11-15 11:37:33,553 - INFO -   - 2312-15993
# 2025-11-15 11:37:33,553 - INFO -   - 2312-16005
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16017
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16021
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16030
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16049
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16058
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16068
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16090
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16094
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16097
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16099
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16105
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16111
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16112
# 2025-11-15 11:37:33,554 - INFO -   - 2312-16128
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16130
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16133
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16136
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16138
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16140
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16153
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16155
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16158
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16194
# 2025-11-15 11:37:33,555 - INFO -   - 2312-16200
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16205
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16208
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16219
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16226
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16234
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16235
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16236
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16238
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16254
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16269
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16271
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16273
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16277
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16299
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16309
# 2025-11-15 11:37:33,556 - INFO -   - 2312-16310
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16311
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16315
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16320
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16321
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16326
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16327
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16328
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16329
# 2025-11-15 11:37:33,557 - INFO -   - 2312-16330
# 2025-11-15 11:37:33,558 - INFO -
# --- Cleaning up temporary files ---
# 2025-11-15 11:37:33,623 - INFO - Success: Cleaned up temp directory
# 2025-11-15 11:37:33,623 - INFO -
# ================================================================================
# 2025-11-15 11:37:33,623 - INFO - Pipeline completed!
# 2025-11-15 11:37:33,623 - INFO - ================================================================================
# 2025-11-15 11:37:33,623 - INFO -
# Summary:
# 2025-11-15 11:37:33,624 - INFO -   Total papers: 500
# 2025-11-15 11:37:33,624 - INFO -   Already complete: 0
# 2025-11-15 11:37:33,624 - INFO -   Downloaded: 496
# 2025-11-15 11:37:33,624 - INFO -   Failed downloads: 4
# 2025-11-15 11:37:33,624 - INFO -   With references: 495
# 2025-11-15 11:37:33,624 - INFO -   Without references: 1
# 2025-11-15 11:37:37,115 - INFO - Statistics tracking completed
# 2025-11-15 11:37:37,117 - INFO - Statistics saved to /content/arxiv_scraper/data/statistics_final.json
# 2025-11-15 11:37:37,121 - INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251115_113737.json
#
# ================================================================================
# SCRAPING STATISTICS REPORT
# ================================================================================
#
# TIME INFORMATION:
#   Start Time: 2025-11-15 11:11:01.858558
#   End Time: 2025-11-15 11:37:36.989413
#   Total Duration: 0:26:35
#
# PHASE DURATIONS:
#   Metadata Harvesting (arXiv API): 0:00:15
#   Source Download (Parallel): 0:01:25
#   Reference Extraction (Parallel): 0:24:48
#
# PAPER STATISTICS:
#   Total Identified: 500
#   Total Attempted: 500
#   Successfully Downloaded: 496
#   Failed Downloads: 4
#   Success Rate: 99.20%
#
# VERSION STATISTICS:
#   Total Versions: 848
#   Successfully Processed: 844
#   Failed Versions: 4
#
# PERFORMANCE METRICS:
#   Average Time per Paper: 0.00s
#   Fastest Paper: 0.00s
#   Slowest Paper: 0.00s
#
# FILE SIZE STATISTICS:
#   Average Size Before Figure Removal: 4.13 MB
#   Average Size After Figure Removal: 518.19 KB
#   Total Raw Size: 3.40 GB
#   Total Extracted Size: 427.10 MB
#   Space Saved: 2.99 GB
#   Figures Removed: 16478
#
# REFERENCE STATISTICS:
#   Papers with References: 466
#   Papers without References: 30
#   Total References: 20253
#   Average References per Paper: 43.46
#   Reference Success Rate: 93.95%
#
# MEMORY USAGE:
#   Initial RAM: 35.85 MB
#   Peak RAM: 317.88 MB
#   Average RAM: 292.41 MB
#   Initial Disk Usage: 0.00 GB
#   Final Disk Usage: 0.37 GB
#   Disk Space Used: 0.37 GB
#
# ERROR STATISTICS:
#   Total Errors: 9
#   Error Types:
#     Download request error: HTTPError: 4
#     Download error: TypeError: 4
#     Reference not found (404): 1
#
# ================================================================================
# 2025-11-15 11:37:37,122 - INFO -
# Statistics: /content/arxiv_scraper/data/statistics_final.json
# 2025-11-15 11:37:37,122 - INFO - Papers: /content/arxiv_scraper/data/papers

# %%
# !zip -r scrape_data.zip /content/arxiv_scraper/data/papers
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/1_intro.tex (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/2_related_short.tex (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/X_suppl.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/5_conclusion.tex (deflated 38%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/4_experiments.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/3_method.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/sec/0_abstract.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/preamble.tex (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/tex/2312.16145v1/main.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16145/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/references.json (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/tex/2312.15851v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/tex/2312.15851v1/sample-authordraft.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/tex/2312.15851v1/sample-base.bib (deflated 75%)
#   adding: content/arxiv_scraper/data/papers/2312-15851/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/references.json (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v2/LFT-gen-arXiv-v2.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v3/LFT-gen-arXiv-v3.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v1/no-revtex.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v1/LFT-gen-arXiv-v1.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/tex/2312.16284v1/jm-tex-macros-public.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16284/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15954/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15954/references.json (deflated 28%)
#   adding: content/arxiv_scraper/data/papers/2312-15954/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15954/tex/2312.15954v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15954/tex/2312.15954v2/main.tex (deflated 86%)
#   adding: content/arxiv_scraper/data/papers/2312-15954/metadata.json (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/references.json (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v1/arxiv.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v1/refs.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v3/iclr2024_camera_ready.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v3/math_commands.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v3/refs.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v2/iclr2024_camera_ready.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v2/math_commands.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/tex/2312.16168v2/refs.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16168/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/references.json (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/tex/2312.15949v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/tex/2312.15949v1/iclr2023_conference.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/tex/2312.15949v1/iclr2023_conference.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/tex/2312.15949v1/math_commands.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-15949/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/tex/2312.16278v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/tex/2312.16278v1/sn-article.tex (deflated 76%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/tex/2312.16278v1/bib.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16278/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16288/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16288/references.json (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16288/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16288/tex/2312.16288v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16288/tex/2312.16288v1/main.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16288/metadata.json (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/tex/2312.15916v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/tex/2312.15916v1/camera_ready.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/tex/2312.15916v1/aaai24.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-15916/metadata.json (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/references.json (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/1_intro.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/algo/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/algo/algo.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/X_suppl.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/5_Conclusion.tex (deflated 60%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/4_results.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/3_methods.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/merge_3_and_6_models.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Domain_Adaptation_Appendix.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/TA_task_imagenet.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/merge_12_models.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Table1.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/TA_domain.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/TA_DA.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/merge_models_on_imagenet.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/TA_task.tex (deflated 60%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Merge_results_on_domains.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Domain_Adaptation.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Gating_Effectiveness.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Ablation_Study.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Domain_individual.tex (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/maintabs/Ablation_Study_2.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/0_abstract.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/sec/2_related_work.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/preamble.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/main.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/main.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/tex/2312.16240v1/rebuttal.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-16240/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/references.json (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_dtu.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_abl.tex (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_render.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_abl_new.tex (deflated 39%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_seg.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_mesh.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/tables/tab_nerf.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/supp.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/1_intro.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/2_related.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/3_main.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/4_exp.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/5_sup.tex (deflated 32%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/sec/0_abstract.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/preamble.tex (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/main.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/main.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v3/rebuttal.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/tables/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/tables/tab_abl.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/tables/tab_render.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/tables/tab_seg.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/tables/tab_mesh.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/seal.bib (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sam.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/main_arxiv.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/1_intro.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/2_related.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/X_suppl.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/4_experiment.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/5_conclusion.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/3_method.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/sec/0_abstract.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/preamble.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v2/main.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/tables/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/tables/tab_abl.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/tables/tab_render.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/tables/tab_seg.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/tables/tab_mesh.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/seal.bib (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sam.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/main_arxiv.tex (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/1_intro.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/2_related.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/X_suppl.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/4_experiment.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/5_conclusion.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/3_method.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/sec/0_abstract.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/preamble.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/tex/2312.15856v1/main.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15856/metadata.json (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/references.json (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/2312.16011v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/2312.16011v3/TSDP.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/2312.16011v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/2312.16011v2/TSDP.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/2312.16011v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/tex/2312.16011v1/TSDP.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16011/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16121/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16121/references.json (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16121/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16121/tex/2312.16121v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16121/tex/2312.16121v1/scifile.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16121/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/references.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/tex/2312.16152v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/tex/2312.16152v2/Polynomial_Reconstruction_Problem_for_Hypergraphs_-_improved_arxiv.tex (deflated 75%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/tex/2312.16152v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/tex/2312.16152v1/Polynomial_Reconstruction_Problem_for_Hypergraphs_-_arxiv.tex (deflated 75%)
#   adding: content/arxiv_scraper/data/papers/2312-16152/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/tex/2312.16291v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/tex/2312.16291v1/math_commands.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/tex/2312.16291v1/main.tex (deflated 76%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/tex/2312.16291v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/tex/2312.16291v2/main.tex (deflated 75%)
#   adding: content/arxiv_scraper/data/papers/2312-16291/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/tex/2312.15971v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/tex/2312.15971v1/GCT-Net.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/tex/2312.15971v1/mybib.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15971/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-15992/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15992/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15992/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15992/tex/2312.15992v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15992/tex/2312.15992v1/main.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-15992/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/tex/2312.16102v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/tex/2312.16102v1/References.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/tex/2312.16102v1/main.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16102/metadata.json (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/references.json (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/tex/2312.16325v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/tex/2312.16325v1/QI-Invariance.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/tex/2312.16325v1/QI-Invariance.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16325/metadata.json (deflated 43%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/references.json (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/tex/2312.16186v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/tex/2312.16186v1/hstaccel_revision_for_publisher.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/tex/2312.16186v1/biblio.bib (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16186/metadata.json (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/references.json (deflated 27%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/2312.16289v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/2312.16289v1/library.bib (deflated 75%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/2312.16289v1/paper4.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/2312.16289v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/2312.16289v2/library.bib (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/tex/2312.16289v2/paper4.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16289/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v1/main.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v1/bibfile.bib (deflated 78%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v3/main.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v3/bibfile.bib (deflated 78%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v2/main.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/tex/2312.15874v2/bibfile.bib (deflated 78%)
#   adding: content/arxiv_scraper/data/papers/2312-15874/metadata.json (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16068/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16068/references.json (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16068/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16068/metadata.json (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/references.json (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v1/draft.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v1/draft.bib (deflated 81%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v3/draft.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v3/draft.bib (deflated 81%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v2/draft.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/tex/2312.15904v2/draft.bib (deflated 81%)
#   adding: content/arxiv_scraper/data/papers/2312-15904/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16010/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16010/references.json (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2312-16010/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16010/tex/2312.16010v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16010/tex/2312.16010v1/DareFightingICE-New.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16010/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v1/bibliography.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v1/main.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v2/bibliography.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v2/supplementary.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/tex/2312.16024v2/main.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16024/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/references.json (deflated 43%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/2312.16033v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/2312.16033v1/main.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/2312.16033v1/bibtex.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/2312.16033v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/2312.16033v2/main.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/tex/2312.16033v2/bibtex.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16033/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/prelim.tex (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/arXiv.bib (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/mbrb_algo_v3.1_TS.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/correctnessAnalysis.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/arXiv.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/sec-intro_compacted.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/fig/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/fig/msg-dist.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/fig/msg-distNew.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v2/sec-intro_initial.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/prelim.tex (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/sec-intro_compacted.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/mbrb_algo_v3.1.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/main_v2_v3.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/fig/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/fig/msg-dist.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/main.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/tex/2312.16253v1/sec-intro_initial.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16253/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/references.json (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/2312.16295v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/2312.16295v1/custom-commands.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/2312.16295v1/Qcos-draft-combined.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/2312.16295v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/2312.16295v2/refs-Qcos-draft-combined.bib (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/tex/2312.16295v2/main.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16295/metadata.json (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-16213/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16213/references.json (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16213/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16213/tex/2312.16213v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16213/tex/2312.16213v1/arxiv.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16213/metadata.json (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/references.json (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/abstract.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/ref.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/appendixJournal.tex (deflated 80%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/exact.tex (deflated 76%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/lipics-v2021-sample-article.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/conclusion.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/oldMultApprox.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/img/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/img/interval_pic.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/preliminaries.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/main.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/introduction.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/lowerbound.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/appendix.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/partitioning.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v3/approximation.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/abstract.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/ref.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/appendixJournal.tex (deflated 80%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/exact.tex (deflated 76%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/lipics-v2021-sample-article.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/conclusion.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/coverletter.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/oldMultApprox.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/img/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/img/interval_pic.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/preliminaries.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/main.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/introduction.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/lowerbound.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/appendix.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/partitioning.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v4/approximation.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/abstract.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/ref.bib (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/exact.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/lipics-v2021-sample-article.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/conclusion.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/oldMultApprox.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/preliminaries.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/main.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/introduction.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/lowerbound.tex (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/appendix.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/partitioning.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v1/approximation.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/abstract.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/ref.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/exact.tex (deflated 75%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/lipics-v2021-sample-article.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/conclusion.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/oldMultApprox.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/img/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/img/interval_pic.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/preliminaries.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/main.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/introduction.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/lowerbound.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/appendix.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/partitioning.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v2/approximation.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/abstract.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/ref.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/appendixJournal.tex (deflated 80%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/exact.tex (deflated 76%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/lipics-v2021-sample-article.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/conclusion.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/coverletter.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/oldMultApprox.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/img/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/img/interval_pic.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/preliminaries.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/main.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/introduction.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/lowerbound.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/appendix.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/partitioning.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/tex/2312.15959v5/approximation.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2312-15959/metadata.json (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-15913/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15913/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-15913/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15913/metadata.json (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-15902/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15902/references.json (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-15902/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15902/tex/2312.15902v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15902/tex/2312.15902v1/Eigenvalues_and_factors_a_survey.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-15902/metadata.json (deflated 43%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/references.json (deflated 21%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v3/virial_mnras.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v3/apssamp.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v2/virial_mnras.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v2/apssamp.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v1/apssamp.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/tex/2312.16252v1/main.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16252/metadata.json (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/references.json (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/tex/2312.16185v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/tex/2312.16185v1/aipsamp.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/tex/2312.16185v1/aipsamp.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16185/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/references.json (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/sect2_relatedwork.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/sect1_intro.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/sect4_experiment.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/REF.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/sect5_conclution.tex (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/sect3_method.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v2/RL-LLM.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/sect2_relatedwork.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/sect1_intro.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/sect4_experiment.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/REF.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/sect5_conclution.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/sect3_method.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/sect6_acknowledgments.tex (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/tex/2312.16275v1/RL-LLM.tex (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16275/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16140/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16140/references.json (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16140/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16140/metadata.json (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/references.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/tex/2312.16188v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/tex/2312.16188v1/references.bib (deflated 42%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/tex/2312.16188v1/main.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16188/metadata.json (deflated 43%)
#   adding: content/arxiv_scraper/data/papers/2312-16236/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16236/references.json (deflated 42%)
#   adding: content/arxiv_scraper/data/papers/2312-16236/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16236/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16079/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16079/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16079/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16079/tex/2312.16079v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16079/tex/2312.16079v1/Coexistence_assessment_and_interference_mitigation_for_5G_and_Fixed_Satellite_Stations_in_C-band_in_India_arxiv_2023_12_25_copy.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16079/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16022/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16022/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16022/tex/2312.16022v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16022/tex/2312.16022v1/main.tex (deflated 75%)
# ...
#   adding: content/arxiv_scraper/data/papers/2312-16064/references.json (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-16064/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16064/tex/2312.16064v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16064/tex/2312.16064v1/IEEE_Network_SCCGC.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16064/tex/2312.16064v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16064/tex/2312.16064v2/IEEE_Network_SCCGC.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16064/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/references.json (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v1/ex_supplement.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v1/references.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v1/ex_shared.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v1/LP20231218V1.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v1/ex_sharedV.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v2/LP20240415V1.tex (deflated 76%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v2/references.bib (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v2/ex_sharedV.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v3/ex_supplement.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v3/references.bib (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v3/ex_sharedV.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/tex/2312.16116v3/LP20240612V1.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2312-16116/metadata.json (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/references.json (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/tables/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/tables/lib_compare.tex (deflated 80%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main_texts/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main_texts/4_conclusion.tex (deflated 39%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main_texts/3_design_of_openrl.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main_texts/1_introduction.tex (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main_texts/2_related_work.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main_texts/0_abstact.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/figures/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/figures/code_example.tex (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/figures/code_example2.tex (deflated 18%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/figures/framework.tex (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/main.tex (deflated 55%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/sample.bib (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/appendix/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/appendix/0_appendix_A.tex (deflated 22%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/appendix/3_deepspeed.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/appendix/2_NLP_compare.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/appendix/1_appendix_B.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/tex/2312.16189v1/appendix/appendix_lib_compare.tex (deflated 15%)
#   adding: content/arxiv_scraper/data/papers/2312-16189/metadata.json (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/references.json (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/2312.16250v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/2312.16250v1/sn-article.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/2312.16250v1/sn-bibliography.bib (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/2312.16250v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/2312.16250v2/sn-article.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/tex/2312.16250v2/sn-bibliography.bib (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16250/metadata.json (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-16158/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16158/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16158/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16158/metadata.json (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/references.json (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/tex/2312.16081v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/tex/2312.16081v2/TOV-two_columns_un-Marked_.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/tex/2312.16081v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/tex/2312.16081v1/3d_tov_main_v1.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16081/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/tex/2312.16339v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/tex/2312.16339v1/math_commands.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/tex/2312.16339v1/main.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/tex/2312.16339v1/main.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16339/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16239/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16239/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16239/tex/2312.16239v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16239/tex/2312.16239v1/pnl-to-hol.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16239/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/references.json (deflated 29%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/tex/2312.16004v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/tex/2312.16004v1/20231127.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/tex/2312.16004v1/20231127.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16004/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/references.json (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v1/main.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v1/main.bib (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v3/main.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v3/main.bib (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v2/main.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/tex/2312.16192v2/main.bib (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16192/metadata.json (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16123/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16123/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16123/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16123/tex/2312.16123v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16123/tex/2312.16123v1/paper2.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16123/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16241/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16241/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16241/tex/2312.16241v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16241/tex/2312.16241v1/paper.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16241/tex/2312.16241v1/paper.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16241/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-16112/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16112/references.json (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16112/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16112/metadata.json (deflated 42%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/references.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/tex/2312.16078v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/tex/2312.16078v1/arxiv_version.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/tex/2312.16078v1/all_refs.bib (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16078/metadata.json (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-15945/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15945/references.json (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-15945/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15945/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-15866/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15866/references.json (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-15866/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15866/tex/2312.15866v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-15866/tex/2312.15866v1/revised_version.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-15866/metadata.json (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/references.json (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Experiments.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Conclusion.tex (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/StudyareaandCriteria.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/ref.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Appendices.tex (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Relatedwork.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Method.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Introduction.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/main.tex (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Acknowledgements.tex (deflated 40%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v2/Response.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/ref.tex (deflated 17%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Experiments.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Conclusion.tex (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/ref.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Appendices.tex (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Relatedwork.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Method.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Study_area_and_Criteria.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Introduction.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/main.tex (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/tex/2312.16046v1/Acknowledgements.tex (deflated 40%)
#   adding: content/arxiv_scraper/data/papers/2312-16046/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16302/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16302/references.json (deflated 43%)
#   adding: content/arxiv_scraper/data/papers/2312-16302/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16302/tex/2312.16302v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16302/tex/2312.16302v1/sol.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2312-16302/metadata.json (deflated 39%)
#   adding: content/arxiv_scraper/data/papers/2312-16310/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16310/references.json (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16310/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16310/metadata.json (deflated 43%)

# %%
# %rm -rf /content/arxiv_scraper
