# %%
# Setup and Installation
# %pip install arxiv requests psutil
# Out:
# Requirement already satisfied: arxiv in /usr/local/lib/python3.12/dist-packages (2.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Requirement already satisfied: feedparser~=6.0.10 in /usr/local/lib/python3.12/dist-packages (from arxiv) (6.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.12/dist-packages (from feedparser~=6.0.10->arxiv) (1.0.0)

# %%
from pathlib import Path
import os

BASE_DIR = Path("/content/arxiv_scraper")
BASE_DIR.mkdir(exist_ok=True)
os.chdir(BASE_DIR)

# Create subdirectories
for dir_name in ["lib", "data", "logs", "data/papers", "data/temp", "data/statistics"]:
    (BASE_DIR / dir_name).mkdir(parents=True, exist_ok=True)

print("Directory structure created")
# Out:
# Directory structure created

# %%
# %%writefile config.py
import os
from pathlib import Path

# Project paths
BASE_DIR = Path("/content/arxiv_scraper")
DATA_DIR = BASE_DIR / "data"
PAPERS_DIR = DATA_DIR / "papers"
TEMP_DIR = DATA_DIR / "temp"
LOGS_DIR = BASE_DIR / "logs"
STATS_DIR = DATA_DIR / "statistics"

# Create directories if they don't exist
for directory in [PAPERS_DIR, TEMP_DIR, LOGS_DIR, STATS_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

# arXiv settings
ARXIV_ID_RANGES = [
    ("2312", 15844, 99999),
    ("2401", 0, 3095),
]

# API settings
SEMANTIC_SCHOLAR_API_BASE = "https://api.semanticscholar.org/graph/v1"
REQUEST_DELAY = 1
MAX_RETRIES = 5
RETRY_DELAY = 3.0

# Semantic Scholar fields
SEMANTIC_SCHOLAR_FIELDS = "references,references.title,references.authors,references.year,references.paperId,references.externalIds"
SEMANTIC_KEY_API = "FkKyqq5p9R96KizMlPWBwa0YtPjCvyq24ddno82O"

# arXiv API settings
ARXIV_MAX_RESULTS = 100
ARXIV_DELAY = 3.0
ARXIV_BATCH_SIZE = 100

# Download settings
DOWNLOAD_BATCH_SIZE = 3  # Reduced for Colab
FIGURE_EXTENSIONS = ['.png', '.jpg', '.jpeg', '.pdf', '.eps', '.ps', '.gif', '.svg', '.bmp']

# File size limits
MAX_FILE_SIZE = 100 * 1024 * 1024

# Stats settings
STATS_SAVE_INTERVAL = 10

# Cleanup settings
DELETE_RAW_AFTER_EXTRACT = True
DELETE_TEMP_AFTER_COPY = True
# Out:
# Overwriting config.py

# %%
# %%writefile lib/statistics_tracker.py
import psutil
import time
import json
from pathlib import Path
from datetime import datetime, timedelta
from typing import Dict, Any, Optional
import logging
import config

logger = logging.getLogger(__name__)


class StatisticsTracker:
    """Track and report statistics for the scraping process."""

    def __init__(self):
        self.stats = {
            'start_time': None,
            'end_time': None,
            'total_duration': 0,

            # Paper statistics
            'papers': {
                'total_identified': 0,
                'total_attempted': 0,
                'successfully_downloaded': 0,
                'failed_downloads': 0,
                'download_success_rate': 0,
            },

            # Version statistics
            'versions': {
                'total_versions': 0,
                'successfully_processed': 0,
                'failed_versions': 0,
            },

            # File size statistics
            'file_sizes': {
                'raw_sizes': [],  # Size before removing figures
                'extracted_sizes': [],  # Size after removing figures
                'total_raw_size': 0,
                'total_extracted_size': 0,
                'average_raw_size': 0,
                'average_extracted_size': 0,
                'space_saved_by_figure_removal': 0,
                'figures_removed': 0,
            },

            # Reference statistics
            'references': {
                'papers_with_references': 0,
                'papers_without_references': 0,
                'total_references': 0,
                'average_references_per_paper': 0,
                'reference_success_rate': 0,
            },

            # Performance metrics
            'performance': {
                'phase_times': {},  # Time for each phase
                'paper_processing_times': [],
                'average_time_per_paper': 0,
                'fastest_paper_time': float('inf'),
                'slowest_paper_time': 0,
            },

            # Memory statistics
            'memory': {
                'initial_ram_mb': 0,
                'peak_ram_mb': 0,
                'average_ram_mb': 0,
                'ram_samples': [],
                'initial_disk_gb': 0,
                'final_disk_gb': 0,
                'disk_space_used_gb': 0,
            },

            # Errors
            'errors': {
                'total_errors': 0,
                'error_types': {},
            }
        }

        self.process = psutil.Process()
        self.current_phase = None
        self.phase_start_time = None
        self.papers_processed_since_save = 0
        self.save_interval = config.STATS_SAVE_INTERVAL

    def start(self):
        """Start tracking."""
        self.stats['start_time'] = datetime.now()
        self.stats['memory']['initial_ram_mb'] = self.process.memory_info().rss / (1024 * 1024)
        self.stats['memory']['initial_disk_gb'] = self._get_disk_usage()
        logger.info("Statistics tracking started")

        # Try to load existing stats if resuming
        self.load_checkpoint()

    def end(self):
        """End tracking and calculate final statistics."""
        self.stats['end_time'] = datetime.now()
        self.stats['total_duration'] = (self.stats['end_time'] - self.stats['start_time']).total_seconds()

        # Calculate final memory stats
        self.stats['memory']['final_disk_gb'] = self._get_disk_usage()
        self.stats['memory']['disk_space_used_gb'] = (
            self.stats['memory']['final_disk_gb'] - self.stats['memory']['initial_disk_gb']
        )

        if self.stats['memory']['ram_samples']:
            self.stats['memory']['average_ram_mb'] = sum(self.stats['memory']['ram_samples']) / len(self.stats['memory']['ram_samples'])

        # Calculate success rates
        if self.stats['papers']['total_attempted'] > 0:
            self.stats['papers']['download_success_rate'] = (
                self.stats['papers']['successfully_downloaded'] / self.stats['papers']['total_attempted']
            ) * 100

        # Calculate reference success rate
        total_ref_attempts = (
            self.stats['references']['papers_with_references'] +
            self.stats['references']['papers_without_references']
        )
        if total_ref_attempts > 0:
            self.stats['references']['reference_success_rate'] = (
                self.stats['references']['papers_with_references'] / total_ref_attempts
            ) * 100

        # Calculate average references per paper
        if self.stats['references']['papers_with_references'] > 0:
            self.stats['references']['average_references_per_paper'] = (
                self.stats['references']['total_references'] /
                self.stats['references']['papers_with_references']
            )

        # Calculate file size averages
        if self.stats['file_sizes']['raw_sizes']:
            self.stats['file_sizes']['average_raw_size'] = (
                sum(self.stats['file_sizes']['raw_sizes']) / len(self.stats['file_sizes']['raw_sizes'])
            )
            self.stats['file_sizes']['total_raw_size'] = sum(self.stats['file_sizes']['raw_sizes'])

        if self.stats['file_sizes']['extracted_sizes']:
            self.stats['file_sizes']['average_extracted_size'] = (
                sum(self.stats['file_sizes']['extracted_sizes']) / len(self.stats['file_sizes']['extracted_sizes'])
            )
            self.stats['file_sizes']['total_extracted_size'] = sum(self.stats['file_sizes']['extracted_sizes'])

        self.stats['file_sizes']['space_saved_by_figure_removal'] = (
            self.stats['file_sizes']['total_raw_size'] - self.stats['file_sizes']['total_extracted_size']
        )

        # Calculate average time per paper
        if self.stats['performance']['paper_processing_times']:
            self.stats['performance']['average_time_per_paper'] = (
                sum(self.stats['performance']['paper_processing_times']) /
                len(self.stats['performance']['paper_processing_times'])
            )
            self.stats['performance']['fastest_paper_time'] = min(self.stats['performance']['paper_processing_times'])
            self.stats['performance']['slowest_paper_time'] = max(self.stats['performance']['paper_processing_times'])

        logger.info("Statistics tracking completed")

    def start_phase(self, phase_name: str):
        """Start tracking a processing phase."""
        self.current_phase = phase_name
        self.phase_start_time = time.time()
        logger.info(f"Started phase: {phase_name}")

    def end_phase(self):
        """End tracking current phase."""
        if self.current_phase and self.phase_start_time:
            duration = time.time() - self.phase_start_time
            self.stats['performance']['phase_times'][self.current_phase] = duration
            logger.info(f"Completed phase '{self.current_phase}' in {duration:.2f}s")
            self.current_phase = None
            self.phase_start_time = None

    def record_paper_identified(self):
        """Record a paper was identified."""
        self.stats['papers']['total_identified'] += 1

    def record_paper_attempt(self):
        """Record a paper download attempt."""
        self.stats['papers']['total_attempted'] += 1

    def record_paper_success(self, processing_time: float):
        """Record successful paper processing."""
        self.stats['papers']['successfully_downloaded'] += 1
        self.stats['performance']['paper_processing_times'].append(processing_time)

    def record_paper_failure(self):
        """Record failed paper processing."""
        self.stats['papers']['failed_downloads'] += 1

    def record_version(self, success: bool = True):
        """Record version processing."""
        self.stats['versions']['total_versions'] += 1
        if success:
            self.stats['versions']['successfully_processed'] += 1
        else:
            self.stats['versions']['failed_versions'] += 1

    def record_file_sizes(self, raw_size: int, extracted_size: int, figures_removed: int = 0):
        """Record file sizes before and after figure removal."""
        self.stats['file_sizes']['raw_sizes'].append(raw_size)
        self.stats['file_sizes']['extracted_sizes'].append(extracted_size)
        self.stats['file_sizes']['figures_removed'] += figures_removed

    def record_references(self, reference_count: int):
        """Record reference extraction."""
        if reference_count > 0:
            self.stats['references']['papers_with_references'] += 1
            self.stats['references']['total_references'] += reference_count
        else:
            self.stats['references']['papers_without_references'] += 1

    def record_error(self, error_type: str):
        """Record an error."""
        self.stats['errors']['total_errors'] += 1
        if error_type not in self.stats['errors']['error_types']:
            self.stats['errors']['error_types'][error_type] = 0
        self.stats['errors']['error_types'][error_type] += 1

    def sample_memory(self):
        """Sample current memory usage."""
        current_ram_mb = self.process.memory_info().rss / (1024 * 1024)
        self.stats['memory']['ram_samples'].append(current_ram_mb)

        if current_ram_mb > self.stats['memory']['peak_ram_mb']:
            self.stats['memory']['peak_ram_mb'] = current_ram_mb

    def _get_disk_usage(self) -> float:
        """Get current disk usage of data directory in GB."""
        total_size = 0
        try:
            for path in config.DATA_DIR.rglob('*'):
                if path.is_file():
                    total_size += path.stat().st_size
        except Exception as e:
            logger.warning(f"Error calculating disk usage: {e}")
        return total_size / (1024 ** 3)  # Convert to GB

    def get_summary(self) -> Dict[str, Any]:
        """Get statistics summary."""
        return self.stats

    def save_to_file(self, output_path: Optional[Path] = None):
        """Save statistics to JSON file."""
        if output_path is None:
            output_path = config.DATA_DIR / 'statistics.json'

        # Convert datetime objects to strings
        stats_copy = self._serialize_stats(self.stats)

        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(stats_copy, f, indent=2)

        logger.info(f"Statistics saved to {output_path}")

    def save_checkpoint(self):
        """Save incremental checkpoint."""
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        checkpoint_file = config.STATS_DIR / f'checkpoint_{timestamp}.json'

        # Also save to latest checkpoint
        latest_file = config.STATS_DIR / 'checkpoint_latest.json'

        stats_copy = self._serialize_stats(self.stats)

        for file_path in [checkpoint_file, latest_file]:
            try:
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(stats_copy, f, indent=2)
            except Exception as e:
                logger.error(f"Error saving checkpoint to {file_path}: {e}")

        logger.info(f"Checkpoint saved to {checkpoint_file}")
        self.papers_processed_since_save = 0

    def load_checkpoint(self):
        """Load latest checkpoint if exists."""
        latest_file = config.STATS_DIR / 'checkpoint_latest.json'

        if latest_file.exists():
            try:
                with open(latest_file, 'r', encoding='utf-8') as f:
                    loaded_stats = json.load(f)

                # Merge loaded stats with current stats
                # Convert string dates back to datetime
                if 'start_time' in loaded_stats and loaded_stats['start_time']:
                    self.stats['start_time'] = datetime.fromisoformat(loaded_stats['start_time'])

                # Merge other stats
                for key in loaded_stats:
                    if key not in ['start_time', 'end_time']:
                        if isinstance(loaded_stats[key], dict):
                            self.stats[key].update(loaded_stats[key])
                        else:
                            self.stats[key] = loaded_stats[key]

                logger.info(f"Resumed from checkpoint: {latest_file}")
            except Exception as e:
                logger.warning(f"Could not load checkpoint: {e}")

    def maybe_save_checkpoint(self):
        """Save checkpoint if interval reached."""
        self.papers_processed_since_save += 1

        if self.papers_processed_since_save >= self.save_interval:
            self.save_checkpoint()

    def _serialize_stats(self, obj):
        """Serialize datetime objects for JSON."""
        if isinstance(obj, datetime):
            return obj.isoformat()
        elif isinstance(obj, dict):
            return {k: self._serialize_stats(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [self._serialize_stats(item) for item in obj]
        return obj

    def print_summary(self):
        """Print formatted statistics summary."""
        print("\n" + "=" * 80)
        print("SCRAPING STATISTICS REPORT")
        print("=" * 80)

        # Time information
        print(f"\nTIME INFORMATION:")
        print(f"  Start Time: {self.stats['start_time']}")
        print(f"  End Time: {self.stats['end_time']}")
        print(f"  Total Duration: {timedelta(seconds=int(self.stats['total_duration']))}")

        # Phase times
        print(f"\nPHASE DURATIONS:")
        for phase, duration in self.stats['performance']['phase_times'].items():
            print(f"  {phase}: {timedelta(seconds=int(duration))}")

        # Paper statistics
        print(f"\nPAPER STATISTICS:")
        print(f"  Total Identified: {self.stats['papers']['total_identified']}")
        print(f"  Total Attempted: {self.stats['papers']['total_attempted']}")
        print(f"  Successfully Downloaded: {self.stats['papers']['successfully_downloaded']}")
        print(f"  Failed Downloads: {self.stats['papers']['failed_downloads']}")
        print(f"  Success Rate: {self.stats['papers']['download_success_rate']:.2f}%")

        # Version statistics
        print(f"\nVERSION STATISTICS:")
        print(f"  Total Versions: {self.stats['versions']['total_versions']}")
        print(f"  Successfully Processed: {self.stats['versions']['successfully_processed']}")
        print(f"  Failed Versions: {self.stats['versions']['failed_versions']}")

        # Performance
        print(f"\nPERFORMANCE METRICS:")
        if self.stats['performance']['paper_processing_times']:
            print(f"  Average Time per Paper: {self.stats['performance']['average_time_per_paper']:.2f}s")
            print(f"  Fastest Paper: {self.stats['performance']['fastest_paper_time']:.2f}s")
            print(f"  Slowest Paper: {self.stats['performance']['slowest_paper_time']:.2f}s")

        # File sizes
        print(f"\nFILE SIZE STATISTICS:")
        print(f"  Average Size Before Figure Removal: {self._format_bytes(self.stats['file_sizes']['average_raw_size'])}")
        print(f"  Average Size After Figure Removal: {self._format_bytes(self.stats['file_sizes']['average_extracted_size'])}")
        print(f"  Total Raw Size: {self._format_bytes(self.stats['file_sizes']['total_raw_size'])}")
        print(f"  Total Extracted Size: {self._format_bytes(self.stats['file_sizes']['total_extracted_size'])}")
        print(f"  Space Saved: {self._format_bytes(self.stats['file_sizes']['space_saved_by_figure_removal'])}")
        print(f"  Figures Removed: {self.stats['file_sizes']['figures_removed']}")

        # References
        print(f"\nREFERENCE STATISTICS:")
        print(f"  Papers with References: {self.stats['references']['papers_with_references']}")
        print(f"  Papers without References: {self.stats['references']['papers_without_references']}")
        print(f"  Total References: {self.stats['references']['total_references']}")
        print(f"  Average References per Paper: {self.stats['references']['average_references_per_paper']:.2f}")
        print(f"  Reference Success Rate: {self.stats['references']['reference_success_rate']:.2f}%")

        # Memory
        print(f"\nMEMORY USAGE:")
        print(f"  Initial RAM: {self.stats['memory']['initial_ram_mb']:.2f} MB")
        print(f"  Peak RAM: {self.stats['memory']['peak_ram_mb']:.2f} MB")
        print(f"  Average RAM: {self.stats['memory']['average_ram_mb']:.2f} MB")
        print(f"  Initial Disk Usage: {self.stats['memory']['initial_disk_gb']:.2f} GB")
        print(f"  Final Disk Usage: {self.stats['memory']['final_disk_gb']:.2f} GB")
        print(f"  Disk Space Used: {self.stats['memory']['disk_space_used_gb']:.2f} GB")

        # Errors
        if self.stats['errors']['total_errors'] > 0:
            print(f"\nERROR STATISTICS:")
            print(f"  Total Errors: {self.stats['errors']['total_errors']}")
            print(f"  Error Types:")
            for error_type, count in self.stats['errors']['error_types'].items():
                print(f"    {error_type}: {count}")

        print("\n" + "=" * 80)

    def _format_bytes(self, bytes_value: float) -> str:
        """Format bytes to human readable format."""
        for unit in ['B', 'KB', 'MB', 'GB']:
            if bytes_value < 1024.0:
                return f"{bytes_value:.2f} {unit}"
            bytes_value /= 1024.0
        return f"{bytes_value:.2f} TB"
# Out:
# Overwriting lib/statistics_tracker.py

# %%
# %%writefile lib/paper_organizer.py
import logging
import json
import shutil
from pathlib import Path
from typing import Dict
from datetime import datetime
import sys
sys.path.insert(0, str(Path(__file__).parent.parent))
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'organizer.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class PaperOrganizer:
    """Organize papers in the new required structure."""

    def __init__(self):
        self.papers_dir = config.PAPERS_DIR
        self.temp_dir = config.TEMP_DIR

    def format_arxiv_id(self, arxiv_id: str) -> str:
        """Convert arxiv ID '2312.12345' -> '2312-12345'"""
        return arxiv_id.replace('.', '-')

    def get_paper_dir(self, arxiv_id: str) -> Path:
        """Get the directory for a paper."""
        formatted_id = self.format_arxiv_id(arxiv_id)
        return self.papers_dir / formatted_id

    def create_paper_structure(self, arxiv_id: str) -> Dict[str, Path]:
        """Create the directory structure for a paper."""
        paper_dir = self.get_paper_dir(arxiv_id)
        tex_dir = paper_dir / "tex"

        paper_dir.mkdir(parents=True, exist_ok=True)
        tex_dir.mkdir(exist_ok=True)

        return {
            'paper_dir': paper_dir,
            'tex_dir': tex_dir,
            'metadata_file': paper_dir / 'metadata.json',
            'references_file': paper_dir / 'references.json',
        }

    def save_metadata(self, arxiv_id: str, paper_data: Dict):
        """Save paper metadata in ISO format."""
        paths = self.create_paper_structure(arxiv_id)

        # format dates to ISO format
        published = paper_data.get('published', '')
        updated = paper_data.get('updated', '')

        # parse and convert to ISO format
        try:
            if isinstance(published, str):
                pub_date = datetime.fromisoformat(published.replace('Z', '+00:00'))
                published_iso = pub_date.date().isoformat()
            else:
                published_iso = str(published)
        except:
            published_iso = str(published)

        # get all revision dates from version_dates if available
        revised_dates = []

        metadata = {
            'title': paper_data.get('title', 'Unknown'),
            'authors': paper_data.get('authors', []),
            'submission_date': published_iso,
            'revised_dates': revised_dates,
            'categories': paper_data.get('categories', []),
            'abstract': paper_data.get('abstract', ''),
            'arxiv_id': arxiv_id,
            'versions': paper_data.get('versions', []),
            'comments': paper_data.get('comments', ''),
            'license': paper_data.get('license', ''),
        }

        with open(paths['metadata_file'], 'w', encoding='utf-8') as f:
            json.dump(metadata, f, indent=2, ensure_ascii=False)

        logger.info(f"Saved metadata for {arxiv_id}")

    def save_references(self, arxiv_id: str, ref_data: Dict):
        """
        Save references in required format with yyyymm-id keys.

        Expected format:
        {
            "1706-03762": {
                "paper_title": "...",
                "authors": [...],
                "submission_date": "2017-06-12",
                "semantic_scholar_id": "..."
            }
        }
        """
        paths = self.create_paper_structure(arxiv_id)

        references = {}

        if 'references' in ref_data:
            for ref in ref_data['references']:
                # try to extract arXiv ID from externalIds
                ref_arxiv_id = None

                if ref.get('externalIds'):
                    external_ids = ref['externalIds']
                    if 'ArXiv' in external_ids:
                        ref_arxiv_id = external_ids['ArXiv']

                # only include references that have arXiv IDs
                # otherwise skip
                if ref_arxiv_id:
                    formatted_ref_id = self.format_arxiv_id(ref_arxiv_id)

                    # extract authors, only get names
                    authors = []
                    if ref.get('authors'):
                        authors = [author.get('name', 'Unknown') for author in ref['authors']]

                    # parse submission date from year
                    submission_date = ''
                    if ref.get('year'):
                        submission_date = f"{ref['year']}-01-01"

                    references[formatted_ref_id] = {
                        'paper_title': ref.get('title', 'Unknown'),
                        'authors': authors,
                        'submission_date': submission_date,
                        'semantic_scholar_id': ref.get('paperId', '')
                    }

        with open(paths['references_file'], 'w', encoding='utf-8') as f:
            json.dump(references, f, indent=2, ensure_ascii=False)

        logger.info(f"Saved {len(references)} arXiv references for {arxiv_id}")

    def copy_source_files(self, arxiv_id: str, version: str, source_dir: Path):
        """
        Copy .tex files to tex folder and .bib files to paper folder.
        Delete temp directory after copying.
        """
        paths = self.create_paper_structure(arxiv_id)
        tex_dir = paths['tex_dir']
        paper_dir = paths['paper_dir']

        if not source_dir.exists():
            logger.warning(f"Source directory does not exist: {source_dir}")
            return

        tex_count = 0
        bib_count = 0

        for file_path in source_dir.rglob('*'):
            if file_path.is_file():
                file_ext = file_path.suffix.lower()

                if file_ext == '.tex':
                    # Copy .tex files to tex folder, maintaining structure
                    rel_path = file_path.relative_to(source_dir)
                    dest_path = tex_dir / version / rel_path
                    dest_path.parent.mkdir(parents=True, exist_ok=True)

                    try:
                        shutil.copy2(file_path, dest_path)
                        tex_count += 1
                    except Exception as e:
                        logger.debug(f"Could not copy {file_path.name}: {e}")

                elif file_ext == '.bib':
                    dest_path = tex_dir / version / file_path.name
                    dest_path.parent.mkdir(parents=True, exist_ok=True)

                    try:
                        shutil.copy2(file_path, dest_path)
                        bib_count += 1
                    except Exception as e:
                        logger.debug(f"Could not copy {file_path.name}: {e}")

        logger.info(f"Copied {tex_count} .tex files and {bib_count} .bib files for {arxiv_id}")

        # Delete temp directory if configured
        if config.DELETE_TEMP_AFTER_COPY:
            try:
                shutil.rmtree(source_dir)
                logger.debug(f"Deleted temp directory: {source_dir}")
            except Exception as e:
                logger.debug(f"Could not delete temp directory: {e}")


    def is_paper_complete(self, arxiv_id: str) -> bool:
        """Check if a paper has been fully processed."""
        paths = self.create_paper_structure(arxiv_id)

        # check if all required files exist
        has_metadata = paths['metadata_file'].exists()
        has_tex = paths['tex_dir'].exists() and any(paths['tex_dir'].rglob('*.tex'))
        has_references = paths['references_file'].exists()

        return has_metadata and has_tex and has_references
# Out:
# Overwriting lib/paper_organizer.py

# %%
# %%writefile lib/source_identifier.py
import logging
import time
import arxiv
from typing import List, Dict, Optional
import json
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'arxiv_harvester.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class ArxivHarvester:
    """Harvest metadata from arXiv using the arxiv Python API."""

    def __init__(self, id_ranges: List[tuple], checkpoint_interval: int = 10):
        """
        Initialize the harvester.

        Params:
            id_ranges: List of (YYMM, start_id, end_id) tuples
                      e.g., [("2312", 15844, 99999), ("2401", 0, 3095)]
            checkpoint_interval: Save checkpoint every N batches
        """
        self.id_ranges = id_ranges
        self.checkpoint_interval = checkpoint_interval
        self.client = arxiv.Client(
            page_size=config.ARXIV_MAX_RESULTS,
            delay_seconds=config.ARXIV_DELAY,
            num_retries=config.MAX_RETRIES
        )
        self.checkpoint_file = config.DATA_DIR / 'harvest_checkpoint.json'
        self.failed_batches_file = config.DATA_DIR / 'failed_batches.json'

    def generate_arxiv_ids(self, yymm: str, start_id: int, end_id: int) -> List[str]:
        """
        Generate arXiv IDs for a given range.

        Params:
            yymm: Year-month string (e.g., "2312")
            start_id: Starting ID number
            end_id: Ending ID number

        Returns:
            List of arXiv IDs (e.g., ["2312.15844", "2312.15845", ...])
        """
        return [f"{yymm}.{str(i).zfill(5)}" for i in range(start_id, end_id + 1)]

    def load_checkpoint(self) -> Dict:
        """Load checkpoint data if exists."""
        if self.checkpoint_file.exists():
            try:
                with open(self.checkpoint_file, 'r', encoding='utf-8') as f:
                    return json.load(f)
            except Exception as e:
                logger.error(f"Error loading checkpoint: {e}")
        return {'papers': [], 'processed_ranges': {}, 'last_batch_index': {}}

    def save_checkpoint(self, papers: List[Dict], range_key: str, batch_index: int):
        """Save checkpoint data."""
        try:
            checkpoint = self.load_checkpoint()
            checkpoint['papers'] = papers
            checkpoint['processed_ranges'][range_key] = True
            checkpoint['last_batch_index'][range_key] = batch_index

            with open(self.checkpoint_file, 'w', encoding='utf-8') as f:
                json.dump(checkpoint, f, indent=2)
            logger.info(f"✓ Checkpoint saved: {len(papers)} papers")
        except Exception as e:
            logger.error(f"Error saving checkpoint: {e}")

    def load_failed_batches(self) -> List[Dict]:
        """Load failed batches if exists."""
        if self.failed_batches_file.exists():
            try:
                with open(self.failed_batches_file, 'r', encoding='utf-8') as f:
                    return json.load(f)
            except Exception as e:
                logger.error(f"Error loading failed batches: {e}")
        return []

    def save_failed_batch(self, yymm: str, batch_ids: List[str], error_type: str):
        """Save a failed batch for retry."""
        try:
            failed_batches = self.load_failed_batches()
            failed_batches.append({
                'yymm': yymm,
                'batch_ids': batch_ids,
                'error_type': error_type,
                'timestamp': time.time()
            })

            with open(self.failed_batches_file, 'w', encoding='utf-8') as f:
                json.dump(failed_batches, f, indent=2)
            logger.warning(f"✗ Saved failed batch: {len(batch_ids)} IDs ({error_type})")
        except Exception as e:
            logger.error(f"Error saving failed batch: {e}")

    def fetch_paper_batch(self, arxiv_ids: List[str], yymm: str) -> tuple[List[Dict], Optional[str]]:
        """
        Fetch metadata for a batch of arXiv IDs.

        Params:
            arxiv_ids: List of arXiv IDs
            yymm: Year-month string for error tracking

        Returns:
            Tuple of (list of paper metadata dictionaries, error_type if failed)
        """
        papers = []
        error_type = None

        try:
            search = arxiv.Search(id_list=arxiv_ids)
            results = self.client.results(search)

            for paper in results:
                try:
                    paper_data = self._parse_paper(paper)
                    if paper_data:
                        papers.append(paper_data)
                except Exception as e:
                    logger.error(f"Error parsing paper: {e}")
                    continue

        except Exception as e:
            error_msg = str(e).lower()
            if '429' in error_msg or 'rate limit' in error_msg or 'too many requests' in error_msg:
                error_type = '429_rate_limit'
                logger.error(f"Rate limit error (429): {e}")
            else:
                error_type = 'other_error'
                logger.error(f"Error fetching batch: {e}")

        return papers, error_type

    def _parse_paper(self, paper: arxiv.Result) -> Optional[Dict]:
        """
        Parse an arxiv.Result object into our metadata format.

        Params:
            paper: arxiv.Result object

        Returns:
            Dictionary with paper metadata
        """
        try:
            # Extract base arXiv ID (without version)
            arxiv_id = paper.entry_id.split('/')[-1].split('v')[0]

            # Get version from entry_id - the API returns the latest version
            entry_with_version = paper.entry_id.split('/')[-1]
            if 'v' in entry_with_version:
                latest_version = int(entry_with_version.split('v')[-1])
                versions = [f"{arxiv_id}v{i}" for i in range(1, latest_version + 1)]
            else:
                versions = [f"{arxiv_id}v1"]

            # Format dates
            published = paper.published.date().isoformat()
            updated = paper.updated.date().isoformat()

            # Extract authors
            authors = [author.name for author in paper.authors]

            # Extract categories
            categories = [paper.primary_category] + paper.categories
            categories = list(set(categories))  # Remove duplicates

            paper_data = {
                'arxiv_id': arxiv_id,
                'title': paper.title.strip(),
                'authors': authors,
                'categories': categories,
                'abstract': paper.summary.strip().replace('\n', ' '),
                'published': published,
                'updated': updated,
                'comments': paper.comment if paper.comment else '',
                'license': paper.journal_ref if paper.journal_ref else '',
                'versions': versions,
                'pdf_url': paper.pdf_url,
                'entry_id': paper.entry_id
            }

            return paper_data

        except Exception as e:
            logger.error(f"Error parsing paper: {e}")
            return None

    def retry_failed_batches(self) -> List[Dict]:
        """Retry all failed batches."""
        failed_batches = self.load_failed_batches()
        if not failed_batches:
            logger.info("No failed batches to retry")
            return []

        logger.info(f"\n{'='*80}")
        logger.info(f"Retrying {len(failed_batches)} failed batches")
        logger.info(f"{'='*80}\n")

        all_papers = []
        remaining_failures = []

        for i, failure in enumerate(failed_batches, 1):
            yymm = failure['yymm']
            batch_ids = failure['batch_ids']
            error_type = failure['error_type']

            logger.info(f"Retry {i}/{len(failed_batches)}: {yymm} - {len(batch_ids)} IDs ({error_type})")

            # Wait longer for rate limit errors
            if error_type == '429_rate_limit':
                logger.info(f"Waiting {config.ARXIV_DELAY * 3}s for rate limit...")
                time.sleep(config.ARXIV_DELAY * 3)

            papers, error = self.fetch_paper_batch(batch_ids, yymm)

            if error:
                logger.warning(f"Still failing: {error}")
                remaining_failures.append(failure)
            else:
                logger.info(f"✓ Recovered {len(papers)} papers")
                all_papers.extend(papers)

            time.sleep(config.ARXIV_DELAY)

        # Update failed batches file
        with open(self.failed_batches_file, 'w', encoding='utf-8') as f:
            json.dump(remaining_failures, f, indent=2)

        logger.info(f"\n{'='*80}")
        logger.info(f"Retry complete: {len(all_papers)} recovered, {len(remaining_failures)} still failing")
        logger.info(f"{'='*80}\n")

        return all_papers

    def harvest_all_papers(self) -> List[Dict]:
        """
        Harvest all papers across the specified ID ranges and Date ranges.

        Returns:
            List of paper metadata dictionaries
        """
        # Load checkpoint
        checkpoint = self.load_checkpoint()
        all_papers = checkpoint.get('papers', [])
        processed_ranges = checkpoint.get('processed_ranges', {})
        last_batch_indices = checkpoint.get('last_batch_index', {})

        if all_papers:
            logger.info(f"Resuming from checkpoint with {len(all_papers)} papers already collected")

        # Process each range
        for yymm, start_id, end_id in self.id_ranges:
            range_key = f"{yymm}_{start_id}_{end_id}"

            # Skip if already processed
            if processed_ranges.get(range_key):
                logger.info(f"Range {range_key} already processed, skipping")
                continue

            logger.info(f"Processing range: {yymm}.{start_id} to {yymm}.{end_id}")

            # Generate all IDs
            all_ids = self.generate_arxiv_ids(yymm, start_id, end_id)
            logger.info(f"Generated {len(all_ids)} potential IDs")

            # Split into batches
            batch_size = config.ARXIV_BATCH_SIZE
            batches = [all_ids[i:min(i + batch_size, len(all_ids))] for i in range(0, len(all_ids), batch_size)]

            # Resume from last batch if exists
            start_batch = last_batch_indices.get(range_key, 0)
            if start_batch > 0:
                logger.info(f"Resuming from batch {start_batch + 1}/{len(batches)}")

            papers_in_range = []
            consecutive_no_paper_count = 0

            # Process batches sequentially (to respect rate limits)
            for i in range(start_batch, len(batches)):
                batch = batches[i]
                logger.info(f"Batch {i+1}/{len(batches)}: fetching {len(batch)} IDs")

                papers, error = self.fetch_paper_batch(batch, yymm)

                if error:
                    self.save_failed_batch(yymm, batch, error)

                if papers:
                    papers_in_range.extend(papers)
                    all_papers.extend(papers)
                    consecutive_no_paper_count = 0
                    logger.info(f"Found {len(papers)} papers (range: {len(papers_in_range)}, total: {len(all_papers)})")
                else:
                    consecutive_no_paper_count += 1
                    logger.info(f"No papers found in this batch (consecutive: {consecutive_no_paper_count})")

                    # If too many consecutive empty batches, assume no more papers
                    if consecutive_no_paper_count >= 2:
                        logger.info("No more papers found in recent batches, stopping early for this range.")
                        break

                # Save checkpoint every N batches
                if (i + 1) % self.checkpoint_interval == 0:
                    self.save_checkpoint(all_papers, range_key, i)

                # Rate limiting
                time.sleep(config.ARXIV_DELAY)

            # Mark range as complete
            logger.info(f"Completed {yymm}: found {len(papers_in_range)} papers\n")
            processed_ranges[range_key] = True
            self.save_checkpoint(all_papers, range_key, len(batches) - 1)

        logger.info(f"="*80)
        logger.info(f"Harvesting complete! Total papers: {len(all_papers)}")
        logger.info(f"="*80)

        return all_papers
# Out:
# Overwriting lib/source_identifier.py

# %%
# %%writefile lib/reference_extractor.py
import requests
import logging
import json
import time
from pathlib import Path
from typing import Dict, Optional
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'references.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class ReferenceExtractor:
    """Extract reference information using Semantic Scholar API."""

    def __init__(self, stats_tracker=None):
        self.api_base = config.SEMANTIC_SCHOLAR_API_BASE
        self.max_retries = config.MAX_RETRIES
        self.retry_delay = config.RETRY_DELAY
        self.stats = stats_tracker

    def fetch_references(self, arxiv_id: str) -> Optional[Dict]:
        """Fetch reference information for a paper from Semantic Scholar."""
        url = f"{self.api_base}/paper/arXiv:{arxiv_id}"
        # add key to headers
        headers = {
            'x-api-key': config.SEMANTIC_KEY_API
        }
        params = {
            'fields': config.SEMANTIC_SCHOLAR_FIELDS
        }

        for attempt in range(self.max_retries):
            try:
                logger.info(f"Fetching references for arXiv:{arxiv_id} (attempt {attempt + 1})")

                response = requests.get(
                    url,
                    headers=headers,
                    params=params,
                    timeout=30
                )

                if response.status_code == 200:
                    data = response.json()
                    logger.info(f"Successfully fetched references for {arxiv_id}")
                    return data

                elif response.status_code == 404:
                    logger.warning(f"Paper not found in Semantic Scholar: {arxiv_id}")
                    if self.stats:
                        self.stats.record_error("Reference not found (404)")
                    return None

                elif response.status_code == 429:
                    wait_time = self.retry_delay
                    logger.warning(f"Rate limited. Waiting {wait_time}s...")
                    time.sleep(wait_time)
                    continue

                else:
                    logger.error(f"Error {response.status_code}: {response.text[:200]}")
                    if attempt < self.max_retries - 1:
                        time.sleep(self.retry_delay)
                        continue
                    if self.stats:
                        self.stats.record_error(f"HTTP {response.status_code}")
                    return None

            except requests.exceptions.RequestException as e:
                logger.error(f"Request error for {arxiv_id}: {e}")
                if attempt < self.max_retries - 1:
                    time.sleep(self.retry_delay)
                    continue
                if self.stats:
                    self.stats.record_error(f"Request error: {type(e).__name__}")
                return None

        return None
# Out:
# Overwriting lib/reference_extractor.py

# %%
# %%writefile lib/source_downloader.py
import tarfile
import gzip
import logging
import shutil
from pathlib import Path
from typing import List, Optional, Tuple
import config
import concurrent.futures
import requests

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'downloader.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class SourceDownloader:
    """Download and extract arXiv paper sources with figure removal."""

    def __init__(self, stats_tracker=None, paper_organizer=None):
        self.temp_dir = config.TEMP_DIR
        self.figure_extensions = config.FIGURE_EXTENSIONS
        self.stats = stats_tracker
        self.organizer = paper_organizer

    def download_paper_source(self, arxiv_id: str, version: str) -> Optional[Path]:
        """Download source files for a specific paper version."""
        try:
            # Create temporary directory for this version
            version_temp_dir = self.temp_dir / arxiv_id / version
            tar_path = version_temp_dir / f"{version}.tar.gz"

            logger.info(f"Downloading source for {version}")
            version_temp_dir.mkdir(parents=True, exist_ok=True)

            # Download source for the specific version
            # Construct the source URL manually for the specific version
            source_url = f"https://arxiv.org/e-print/{version}"

            try:
                response = requests.get(source_url, timeout=30)
                response.raise_for_status()

                # Save the downloaded content
                with open(tar_path, 'wb') as f:
                    f.write(response.content)

                logger.info(f"Downloaded {version}")
                return tar_path

            except requests.exceptions.RequestException as e:
                logger.error(f"Error downloading from {source_url}: {e}")
                if self.stats:
                    self.stats.record_error(f"Download request error: {type(e).__name__}")
                return None

        except StopIteration:
            logger.warning(f"Paper {version} not found in arXiv")
            if self.stats:
                self.stats.record_error("Paper not found")
            return None
        except Exception as e:
            logger.error(f"Error downloading {version}: {e}")
            if self.stats:
                self.stats.record_error(f"Download error: {type(e).__name__}")
            return None

    def get_directory_size(self, directory: Path) -> int:
        """Get total size of directory in bytes."""
        total_size = 0
        try:
            for path in directory.rglob('*'):
                if path.is_file():
                    total_size += path.stat().st_size
        except Exception as e:
            logger.error(f"Error calculating directory size: {e}")
        return total_size

    def remove_figures_from_directory(self, directory: Path) -> int:
        """Remove figure files from a directory."""
        removed_count = 0

        try:
            for file_path in directory.rglob('*'):
                if file_path.is_file():
                    if any(file_path.suffix.lower() == ext for ext in self.figure_extensions):
                        try:
                            file_path.unlink()
                            removed_count += 1
                            logger.debug(f"Removed figure: {file_path.name}")
                        except Exception as e:
                            logger.debug(f"Could not remove {file_path.name}: {e}")

            if removed_count > 0:
                logger.info(f"Removed {removed_count} figure files from {directory.name}")

        except Exception as e:
            logger.error(f"Error removing figures from {directory}: {e}")
            if self.stats:
                self.stats.record_error(f"Figure removal error: {type(e).__name__}")

        return removed_count

    def extract_nested_archives(self, directory: Path, depth: int = 0, max_depth: int = 3):
        """
        Recursively extract nested tar/tar.gz files.

        Args:
            directory: Directory to search for archives
            depth: Current recursion depth
            max_depth: Maximum recursion depth to prevent infinite loops
        """
        if depth >= max_depth:
            logger.warning(f"Maximum extraction depth ({max_depth}) reached")
            return

        archive_extensions = ['.tar', '.tar.gz', '.tgz', '.gz']

        for file_path in list(directory.rglob('*')):
            if not file_path.is_file():
                continue

            # Check if it's an archive
            is_archive = any(
                str(file_path).endswith(ext) for ext in archive_extensions
            )

            if not is_archive:
                continue

            try:
                extract_subdir = file_path.parent / file_path.stem
                extract_subdir.mkdir(exist_ok=True)

                logger.debug(f"Extracting nested archive: {file_path.name}")

                # Try different extraction methods
                extracted = False

                # Method 1: tar.gz
                if str(file_path).endswith(('.tar.gz', '.tgz')):
                    try:
                        with tarfile.open(file_path, 'r:gz') as tar:
                            tar.extractall(path=extract_subdir)
                        extracted = True
                    except Exception:
                        pass

                # Method 2: plain tar
                if not extracted and str(file_path).endswith('.tar'):
                    try:
                        with tarfile.open(file_path, 'r:') as tar:
                            tar.extractall(path=extract_subdir)
                        extracted = True
                    except Exception:
                        pass

                # Method 3: plain gzip (decompress to single file)
                if not extracted and str(file_path).endswith('.gz'):
                    try:
                        output_file = extract_subdir.parent / file_path.stem
                        with gzip.open(file_path, 'rb') as f_in:
                            with open(output_file, 'wb') as f_out:
                                shutil.copyfileobj(f_in, f_out)
                        extracted = True
                        # If it's a .tar after decompression, extract it
                        if output_file.suffix == '.tar':
                            try:
                                with tarfile.open(output_file, 'r:') as tar:
                                    tar.extractall(path=extract_subdir)
                                output_file.unlink()
                            except Exception:
                                pass
                    except Exception:
                        pass

                if extracted:
                    # Remove the archive file after successful extraction
                    file_path.unlink()
                    logger.debug(f"Extracted and removed: {file_path.name}")

                    # Recursively extract nested archives
                    self.extract_nested_archives(extract_subdir, depth + 1, max_depth)
                else:
                    logger.debug(f"Could not extract: {file_path.name}")

            except Exception as e:
                logger.debug(f"Error extracting nested archive {file_path.name}: {e}")

    def extract_tarball(self, tar_path: Path, arxiv_id: str, version: str) -> Tuple[Optional[Path], int, int, int]:
        """
        Extract a .tar.gz file and remove figures.

        Returns:
            Tuple of (extract_dir, raw_size, extracted_size, figures_removed)
        """
        if not tar_path or not tar_path.exists():
            logger.warning(f"Tar file not found: {tar_path}")
            return None, 0, 0, 0

        extract_dir = self.temp_dir / arxiv_id / version / "extracted"
        try:
            extract_dir.mkdir(parents=True, exist_ok=True)

            # Get raw size
            raw_size = tar_path.stat().st_size

            logger.info(f"Extracting {tar_path.name} ({raw_size} bytes)")

            extracted = False

            # Try multiple extraction methods
            # Method 1: tar.gz
            try:
                with tarfile.open(tar_path, 'r:gz') as tar:
                    tar.extractall(path=extract_dir)
                extracted = True
                logger.debug("Extracted as tar.gz")
            except (tarfile.ReadError, gzip.BadGzipFile) as e:
                logger.debug(f"Not a gzipped tar: {e}")

            # Method 2: plain tar
            if not extracted:
                try:
                    with tarfile.open(tar_path, 'r:') as tar:
                        tar.extractall(path=extract_dir)
                    extracted = True
                    logger.debug("Extracted as plain tar")
                except tarfile.ReadError as e:
                    logger.debug(f"Not a plain tar: {e}")

            # Method 3: gzip only (decompress then check if tar)
            if not extracted:
                try:
                    decompressed_path = extract_dir / "decompressed.tar"
                    with gzip.open(tar_path, 'rb') as f_in:
                        with open(decompressed_path, 'wb') as f_out:
                            shutil.copyfileobj(f_in, f_out)

                    # Try to open as tar
                    try:
                        with tarfile.open(decompressed_path, 'r:') as tar:
                            tar.extractall(path=extract_dir)
                        decompressed_path.unlink()
                        extracted = True
                        logger.debug("Extracted as gzip -> tar")
                    except tarfile.ReadError:
                        # It's just a gzipped file, not a tar
                        extracted = True
                        logger.debug("Extracted as plain gzip")

                except (gzip.BadGzipFile, OSError) as e:
                    logger.debug(f"Not gzipped: {e}")

            # Method 4: Copy as-is (might be a single .tex file)
            if not extracted:
                logger.warning(f"Could not extract {tar_path.name}, copying as-is")
                shutil.copy(tar_path, extract_dir / tar_path.name)
                extracted = True

            if not extracted:
                logger.error(f"Failed to extract {tar_path.name}")
                return None, 0, 0, 0

            # Extract any nested archives (tar/tar.gz inside)
            logger.debug("Checking for nested archives...")
            self.extract_nested_archives(extract_dir)

            # Remove figures
            figures_removed = self.remove_figures_from_directory(extract_dir)

            # Delete raw file if configured
            if config.DELETE_RAW_AFTER_EXTRACT:
                try:
                    tar_path.unlink()
                    logger.debug(f"Deleted raw file: {tar_path.name}")
                except Exception as e:
                    logger.debug(f"Could not delete raw file: {e}")

            # Get size after figure removal (only .tex and .bib files)
            extracted_size = 0
            tex_bib_files = []
            for file_path in extract_dir.rglob('*'):
                if file_path.is_file():
                    if file_path.suffix.lower() in ['.tex', '.bib', '.sty', '.cls', '.bst']:
                        extracted_size += file_path.stat().st_size
                        tex_bib_files.append(file_path.name)

            if tex_bib_files:
                logger.info(f"Found {len(tex_bib_files)} LaTeX files")
            else:
                logger.warning(f"No LaTeX files found in {version}")

            logger.info(f"Extracted {version}: {raw_size} -> {extracted_size} bytes ({figures_removed} figures removed)")

            return extract_dir, raw_size, extracted_size, figures_removed

        except Exception as e:
            logger.error(f"Error extracting {tar_path}: {e}")
            if self.stats:
                self.stats.record_error(f"Extraction error: {type(e).__name__}")
            return None, 0, 0, 0

    def download_and_extract_version(self, arxiv_id: str, version: str) -> bool:
        """Download and extract a single version."""
        try:
            # Download
            tar_path = self.download_paper_source(arxiv_id, version)

            if not tar_path:
                if self.stats:
                    self.stats.record_version(success=False)
                return False

            # Extract
            extract_dir, raw_size, extracted_size, figures_removed = self.extract_tarball(
                tar_path, arxiv_id, version
            )

            if extract_dir:
                # Copy extracted files to organized structure
                if self.organizer:
                    try:
                        self.organizer.copy_source_files(arxiv_id, version, extract_dir)
                        logger.info(f"✓ Organized {version}")
                    except Exception as e:
                        logger.error(f"Error organizing files: {e}")

                if self.stats:
                    self.stats.record_file_sizes(raw_size, extracted_size, figures_removed)
                    self.stats.record_version(success=True)

                # Clean up temp directory if configured
                if config.DELETE_TEMP_AFTER_COPY:
                    try:
                        shutil.rmtree(extract_dir)
                        logger.debug(f"Cleaned up temp dir for {version}")
                    except Exception as e:
                        logger.debug(f"Could not clean up temp: {e}")

                return True
            else:
                if self.stats:
                    self.stats.record_version(success=False)
                return False

        except Exception as e:
            logger.error(f"Error processing {version}: {e}")
            if self.stats:
                self.stats.record_error(f"Processing error: {type(e).__name__}")
                self.stats.record_version(success=False)
            return False

    def download_and_extract_all_versions(self, arxiv_id: str, versions: List[str]):
        """Download and extract all versions of a paper in parallel."""
        logger.info(f"Processing {len(versions)} versions of {arxiv_id}")

        with concurrent.futures.ThreadPoolExecutor(max_workers=config.DOWNLOAD_BATCH_SIZE) as executor:
            futures = {
                executor.submit(self.download_and_extract_version, arxiv_id, version): version
                for version in versions
            }

            for future in concurrent.futures.as_completed(futures):
                version = futures[future]
                try:
                    success = future.result()
                    if success:
                        logger.info(f"✓ Processed {version}")
                    else:
                        logger.warning(f"✗ Failed {version}")
                except Exception as e:
                    logger.error(f"Exception processing {version}: {e}")
# Out:
# Overwriting lib/source_downloader.py

# %%
# %%writefile main.py
import logging
import json
import sys
import time
import threading
from pathlib import Path

from lib.source_identifier import ArxivHarvester
from lib.source_downloader import SourceDownloader
from lib.reference_extractor import ReferenceExtractor
from lib.statistics_tracker import StatisticsTracker
from lib.paper_organizer import PaperOrganizer
import config

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(config.LOGS_DIR / 'main.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


def memory_monitor(stats, stop_event):
    """Background thread to monitor memory usage."""
    while not stop_event.is_set():
        stats.sample_memory()
        time.sleep(5)


def main():
    """Main execution pipeline with optimized speed."""
    stats = StatisticsTracker()
    organizer = PaperOrganizer()
    stats.start()

    stop_monitoring = threading.Event()
    monitor_thread = threading.Thread(target=memory_monitor, args=(stats, stop_monitoring))
    monitor_thread.start()

    try:
        logger.info("=" * 80)
        logger.info("Starting arXiv Data Scraping")
        logger.info("=" * 80)

        # Step 1: Harvest metadata using arXiv API
        stats.start_phase("Metadata Harvesting (arXiv API)")
        logger.info("\n--- STEP 1: Harvesting metadata via arXiv API ---")

        paper_list_file = config.DATA_DIR / 'paper_list.json'

        if paper_list_file.exists():
            logger.info(f"Loading cached paper list from {paper_list_file}")
            with open(paper_list_file, 'r', encoding='utf-8') as f:
                papers = json.load(f)
            logger.info(f"Loaded {len(papers)} papers from cache")
        else:
            harvester = ArxivHarvester(
                id_ranges=config.ARXIV_ID_RANGES,
                checkpoint_interval=10  # Save every 10 batches
            )

            # Harvest papers with checkpoint support
            papers = harvester.harvest_all_papers()

            # Retry failed batches
            failed_papers = harvester.retry_failed_batches()
            if failed_papers:
                papers.extend(failed_papers)
                # Remove duplicates
                seen = set()
                papers = [p for p in papers if not (p['arxiv_id'] in seen or seen.add(p['arxiv_id']))]

            # Record identified papers
            for _ in papers:
                stats.record_paper_identified()

        # Save paper list
        with open(paper_list_file, 'w', encoding='utf-8') as f:
            json.dump(papers, f, indent=2, default=str)

        logger.info(f"Saved {len(papers)} papers to {paper_list_file}")

        stats.end_phase()
        stats.save_checkpoint()

        if not papers:
            logger.warning("No papers found. Exiting.")
            return

        logger.info(f"\n{'='*80}")
        logger.info(f"Found {len(papers)} papers to process")
        logger.info(f"{'='*80}\n")

        # Step 2: Process each paper
        stats.start_phase("Paper Processing")
        logger.info("\n--- STEP 2: Processing papers (parallel) ---")

        downloader = SourceDownloader(stats_tracker=stats, paper_organizer=organizer)
        ref_extractor = ReferenceExtractor(stats_tracker=stats)

        for i, paper in enumerate(papers, 1):
            arxiv_id = paper['arxiv_id']
            versions = paper['versions']

            logger.info(f"\n{'='*60}")
            logger.info(f"[{i}/{len(papers)}] {arxiv_id}: {paper['title'][:80]}...")

            # Check if already complete
            if organizer.is_paper_complete(arxiv_id):
                logger.info(f"✓ Already complete, skipping")
                stats.record_paper_success(0)
                continue

            stats.record_paper_attempt()
            paper_start_time = time.time()

            try:
                # Save metadata
                organizer.save_metadata(arxiv_id, paper)

                # Download and extract versions
                logger.info(f"Downloading {len(versions)} versions in parallel...")
                downloader.download_and_extract_all_versions(arxiv_id, versions)

                # Extract references
                logger.info(f"Fetching references...")
                ref_data = ref_extractor.fetch_references(arxiv_id)
                if ref_data:
                    organizer.save_references(arxiv_id, ref_data)
                    ref_count = len(ref_data.get('references', []))
                    stats.record_references(ref_count)
                else:
                    stats.record_references(0)

                # Small delay to avoid rate limiting
                time.sleep(config.REQUEST_DELAY)

                paper_time = time.time() - paper_start_time
                stats.record_paper_success(paper_time)
                logger.info(f"✓ Completed in {paper_time:.2f}s")

                # Save checkpoint periodically
                stats.maybe_save_checkpoint()

            except Exception as e:
                logger.error(f"✗ Error: {e}")
                import traceback
                traceback.print_exc()
                stats.record_paper_failure()
                stats.record_error(f"Error: {type(e).__name__}")

        stats.end_phase()

        # Cleanup temp directory
        logger.info("\n--- Cleaning up temporary files ---")
        try:
            if config.TEMP_DIR.exists():
                import shutil
                shutil.rmtree(config.TEMP_DIR)
                config.TEMP_DIR.mkdir(parents=True, exist_ok=True)
                logger.info("✓ Cleaned up temp directory")
        except Exception as e:
            logger.warning(f"Could not clean temp directory: {e}")

        logger.info("\n" + "=" * 80)
        logger.info("Pipeline completed!")
        logger.info("=" * 80)

    finally:
        stop_monitoring.set()
        monitor_thread.join()
        stats.end()
        stats.save_to_file(config.DATA_DIR / 'statistics_final.json')
        stats.save_checkpoint()
        stats.print_summary()
        logger.info(f"\n📊 Statistics: {config.DATA_DIR / 'statistics_final.json'}")
        logger.info(f"📁 Papers: {config.PAPERS_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Overwriting main.py

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# ============================================================
# 2025-11-13 22:58:54,533 - INFO - [4805/5000] 2401.02901: Charged-current non-standard neutrino interactions at Daya Bay...
# 2025-11-13 22:58:54,534 - INFO - Saved metadata for 2401.02901
# 2025-11-13 22:58:54,534 - INFO - Downloading 6 versions in parallel...
# 2025-11-13 22:58:54,534 - INFO - Processing 6 versions of 2401.02901
# 2025-11-13 22:58:54,535 - INFO - Downloading source for 2401.02901v1
# 2025-11-13 22:58:54,535 - INFO - Downloading source for 2401.02901v2
# 2025-11-13 22:58:54,535 - INFO - Downloading source for 2401.02901v3
# 2025-11-13 22:58:55,278 - INFO - Downloaded 2401.02901v2
# 2025-11-13 22:58:55,278 - INFO - Extracting 2401.02901v2.tar.gz (658230 bytes)
# 2025-11-13 22:58:55,295 - INFO - Removed 39 figure files from extracted
# 2025-11-13 22:58:55,295 - INFO - Found 5 LaTeX files
# 2025-11-13 22:58:55,296 - INFO - Extracted 2401.02901v2: 658230 -> 185735 bytes (39 figures removed)
# 2025-11-13 22:58:55,297 - INFO - Copied 2 .tex files and 1 .bib files for 2401.02901
# 2025-11-13 22:58:56,906 - INFO - Downloaded 2401.02901v5
# 2025-11-13 22:58:56,906 - INFO - Extracting 2401.02901v5.tar.gz (657696 bytes)
# 2025-11-13 22:58:56,923 - INFO - Removed 39 figure files from extracted
# 2025-11-13 22:58:56,924 - INFO - Found 5 LaTeX files
# 2025-11-13 22:58:56,924 - INFO - Extracted 2401.02901v5: 657696 -> 186424 bytes (39 figures removed)
# 2025-11-13 22:58:56,925 - INFO - Copied 2 .tex files and 1 .bib files for 2401.02901
# 2025-11-13 22:58:56,926 - INFO - ✓ Organized 2401.02901v5
# 2025-11-13 22:58:56,926 - INFO - ✓ Processed 2401.02901v5
# 2025-11-13 22:58:56,926 - INFO - Fetching references...
# 2025-11-13 22:58:56,926 - INFO - Fetching references for arXiv:2401.02901 (attempt 1)
# 2025-11-13 22:58:57,861 - INFO - Successfully fetched references for 2401.02901
# 2025-11-13 22:58:57,863 - INFO - Saved 39 arXiv references for 2401.02901
# 2025-11-13 22:58:58,863 - INFO - ✓ Completed in 4.33s
# 2025-11-13 22:58:58,863 - INFO -
# ============================================================
# 2025-11-13 22:58:58,863 - INFO - [4806/5000] 2401.02903: Deep Reinforcement Learning for Local Path Following of an Autonomous Formula SA...
# 2025-11-13 22:58:58,864 - INFO - Saved metadata for 2401.02903
# 2025-11-13 22:58:58,864 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:58:58,864 - INFO - Processing 1 versions of 2401.02903
# 2025-11-13 22:58:58,865 - INFO - Downloading source for 2401.02903v1
# 2025-11-13 22:59:05,446 - INFO - Downloaded 2401.02903v1
# 2025-11-13 22:59:05,447 - INFO - Extracting 2401.02903v1.tar.gz (13180921 bytes)
# 2025-11-13 22:59:05,547 - INFO - Removed 41 figure files from extracted
# 2025-11-13 22:59:05,549 - INFO - Found 5 LaTeX files
# 2025-11-13 22:59:05,549 - INFO - Extracted 2401.02903v1: 13180921 -> 378414 bytes (41 figures removed)
# 2025-11-13 22:59:05,550 - INFO - Copied 1 .tex files and 1 .bib files for 2401.02903
# 2025-11-13 22:59:05,551 - INFO - ✓ Organized 2401.02903v1
# 2025-11-13 22:59:05,551 - INFO - ✓ Processed 2401.02903v1
# 2025-11-13 22:59:05,551 - INFO - Fetching references...
# 2025-11-13 22:59:05,551 - INFO - Fetching references for arXiv:2401.02903 (attempt 1)
# 2025-11-13 22:59:06,042 - INFO - Successfully fetched references for 2401.02903
# 2025-11-13 22:59:06,044 - INFO - Saved 13 arXiv references for 2401.02903
# 2025-11-13 22:59:07,044 - INFO - ✓ Completed in 8.18s
# 2025-11-13 22:59:07,044 - INFO -
# ============================================================
# 2025-11-13 22:59:07,044 - INFO - [4807/5000] 2401.02909: Introducing Bode: A Fine-Tuned Large Language Model for Portuguese Prompt-Based ...
# 2025-11-13 22:59:07,045 - INFO - Saved metadata for 2401.02909
# 2025-11-13 22:59:07,045 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:59:07,045 - INFO - Processing 1 versions of 2401.02909
# 2025-11-13 22:59:07,046 - INFO - Downloading source for 2401.02909v1
# 2025-11-13 22:59:07,863 - INFO - Downloaded 2401.02909v1
# 2025-11-13 22:59:07,863 - INFO - Extracting 2401.02909v1.tar.gz (1065063 bytes)
# 2025-11-13 22:59:07,879 - INFO - Removed 6 figure files from extracted
# 2025-11-13 22:59:07,879 - INFO - Found 12 LaTeX files
# 2025-11-13 22:59:07,879 - INFO - Extracted 2401.02909v1: 1065063 -> 135875 bytes (6 figures removed)
# 2025-11-13 22:59:07,882 - INFO - Copied 9 .tex files and 1 .bib files for 2401.02909
# 2025-11-13 22:59:07,882 - INFO - ✓ Organized 2401.02909v1
# 2025-11-13 22:59:07,883 - INFO - ✓ Processed 2401.02909v1
# 2025-11-13 22:59:07,883 - INFO - Fetching references...
# 2025-11-13 22:59:07,883 - INFO - Fetching references for arXiv:2401.02909 (attempt 1)
# 2025-11-13 22:59:08,353 - INFO - Successfully fetched references for 2401.02909
# 2025-11-13 22:59:08,354 - INFO - Saved 13 arXiv references for 2401.02909
# 2025-11-13 22:59:09,354 - INFO - ✓ Completed in 2.31s
# 2025-11-13 22:59:09,354 - INFO -
# ============================================================
# 2025-11-13 22:59:09,354 - INFO - [4808/5000] 2401.02912: Decoding the thermal history of the merging cluster Cygnus A...
# 2025-11-13 22:59:09,355 - INFO - Saved metadata for 2401.02912
# 2025-11-13 22:59:09,355 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:59:09,355 - INFO - Processing 1 versions of 2401.02912
# 2025-11-13 22:59:09,356 - INFO - Downloading source for 2401.02912v1
# 2025-11-13 22:59:13,162 - INFO - Downloaded 2401.02912v1
# 2025-11-13 22:59:13,162 - INFO - Extracting 2401.02912v1.tar.gz (6725737 bytes)
# 2025-11-13 22:59:13,201 - INFO - Removed 11 figure files from extracted
# 2025-11-13 22:59:13,202 - INFO - Found 3 LaTeX files
# 2025-11-13 22:59:13,202 - INFO - Extracted 2401.02912v1: 6725737 -> 174018 bytes (11 figures removed)
# 2025-11-13 22:59:13,203 - INFO - Copied 1 .tex files and 0 .bib files for 2401.02912
# 2025-11-13 22:59:13,203 - INFO - ✓ Organized 2401.02912v1
# 2025-11-13 22:59:13,204 - INFO - ✓ Processed 2401.02912v1
# 2025-11-13 22:59:13,204 - INFO - Fetching references...
# 2025-11-13 22:59:13,204 - INFO - Fetching references for arXiv:2401.02912 (attempt 1)
# 2025-11-13 22:59:13,450 - INFO - Successfully fetched references for 2401.02912
# 2025-11-13 22:59:13,451 - INFO - Saved 0 arXiv references for 2401.02912
# 2025-11-13 22:59:14,451 - INFO - ✓ Completed in 5.10s
# 2025-11-13 22:59:14,451 - INFO -
# ============================================================
# 2025-11-13 22:59:14,451 - INFO - [4809/5000] 2401.02916: Uncovering the human motion pattern: Pattern Memory-based Diffusion Model for Tr...
# 2025-11-13 22:59:14,452 - INFO - Saved metadata for 2401.02916
# 2025-11-13 22:59:14,452 - INFO - Downloading 2 versions in parallel...
# 2025-11-13
- INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251113_225922.json
# 2025-11-13 22:59:22,293 - INFO -
# ============================================================
# 2025-11-13 22:59:22,293 - INFO - [4811/5000] 2401.02920: Analytically-Driven Resource Management for Cloud-Native Microservices...
# 2025-11-13 22:59:22,294 - INFO - Saved metadata for 2401.02920
# 2025-11-13 22:59:22,294 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:59:22,294 - INFO - Processing 1 versions of 2401.02920
# 2025-11-13 22:59:22,295 - INFO - Downloading source for 2401.02920v1
# 2025-11-13 22:59:22,808 - INFO - Downloaded 2401.02920v1
# 2025-11-13 22:59:22,808 - INFO - Extracting 2401.02920v1.tar.gz (685751 bytes)
# 2025-11-13 22:59:22,833 - INFO - Removed 27 figure files from extracted
# 2025-11-13 22:59:22,834 - INFO - Found 21 LaTeX files
# 2025-11-13 22:59:22,834 - INFO - Extracted 2401.02920v1: 685751 -> 382621 bytes (27 figures removed)
# 2025-11-13 22:59:22,841 - INFO - Copied 20 .tex files and 0 .bib files for 2401.02920
# 2025-11-13 22:59:22,842 - INFO - ✓ Organized 2401.02920v1
# 2025-11-13 22:59:22,842 - INFO - ✓ Processed 2401.02920v1
# 2025-11-13 22:59:22,842 - INFO - Fetching references...
# 2025-11-13 22:59:22,842 - INFO - Fetching references for arXiv:2401.02920 (attempt 1)
# 2025-11-13 22:59:23,501 - INFO - Successfully fetched references for 2401.02920
# 2025-11-13 22:59:23,502 - INFO - Saved 12 arXiv references for 2401.02920
# 2025-11-13 22:59:24,502 - INFO - ✓ Completed in 2.21s
# 2025-11-13 22:59:24,503 - INFO -
# ============================================================
# 2025-11-13 22:59:24,503 - INFO - [4812/5000] 2401.02931: SPFormer: Enhancing Vision Transformer with Superpixel Representation...
# 2025-11-13 22:59:24,503 - INFO - Saved metadata for 2401.02931
# 2025-11-13 22:59:24,503 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:59:24,504 - INFO - Processing 1 versions of 2401.02931
# 2025-11-13 22:59:24,504 - INFO - Downloading source for 2401.02931v1
# 2025-11-13 22:59:25,003 - INFO - Downloaded 2401.02931v1
# 2025-11-13 22:59:25,004 - INFO - Extracting 2401.02931v1.tar.gz (400176 bytes)
# 2025-11-13 22:59:25,012 - INFO - Removed 6 figure files from extracted
# 2025-11-13 22:59:25,013 - INFO - Found 10 LaTeX files
# 2025-11-13 22:59:25,013 - INFO - Extracted 2401.02931v1: 400176 -> 93981 bytes (6 figures removed)
# 2025-11-13 22:59:25,016 - INFO - Copied 8 .tex files and 0 .bib files for 2401.02931
# 2025-11-13 22:59:25,016 - INFO - ✓ Organized 2401.02931v1
# 2025-11-13 22:59:25,016 - INFO - ✓ Processed 2401.02931v1
# 2025-11-13 22:59:25,016 - INFO - Fetching references...
# 2025-11-13 22:59:25,016 - INFO - Fetching references for arXiv:2401.02931 (attempt 1)
# 2025-11-13 22:59:25,693 - INFO - Successfully fetched references for 2401.02931
# 2025-11-13 22:59:25,695 - INFO - Saved 47 arXiv references for 2401.02931
# 2025-11-13 22:59:26,695 - INFO - ✓ Completed in 2.19s
# 2025-11-13 22:59:26,695 - INFO -
# ============================================================
# 2025-11-13 22:59:26,695 - INFO - [4813/5000] 2401.02932: The Fate of Primary Iron Sulfides in the CM1 Carbonaceous Chondrites: Effects of...
# 2025-11-13 22:59:26,696 - INFO - Saved metadata for 2401.02932
# 2025-11-13 22:59:26,696 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:59
- INFO - Downloading 2 versions in parallel...
# 2025-11-13 22:59:46,875 - INFO - Processing 2 versions of 2401.02945
# 2025-11-13 22:59:46,876 - INFO - Downloading source for 2401.02945v1
# 2025-11-13 22:59:46,877 - INFO - Downloading source for 2401.02945v2
# 2025-11-13 22:59:52,147 - INFO - Downloaded 2401.02945v2
# 2025-11-13 22:59:52,148 - INFO - Extracting 2401.02945v2.tar.gz (15563190 bytes)
# 2025-11-13 22:59:52,274 - INFO - Removed 31 figure files from extracted
# 2025-11-13 22:59:52,277 - INFO - Found 12 LaTeX files
# 2025-11-13 22:59:52,277 - INFO - Extracted 2401.02945v2: 15563190 -> 808327 bytes (31 figures removed)
# 2025-11-13 22:59:52,280 - INFO - Copied 8 .tex files and 1 .bib files for 2401.02945
# 2025-11-13 22:59:52,281 - INFO - ✓ Organized 2401.02945v2
# 2025-11-13 22:59:52,281 - INFO - ✓ Processed 2401.02945v2
# 2025-11-13 22:59:55,170 - INFO - Downloaded 2401.02945v1
# 2025-11-13 22:59:55,170 - INFO - Extracting 2401.02945v1.tar.gz (15562784 bytes)
# 2025-11-13 22:59:55,296 - INFO - Removed 31 figure files from extracted
# 2025-11-13 22:59:55,299 - INFO - Found 12 LaTeX files
# 2025-11-13 22:59:55,299 - INFO - Extracted 2401.02945v1: 15562784 -> 805174 bytes (31 figures removed)
# 2025-11-13 22:59:55,302 - INFO - Copied 8 .tex files and 1 .bib files for 2401.02945
# 2025-11-13 22:59:55,303 - INFO - ✓ Organized 2401.02945v1
# 2025-11-13 22:59:55,303 - INFO - ✓ Processed 2401.02945v1
# 2025-11-13 22:59:55,303 - INFO - Fetching references...
# 2025-11-13 22:59:55,304 - INFO - Fetching references for arXiv:2401.02945 (attempt 1)
# 2025-11-13 22:59:56,213 - INFO - Successfully fetched references for 2401.02945
# 2025-11-13 22:59:56,217 - INFO - Saved 97 arXiv references for 2401.02945
# 2025-11-13 22:59:57,217 - INFO - ✓ Completed in 10.34s
# 2025-11-13 22:59:57,218 - INFO -
# ============================================================
# 2025-11-13 22:59:57,218 - INFO - [4816/5000] 2401.02953: Linked factor analysis...
# 2025-11-13 22:59:57,218 - INFO - Saved metadata for 2401.02953
# 2025-11-13 22:59:57,219 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 22:59:57,219 - INFO - Processing 1 versions of 2401.02953
# 2025-11-13 22:59:57,219 - INFO - Downloading source for 2401.02953v1
# 2025-11-13 23:00:00,262 - INFO - Downloaded 2401.02953v1
# 2025-11-13 23:00:00,262 - INFO - Extracting 2401.02953v1.tar.gz (6680688 bytes)
# 2025-11-13 23:00:00,322 - INFO - Removed 9 figure files from extracted
# 2025-11-13 23:00:00,323 - INFO - Found 2 LaTeX files
# 2025-11-13 23:00:00,324 - INFO - Extracted 2401.02953v1: 6680688 -> 125176 bytes (9 figures removed)
# 2025-11-13 23:00:00,324 - INFO - Copied 1 .tex files and 1 .bib files for 2401.02953
# 2025-11-13 23:00:00,325 - INFO - ✓ Organized 2401.02953v1
# 2025-11-13 23:00:00,325 - INFO - ✓ Processed 2401.02953v1
# 2025-11-13 23:00:00,325 - INFO - Fetching references...
# 2025-11-13 23:00:00,325 - INFO - Fetching references for arXiv:2401.02953 (attempt 1)
# 2025-11-13 23:00:00,969 - INFO - Successfully fetched references for 2401.02953
# 2025-11-13 23:00:00,971 - INFO - Saved 10 arXiv references for 2401.02953
# 2025-11-13 23:00:01,971 - INFO - ✓ Completed in 4.75s
# 2025-11-13 23:00:01,971 - INFO -
# ============================================================
# 2025-11-13 23:00:01,971 - INFO - [4817/5000] 2401.02959: A toy model for approaching volcanic plumbing systems as complex systems...
# 2025-11-13 23:00:01,972 - INFO - Saved metadata for 2401.02959
# 2025-11-13 23:00:01,972 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 23:00:01,972 - INFO - Processing 1 versions of 2401.02959
# 2025-11-13 23:00:01,973 - INFO - Downloading source for 2401.02959v1
# 2025-11-13 23:00:02,648 - INFO - Downloaded 2401.02959v1
# 2025-11-13 23:00:02,649 - INFO - Extracting 2401.02959v1.tar.gz (295004 bytes)
# 2025-11-13 23:00:02,653 - INFO - Removed 1 figure files from extracted
# 2025-11-13 23:00:02,654 - INFO - Found 4 LaTeX files
# 2025-11-13 23:00:02,654 - INFO - Extracted 2401.02959v1: 295004 -> 88490 bytes (1 figures removed)
# 2025-11-13 23:00:02,655 - INFO - Copied 1 .tex files and 1 .bib files for 2401.02959
# 2025-11-13 23:00:02,655 - INFO - ✓ Organized 2401.02959v1
# 2025-11-13 23:00:02,655 - INFO - ✓ Processed 2401.02959v1
# 2025-11-13 23:00:02,655 - INFO - Fetching references...
# 2025-11-13 23:00:02,655 - INFO - Fetching references for arXiv:2401.02959 (attempt 1)
# 2025-11-13 23:00:03,118 - INFO - Successfully fetched references for 2401.02959
# 2025-11-13 23:00:03,118 - INFO - Saved 0 arXiv references for 2401.02959
# 2025-11-13 23:00:04,119 - INFO - ✓ Completed in 2.15s
# 2025-11-13 23:00:04,119 - INFO -
# ============================================================
# 2025-11-13 23:00:04,119 - INFO - [4818/5000] 2401.02969: Jovian electrons in the inner heliosphere: Opportunities for Multi-spacecraft Ob...
# 2025-11-13 23:00:04,120 - INFO - Saved metadata for 2401.02969
# 2025-11-13 23:00:04,120 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 23:00:04,120 - INFO - Processing 1 versions of 2401.02969
# 2025-11-13 23:00:04,120 - INFO - Downloading source for 2401.02969v1
# 2025-11-13 23:00:08,794 - INFO - Downloaded 2401.02969v1
# 2025-11-13 23:00:08,794 - INFO - Extracting 2401.02969v1.tar.gz (7969975 bytes)
# 2025-11-13 23:00:08,896 - INFO - Removed 12 figure files from extracted
# 2025-11-13 23:00:08,899 - INFO - Found 3 LaTeX files
# 2025-11-13 23:00:08,899 - INFO - Extracted 2401.02969v1: 7969975 -> 283083 bytes (12 figures removed)
# 2025-11-13 23:00:08,900 - INFO - Copied 1 .tex files and 1 .bib files for 2401.02969
# 2025-11-13 23:00:08,901 - INFO - ✓ Organized 2401.02969v1
# 2025-11-13 23:00:08,901 - INFO - ✓ Processed 2401.02969v1
# 2025-11-13 23:00:08,901 - INFO - Fetching references...
# 2025-11-13 23:00:08,901 - INFO - Fetching references for arXiv:2401.02969 (attempt 1)
# 2025-11-13 23:00:09,684 - INFO - Successfully fetched references for 2401.02969
- INFO - Copied 1 .tex files and 1 .bib files for 2401.02930
# 2025-11-13 23:00:58,600 - INFO - ✓ Organized 2401.02930v1
# 2025-11-13 23:00:58,600 - INFO - ✓ Processed 2401.02930v1
# 2025-11-13 23:00:58,600 - INFO - Fetching references...
# 2025-11-13 23:00:58,600 - INFO - Fetching references for arXiv:2401.02930 (attempt 1)
# 2025-11-13 23:00:58,840 - INFO - Successfully fetched references for 2401.02930
# 2025-11-13 23:00:58,841 - INFO - Saved 10 arXiv references for 2401.02930
# 2025-11-13 23:00:59,842 - INFO - ✓ Completed in 1.66s
# 2025-11-13 23:00:59,842 - INFO -
# ============================================================
# 2025-11-13 23:00:59,842 - INFO - [4827/5000] 2401.02915: Contragredient Lie algebras in symmetric categories...
# 2025-11-13 23:00:59,843 - INFO - Saved metadata for 2401.02915
# 2025-11-13 23:00:59,843 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 23:00:59,843 - INFO - Processing 1 versions of 2401.02915
# 2025-11-13 23:00:59,843 - INFO - Downloading source for 2401.02915v1
# 2025-11-13 23:01:00,379 - INFO - Downloaded 2401.02915v1
# 2025-11-13 23:01:00,380 - INFO - Extracting 2401.02915v1.tar.gz (52762 bytes)
# 2025-11-13 23:01:00,383 - INFO - Found 1 LaTeX files
# 2025-11-13 23:01:00,383 - INFO - Extracted 2401.02915v1: 52762 -> 198724 bytes (0 figures removed)
# 2025-11-13 23:01:00,384 - INFO - Copied 1 .tex files and 0 .bib files for 2401.02915
# 2025-11-13 23:01:00,385 - INFO - ✓ Organized 2401.02915v1
# 2025-11-13 23:01:00,385 - INFO - ✓ Processed 2401.02915v1
# 2025-11-13 23:01:00,385 - INFO - Fetching references...
# 2025-11-13 23:01:00,385 - INFO - Fetching references for arXiv:2401.02915 (attempt 1)
# 2025-11-13 23:01:00,864 - INFO - Successfully fetched references for 2401.02915
# 2025-11-13 23:01:00,865 - INFO - Saved 17 arXiv references for 2401.02915
# 2025-11-13 23:01:01,865 - INFO - ✓ Completed in 2.02s
# 2025-11-13 23:01:01,866 - INFO -
# ============================================================
# 2025-11-13 23:01:01,866 - INFO - [4828/5000] 2401.02918: Approximation Algorithms for the Weighted Nash Social Welfare via Convex and Non...
# 2025-11-13 23:01:01,866 - INFO - Saved metadata for 2401.02918
# 2025-11-13 23:01:01,866 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 23:01:01,867 - INFO - Processing 1 versions of 2401.02918
# 2025-11-13 23:01:01,867 - INFO - Downloading source for 2401.02918v1
# 2025-11-13 23:01:02,720 - INFO - Downloaded 2401.02918v1
# 2025-11-13 23:01:02,720 - INFO - Extracting 2401.02918v1.tar.gz (31269 bytes)
# 2025-11-13 23:01:02,722 - INFO - Found 1 LaTeX files
# 2025-11-13 23:01:02,722 - INFO - Extracted 2401.02918v1: 31269 -> 125931 bytes (0 figures removed)
# 2025-11-13 23:01:02,723 - INFO - Copied 1 .tex files and 0 .bib files for 2401.02918
# 2025-11-13 23:01:02,723 - INFO - ✓ Organized 2401.02918v1
# 2025-11-13 23:01:02,723 - INFO - ✓ Processed 2401.02918v1
# 2025-11-13 23:01:02,724 - INFO - Fetching references...
# 2025-11-13 23:01:02,724 - INFO - Fetching references for arXiv:2401.02918 (attempt 1)
# 2025-11-13 23:01:03,220 - INFO - Successfully fetched references for 2401.02918
# 2025-11-13 23:01:03,221 - INFO - Saved 8 arXiv references for 2401.02918
# 2025-11-13 23:01:04,221 - INFO - ✓ Completed in 2.36s
# 2025-11-13 23:01:04,221 - INFO -
# ============================================================
# 2025-11-13 23:01:04,222 - INFO - [4829/5000] 2401.02921: Towards ASR Robust Spoken Language Understanding Through In-Context Learning Wit...
# 2025-11-13 23:01:04,222 - INFO - Saved metadata for 2401.02921
# 2025-11-13 23:01:04,222 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 23:01:04,222 - INFO - Processing 1 versions of 2401.02921
# 2025-11-13 23:01:04,223 - INFO - Downloading source for 2401.02921v1
# 2025-11-13 23:01:04,945 - INFO - Downloaded 2401.02921v1
# 2025-11-13 23:01:04,946 - INFO - Extracting 2401.02921v1.tar.gz (933623 bytes)
# 2025-11-13 23:01:04,960 - INFO - Removed 15 figure files from extracted
# 2025-11-13 23:01:04,961 - INFO - Found 4 LaTeX files
# 2025-11-13 23:01:04,961 - INFO - Extracted 2401.02921v1: 933623 -> 120297 bytes (15 figures removed)
# 2025-11-13 23:01:04,962 - INFO - Copied 1 .tex files and 1 .bib files for 2401.02921
# 2025-11-13 23:01:04,962 - INFO - ✓ Organized 2401.02921v1
# 2025-11-13 23:01:04,962 - INFO - ✓ Processed 2401.02921v1
# 2025-11-13 23:01:04,962 - INFO - Fetching references...
# 2025-11-13 23:01:04,963 - INFO - Fetching references for arXiv:2401.02921 (attempt 1)
# 2025-11-13 23:01:05,749 - INFO - Successfully fetched references for 2401.02921
# 2025-11-13 23:01:05,750 - INFO - Saved 21 arXiv references for 2401.02921
# 2025-11-13 23:01:06,751 - INFO - ✓ Completed in 2.53s
# 2025-11-13 23:01:06,751 - INFO -
# ============================================================
# 2025-11-13 23:01:06,751 - INFO - [4830/5000] 2401.02935: Towards a zk-SNARK compiler for Wolfram language...
# 2025-11-13 23:01:06,752 - INFO - Saved metadata for 2401.02935
# 2025-11-13 23:01:06,752 - INFO - Downloading 1 versions in parallel...
# 2025-11-13 23:01:06,752 - INFO - Processing 1 versions of 2401.02935
# 2025-11-13 23:01:06,752 - INFO - Downloading source for 2401.02935v1
# 2025-11-13 23:01:08,330 - INFO - Downloaded 2401.02935v1
# 2025-11-13 23:01:08,330 - INFO - Extracting 2401.02935v1.tar.gz (2374391 bytes)
# 2025-11-13 23:01:08,355 - INFO - Removed 9 figure files from extracted
# 2025-11-13 23:01:08,356 - INFO - Found 4 LaTeX files
# 2025-11-13 23:01:08,356 - INFO - Extracted 2401.02935v1: 2374391 -> 79009 bytes (9 figures removed)
# 2025-11-13 23:01:08,357 - INFO - Copied 1 .tex files and 1 .bib files for 2401.02935
# 2025-11-13 23:01:08,357 - INFO - ✓ Organized 2401.02935v1
# 2025-11-13 23:01:08,358 - INFO - ✓ Processed 2401.02935v1
# 2025-11-13 23:01:08,358 - INFO - Fetching references...
# 2025-11-13 23:01:08,358 - INFO - Fetching references for arXiv:2401.02935 (attempt 1)
# 2025-11-13 23:01:08,860 - INFO - Successfully fetched references for 2401.02935
# 2025-11-13 23:01:08,861 - INFO - Saved 0 arXiv references for 2401.02935
# 2025-11-13 23:01:09,861 - INFO - ✓ Completed in 3.11s
# ...
# 2025-11-13 23:11:35,551 - INFO - Extracting 2401.03087v1.tar.gz (51984 bytes)
# 2025-11-13 23:11:35,553 - INFO - Found 2 LaTeX files
# 2025-11-13 23:11:35,553 - INFO - Extracted 2401.03087v1: 51984 -> 174983 bytes (0 figures removed)
# 2025-11-13 23:11:35,554 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03087
# 2025-11-13 23:11:35,554 - INFO - ✓ Organized 2401.03087v1
# 2025-11-13 23:11:35,555 - INFO - ✓ Processed 2401.03087v1
# 2025-11-13 23:11:35,664 - INFO - Downloaded 2401.03087v2
# 2025-11-13 23:11:35,665 - INFO - Extracting 2401.03087v2.tar.gz (52774 bytes)
# 2025-11-13 23:11:35,667 - INFO - Found 2 LaTeX files
# 2025-11-13 23:11:35,668 - INFO - Extracted 2401.03087v2: 52774 -> 176038 bytes (0 figures removed)
# 2025-11-13 23:11:35,668 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03087
# 2025-11-13 23:11:35,669 - INFO - ✓ Organized 2401.03087v2
# 2025-11-13 23:11:35,669 - INFO - ✓ Processed 2401.03087v2
# 2025-11-13 23:11:35,669 - INFO - Fetching references...
# 2025-11-13 23:11:35,669 - INFO - Fetching references for arXiv:2401.03087 (attempt 1)
# 2025-11-13 23:11:36,052 - INFO - Successfully fetched references for 2401.03087
# 2025-11-13 23:11:36,053 - INFO - Saved 22 arXiv references for 2401.03087
# 2025-11-13 23:11:37,053 - INFO - ✓ Completed in 1.88s
# 2025-11-13 23:11:37,053 - INFO -
# ============================================================
# 2025-11-13 23:11:37,053 - INFO - [4996/5000] 2401.03089: Continuously bounds-preserving discontinuous Galerkin methods for hyperbolic con...
# 2025-11-13 23:11:37,054 - INFO - Saved metadata for 2401.03089
# 2025-11-13 23:11:37,054 - INFO - Downloading 2 versions in parallel...
# 2025-11-13 23:11:37,054 - INFO - Processing 2 versions of 2401.03089
# 2025-11-13 23:11:37,054 - INFO - Downloading source for 2401.03089v1
# 2025-11-13 23:11:37,055 - INFO - Downloading source for 2401.03089v2
# 2025-11-13 23:11:37,882 - INFO - Downloaded 2401.03089v2
# 2025-11-13 23:11:37,883 - INFO - Extracting 2401.03089v2.tar.gz (1088300 bytes)
# 2025-11-13 23:11:37,935 - INFO - Downloaded 2401.03089v1
# 2025-11-13 23:11:37,936 - INFO - Extracting 2401.03089v1.tar.gz (1086191 bytes)
# 2025-11-13 23:11:37,959 - INFO - Removed 15 figure files from extracted
# 2025-11-13 23:11:37,964 - INFO - Found 45 LaTeX files
# 2025-11-13 23:11:37,964 - INFO - Extracted 2401.03089v2: 1088300 -> 405326 bytes (15 figures removed)
# 2025-11-13 23:11:37,995 - INFO - Copied 39 .tex files and 1 .bib files for 2401.03089
# 2025-11-13 23:11:38,002 - INFO - ✓ Organized 2401.03089v2
# 2025-11-13 23:11:38,002 - INFO - ✓ Processed 2401.03089v2
# 2025-11-13 23:11:38,021 - INFO - Removed 15 figure files from extracted
# 2025-11-13 23:11:38,023 - INFO - Found 43 LaTeX files
# 2025-11-13 23:11:38,023 - INFO - Extracted 2401.03089v1: 1086191 -> 399109 bytes (15 figures removed)
# 2025-11-13 23:11:38,036 - INFO - Copied 37 .tex files and 1 .bib files for 2401.03089
# 2025-11-13 23:11:38,039 - INFO - ✓ Organized 2401.03089v1
# 2025-11-13 23:11:38,039 - INFO - ✓ Processed 2401.03089v1
# 2025-11-13 23:11:38,039 - INFO - Fetching references...
# 2025-11-13 23:11:38,039 - INFO - Fetching references for arXiv:2401.03089 (attempt 1)
# 2025-11-13 23:11:38,711 - INFO - Successfully fetched references for 2401.03089
# 2025-11-13 23:11:38,712 - INFO - Saved 15 arXiv references for 2401.03089
# 2025-11-13 23:11:39,713 - INFO - ✓ Completed in 2.66s
# 2025-11-13 23:11:39,713 - INFO -
# ============================================================
# 2025-11-13 23:11:39,713 - INFO - [4997/5000] 2401.03028: Phase transitions and scale invariance in topological Anderson insulators...
# 2025-11-13 23:11:39,714 - INFO - Saved metadata for 2401.03028
# 2025-11-13 23:11:39,714 - INFO - Downloading 2 versions in parallel...
# 2025-11-13 23:11:39,714 - INFO - Processing 2 versions of 2401.03028
# 2025-11-13 23:11:39,714 - INFO - Downloading source for 2401.03028v1
# 2025-11-13 23:11:39,714 - INFO - Downloading source for 2401.03028v2
# 2025-11-13 23:11:42,320 - INFO - Downloaded 2401.03028v1
# 2025-11-13 23:11:42,321 - INFO - Extracting 2401.03028v1.tar.gz (5793347 bytes)
# 2025-11-13 23:11:42,383 - INFO - Removed 7 figure files from extracted
# 2025-11-13 23:11:42,384 - INFO - Found 3 LaTeX files
# 2025-11-13 23:11:42,384 - INFO - Extracted 2401.03028v1: 5793347 -> 183708 bytes (7 figures removed)
# 2025-11-13 23:11:42,385 - INFO - Copied 2 .tex files and 1 .bib files for 2401.03028
# 2025-11-13 23:11:42,386 - INFO - ✓ Organized 2401.03028v1
# 2025-11-13 23:11:42,386 - INFO - ✓ Processed 2401.03028v1
# 2025-11-13 23:11:42,431 - INFO - Downloaded 2401.03028v2
# 2025-11-13 23:11:42,432 - INFO - Extracting 2401.03028v2.tar.gz (5564423 bytes)
# 2025-11-13 23:11:42,489 - INFO - Removed 9 figure files from extracted
# 2025-11-13 23:11:42,490 - INFO - Found 3 LaTeX files
# 2025-11-13 23:11:42,491 - INFO - Extracted 2401.03028v2: 5564423 -> 197865 bytes (9 figures removed)
# 2025-11-13 23:11:42,492 - INFO - Copied 2 .tex files and 1 .bib files for 2401.03028
# 2025-11-13 23:11:42,492 - INFO - ✓ Organized 2401.03028v2
# 2025-11-13 23:11:42,492 - INFO - ✓ Processed 2401.03028v2
# 2025-11-13 23:11:42,493 - INFO - Fetching references...
# 2025-11-13 23:11:42,493 - INFO - Fetching references for arXiv:2401.03028 (attempt 1)
# 2025-11-13 23:11:42,922 - INFO - Successfully fetched references for 2401.03028
# 2025-11-13 23:11:42,924 - INFO - Saved 52 arXiv references for 2401.03028
# 2025-11-13 23:11:43,924 - INFO - ✓ Completed in 4.21s
# 2025-11-13 23:11:43,924 - INFO -
# ============================================================
# 2025-11-13 23:11:43,925 - INFO - [4998/5000] 2401.03090: Generalized Stein's lemma and asymptotic equipartition property for subalgebra e...
# 2025-11-13 23:11:43,925 - INFO - Saved metadata for 2401.03090
# 2025-11-13 23:11:43,925 - INFO - Downloading 2 versions in parallel...
# 2025-11-13 23:11:43,926 - INFO - Processing 2 versions of 2401.03090
# 2025-11-13 23:11:43,926 - INFO - Downloading source for 2401.03090v1
# 2025-11-13 23:11:43,926 - INFO - Downloading source for 2401.03090v2
# 2025-11-13 23:11:44,301 - INFO - Downloaded 2401.03090v2
# 2025-11-13 23:11:44,302 - INFO - Extracting 2401.03090v2.tar.gz (24011 bytes)
# 2025-11-13 23:11:44,304 - INFO - Found 1 LaTeX files
# 2025-11-13 23:11:44,305 - INFO - Extracted 2401.03090v2: 24011 -> 76942 bytes (0 figures removed)
# 2025-11-13 23:11:44,306 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03090
# 2025-11-13 23:11:44,306 - INFO - ✓ Organized 2401.03090v2
# 2025-11-13 23:11:44,306 - INFO - ✓ Processed 2401.03090v2
# 2025-11-13 23:11:44,359 - INFO - Downloaded 2401.03090v1
# 2025-11-13 23:11:44,360 - INFO - Extracting 2401.03090v1.tar.gz (23751 bytes)
# 2025-11-13 23:11:44,362 - INFO - Found 1 LaTeX files
# 2025-11-13 23:11:44,362 - INFO - Extracted 2401.03090v1: 23751 -> 76381 bytes (0 figures removed)
# 2025-11-13 23:11:44,363 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03090
# 2025-11-13 23:11:44,363 - INFO - ✓ Organized 2401.03090v1
# 2025-11-13 23:11:44,363 - INFO - ✓ Processed 2401.03090v1
# 2025-11-13 23:11:44,364 - INFO - Fetching references...
# 2025-11-13 23:11:44,364 - INFO - Fetching references for arXiv:2401.03090 (attempt 1)
# 2025-11-13 23:11:44,838 - INFO - Successfully fetched references for 2401.03090
# 2025-11-13 23:11:44,839 - INFO - Saved 24 arXiv references for 2401.03090
# 2025-11-13 23:11:45,840 - INFO - ✓ Completed in 1.91s
# 2025-11-13 23:11:45,840 - INFO -
# ============================================================
# 2025-11-13 23:11:45,840 - INFO - [4999/5000] 2401.03036: Modelling and calibration of pair-rule protein patterns in Drosophila embryo: Fr...
# 2025-11-13 23:11:45,841 - INFO - Saved metadata for 2401.03036
# 2025-11-13 23:11:45,841 - INFO - Downloading 4 versions in parallel...
# 2025-11-13 23:11:45,841 - INFO - Processing 4 versions of 2401.03036
# 2025-11-13 23:11:45,841 - INFO - Downloading source for 2401.03036v1
# 2025-11-13 23:11:45,841 - INFO - Downloading source for 2401.03036v2
# 2025-11-13 23:11:45,842 - INFO - Downloading source for 2401.03036v3
# 2025-11-13 23:11:47,232 - INFO - Downloaded 2401.03036v2
# 2025-11-13 23:11:47,233 - INFO - Extracting 2401.03036v2.tar.gz (3089293 bytes)
# 2025-11-13 23:11:47,259 - INFO - Removed 11 figure files from extracted
# 2025-11-13 23:11:47,260 - INFO - Found 1 LaTeX files
# 2025-11-13 23:11:47,260 - INFO - Extracted 2401.03036v2: 3089293 -> 91415 bytes (11 figures removed)
# 2025-11-13 23:11:47,260 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03036
# 2025-11-13 23:11:47,261 - INFO - ✓ Organized 2401.03036v2
# 2025-11-13 23:11:47,261 - INFO - Downloading source for 2401.03036v4
# 2025-11-13 23:11:47,261 - INFO - ✓ Processed 2401.03036v2
# 2025-11-13 23:11:47,309 - INFO - Downloaded 2401.03036v1
# 2025-11-13 23:11:47,309 - INFO - Extracting 2401.03036v1.tar.gz (3027553 bytes)
# 2025-11-13 23:11:47,336 - INFO - Removed 10 figure files from extracted
# 2025-11-13 23:11:47,336 - INFO - Found 1 LaTeX files
# 2025-11-13 23:11:47,336 - INFO - Extracted 2401.03036v1: 3027553 -> 90917 bytes (10 figures removed)
# 2025-11-13 23:11:47,337 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03036
# 2025-11-13 23:11:47,337 - INFO - ✓ Organized 2401.03036v1
# 2025-11-13 23:11:47,337 - INFO - ✓ Processed 2401.03036v1
# 2025-11-13 23:11:47,567 - INFO - Downloaded 2401.03036v3
# 2025-11-13 23:11:47,567 - INFO - Extracting 2401.03036v3.tar.gz (3100172 bytes)
# 2025-11-13 23:11:47,595 - INFO - Removed 11 figure files from extracted
# 2025-11-13 23:11:47,595 - INFO - Found 1 LaTeX files
# 2025-11-13 23:11:47,595 - INFO - Extracted 2401.03036v3: 3100172 -> 92941 bytes (11 figures removed)
# 2025-11-13 23:11:47,596 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03036
# 2025-11-13 23:11:47,596 - INFO - ✓ Organized 2401.03036v3
# 2025-11-13 23:11:47,596 - INFO - ✓ Processed 2401.03036v3
# 2025-11-13 23:11:48,230 - INFO - Downloaded 2401.03036v4
# 2025-11-13 23:11:48,230 - INFO - Extracting 2401.03036v4.tar.gz (3099738 bytes)
# 2025-11-13 23:11:48,256 - INFO - Removed 11 figure files from extracted
# 2025-11-13 23:11:48,257 - INFO - Found 1 LaTeX files
# 2025-11-13 23:11:48,257 - INFO - Extracted 2401.03036v4: 3099738 -> 91863 bytes (11 figures removed)
# 2025-11-13 23:11:48,258 - INFO - Copied 1 .tex files and 0 .bib files for 2401.03036
# 2025-11-13 23:11:48,258 - INFO - ✓ Organized 2401.03036v4
# 2025-11-13 23:11:48,258 - INFO - ✓ Processed 2401.03036v4
# 2025-11-13 23:11:48,259 - INFO - Fetching references...
# 2025-11-13 23:11:48,259 - INFO - Fetching references for arXiv:2401.03036 (attempt 1)
# 2025-11-13 23:11:48,892 - INFO - Successfully fetched references for 2401.03036
# 2025-11-13 23:11:48,893 - INFO - Saved 2 arXiv references for 2401.03036
# 2025-11-13 23:11:49,893 - INFO - ✓ Completed in 4.05s
# 2025-11-13 23:11:49,893 - INFO -
# ============================================================
# 2025-11-13 23:11:49,893 - INFO - [5000/5000] 2401.03015: Ground state energy and magnetization curve of a frustrated magnetic system from...
# 2025-11-13 23:11:49,894 - INFO - Saved metadata for 2401.03015
# 2025-11-13 23:11:49,894 - INFO - Downloading 3 versions in parallel...
# 2025-11-13 23:11:49,894 - INFO - Processing 3 versions of 2401.03015
# 2025-11-13 23:11:49,894 - INFO - Downloading source for 2401.03015v1
# 2025-11-13 23:11:49,895 - INFO - Downloading source for 2401.03015v2
# 2025-11-13 23:11:49,897 - INFO - Downloading source for 2401.03015v3
# 2025-11-13 23:11:51,375 - INFO - Downloaded 2401.03015v1
# 2025-11-13 23:11:51,376 - INFO - Extracting 2401.03015v1.tar.gz (4539953 bytes)
# 2025-11-13 23:11:51,422 - INFO - Removed 19 figure files from extracted
# 2025-11-13 23:11:51,423 - INFO - Found 12 LaTeX files
# 2025-11-13 23:11:51,423 - INFO - Extracted 2401.03015v1: 4539953 -> 193649 bytes (19 figures removed)
# 2025-11-13 23:11:51,427 - INFO - Copied 12 .tex files and 0 .bib files for 2401.03015
# 2025-11-13 23:11:51,428 - INFO - ✓ Organized 2401.03015v1
# 2025-11-13 23:11:51,428 - INFO - ✓ Processed 2401.03015v1
# 2025-11-13 23:11:51,928 - INFO - Downloaded 2401.03015v3
# 2025-11-13 23:11:51,928 - INFO - Extracting 2401.03015v3.tar.gz (4861239 bytes)
# 2025-11-13 23:11:51,979 - INFO - Removed 20 figure files from extracted
# 2025-11-13 23:11:51,980 - INFO - Found 12 LaTeX files
# 2025-11-13 23:11:51,980 - INFO - Extracted 2401.03015v3: 4861239 -> 205135 bytes (20 figures removed)
# 2025-11-13 23:11:51,984 - INFO - Copied 12 .tex files and 0 .bib files for 2401.03015
# 2025-11-13 23:11:51,985 - INFO - ✓ Organized 2401.03015v3
# 2025-11-13 23:11:51,985 - INFO - ✓ Processed 2401.03015v3
# 2025-11-13 23:11:52,823 - INFO - Downloaded 2401.03015v2
# 2025-11-13 23:11:52,824 - INFO - Extracting 2401.03015v2.tar.gz (4860334 bytes)
# 2025-11-13 23:11:52,873 - INFO - Removed 20 figure files from extracted
# 2025-11-13 23:11:52,875 - INFO - Found 12 LaTeX files
# 2025-11-13 23:11:52,875 - INFO - Extracted 2401.03015v2: 4860334 -> 204764 bytes (20 figures removed)
# 2025-11-13 23:11:52,878 - INFO - Copied 12 .tex files and 0 .bib files for 2401.03015
# 2025-11-13 23:11:52,879 - INFO - ✓ Organized 2401.03015v2
# 2025-11-13 23:11:52,879 - INFO - ✓ Processed 2401.03015v2
# 2025-11-13 23:11:52,880 - INFO - Fetching references...
# 2025-11-13 23:11:52,880 - INFO - Fetching references for arXiv:2401.03015 (attempt 1)
# 2025-11-13 23:11:53,555 - INFO - Successfully fetched references for 2401.03015
# 2025-11-13 23:11:53,557 - INFO - Saved 82 arXiv references for 2401.03015
# 2025-11-13 23:11:54,557 - INFO - ✓ Completed in 4.66s
# 2025-11-13 23:11:54,636 - INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251113_231154.json
# 2025-11-13 23:11:54,636 - INFO - Completed phase 'Paper Processing' in 25152.39s
# 2025-11-13 23:11:54,636 - INFO -
# --- Cleaning up temporary files ---
# 2025-11-13 23:11:55,595 - INFO - ✓ Cleaned up temp directory
# 2025-11-13 23:11:55,595 - INFO -
# ================================================================================
# 2025-11-13 23:11:55,595 - INFO - Pipeline completed!
# 2025-11-13 23:11:55,595 - INFO - ================================================================================
# 2025-11-13 23:11:59,775 - INFO - Statistics tracking completed
# 2025-11-13 23:11:59,800 - INFO - Statistics saved to /content/arxiv_scraper/data/statistics_final.json
# 2025-11-13 23:11:59,843 - INFO - Checkpoint saved to /content/arxiv_scraper/data/statistics/checkpoint_20251113_231159.json
#
# ================================================================================
# SCRAPING STATISTICS REPORT
# ================================================================================
#
# TIME INFORMATION:
#   Start Time: 2025-11-13 16:09:09.969660
#   End Time: 2025-11-13 23:11:58.460189
#   Total Duration: 7:02:48
#
# PHASE DURATIONS:
#   Metadata Harvesting (arXiv API): 0:00:00
#   Paper Processing: 6:59:12
#
# PAPER STATISTICS:
#   Total Identified: 0
#   Total Attempted: 5000
#   Successfully Downloaded: 5000
#   Failed Downloads: 0
#   Success Rate: 100.00%
#
# VERSION STATISTICS:
#   Total Versions: 8171
#   Successfully Processed: 8139
#   Failed Versions: 32
#
# PERFORMANCE METRICS:
#   Average Time per Paper: 5.03s
#   Fastest Paper: 1.53s
#   Slowest Paper: 82.23s
#
# FILE SIZE STATISTICS:
#   Average Size Before Figure Removal: 3.89 MB
#   Average Size After Figure Removal: 461.07 KB
#   Total Raw Size: 30.95 GB
#   Total Extracted Size: 3.58 GB
#   Space Saved: 27.37 GB
#   Figures Removed: 125606
#
# REFERENCE STATISTICS:
#   Papers with References: 4662
#   Papers without References: 338
#   Total References: 204472
#   Average References per Paper: 43.86
#   Reference Success Rate: 93.24%
#
# MEMORY USAGE:
#   Initial RAM: 35.19 MB
#   Peak RAM: 354.38 MB
#   Average RAM: 253.73 MB
#   Initial Disk Usage: 0.00 GB
#   Final Disk Usage: 3.30 GB
#   Disk Space Used: 3.30 GB
#
# ERROR STATISTICS:
#   Total Errors: 41
#   Error Types:
#     Download request error: HTTPError: 31
#     Reference not found (404): 9
#     Download request error: ConnectionError: 1
#
# ================================================================================
# 2025-11-13 23:11:59,843 - INFO -
# 📊 Statistics: /content/arxiv_scraper/data/statistics_final.json
# 2025-11-13 23:11:59,843 - INFO - 📁 Papers: /content/arxiv_scraper/data/papers

# %%
# !zip -r scrape_data.zip /content/arxiv_scraper/data/papers
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/arxiv_scraper/data/papers/2401-02116/tex/2401.02116v2/sections/1_intro.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2401-02116/tex/2401.02116v2/sections/4_search.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2401-02116/tex/2401.02116v2/sections/appendix.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2401-02116/tex/2401.02116v2/sections/5_exp.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2401-02116/tex/2401.02116v2/main.tex (deflated 60%)
#   adding: content/arxiv_scraper/data/papers/2401-02116/references.json (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-02116/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2312-17272/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17272/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17272/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17272/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/references.bib (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Conclusion.tex (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Calibration.tex (deflated 67%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Introduction.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/BelleIIExperiment.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Systematics.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/DataMC.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Recontruction.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Result.tex (deflated 78%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/Sections/Fit.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/main.tex (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/definitions.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/pub033-orcid.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/tex/2401.02840v1/acknowledgements.tex (deflated 55%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02840/metadata.json (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/tex/2401.00188v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/tex/2401.00188v1/ECPOGAM_03212023.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/tex/2401.00188v1/TradingStrategy_clean.bib (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00188/metadata.json (deflated 45%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/tex/2401.00154v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/tex/2401.00154v2/sn-article.tex (deflated 74%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/tex/2401.00154v2/sn-sample-bib.tex (deflated 40%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/tex/2401.00154v2/sn-bibliography.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/references.json (deflated 60%)
#   adding: content/arxiv_scraper/data/papers/2401-00154/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/2401.01160v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/2401.01160v1/main.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/2401.01160v1/main.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/2401.01160v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/2401.01160v2/main.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/tex/2401.01160v2/main.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-01160/metadata.json (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2312-17468/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17468/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17468/tex/2312.17468v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17468/tex/2312.17468v1/main.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-17468
)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/msrvtt_vatex_activitynet.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/msrvtt.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/msvd_supple.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/msrvttfull.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/activitynet_supple.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/msrvttfull_supple.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/vatex.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/msvd.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/analyse.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/activitynet.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/ab_weight.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/vatex_supple.tex (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/tables/ab_intraandinter.tex (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/conclusion.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/method.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/tex/2401.00701v1/related.tex (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-00701/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/tex/2312.17356v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/tex/2312.17356v1/bibliography.bib (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/tex/2312.17356v1/samplepaper.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/references.json (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2312-17356/metadata.json (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v2/sample.bib (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v2/main_v2_arxiv.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v3/sample.bib (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v3/main_v3_arxiv.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v1/main.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/tex/2312.17690v1/sample.bib (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17690/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/sections/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/sections/4results.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/sections/2preliminaries.tex (deflated 55%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/sections/5discussion.tex (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/sections/1introduction.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/sections/3optimization_framework.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/title_and_authors.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/appendix.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/abstract.tex (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/text/acknowledgements.tex (deflated 32%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/Refs.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v2/main.tex (deflated 57%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/sections/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/sections/4results.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/sections/2preliminaries.tex (deflated 55%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/sections/5discussion.tex (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/sections/1introduction.tex (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/sections/3optimization_framework.tex (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/title_and_authors.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/appendix.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/abstract.tex (deflated 42%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/text/acknowledgements.tex (deflated 23%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/Refs.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v1/main.tex (deflated 56%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v3/Refs.bib (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/tex/2401.00635v3/main.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/references.json (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2401-00635/metadata.json (deflated 48%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/2312.17492v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/2312.17492v1/aaai24.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/2312.17492v1/HEAP_camerady_ready.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/2312.17492v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/2312.17492v2/aaai24.bib (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/tex/2312.17492v2/HEAP_camerady_ready.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/references.json (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2312-17492/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/section4.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/section3.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/elsarticle-template-num-names.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/doc/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/doc/elsdoc.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/example_paper.bib (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/elsarticle-template-harv.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/main.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/elsarticle-template-num.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/section5.tex (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/section1.tex (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/tex/2401.00755v1/section2.tex (deflated 59%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-00755/metadata.json (deflated 55%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/2312.16335v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/2312.16335v2/refs.bib (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/2312.16335v2/main_arxiv_v2.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/2312.16335v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/2312.16335v1/main_arxiv.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/tex/2312.16335v1/commands.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/references.json (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2312-16335/metadata.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/figs/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/figs/fig_hA1.tex (deflated 25%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/figs/fig_stab_test_2+1_1.tex (deflated 63%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/figs/fig_hst_resid_2+2.tex (deflated 52%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/h_A1.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/intro.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/ref.bib (deflated 77%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/macro.tex (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/flow_chart.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/table/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/table/tab_minima_2+2.tex (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/table/tab_ensembles.tex (deflated 46%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/table/tab_symbol.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/main.tex (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/tex/2401.01561v1/application.tex (deflated 64%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/references.json (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-01561/metadata.json (deflated 44%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/tex/2312.16738v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/tex/2312.16738v2/manuscript_arxiv.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/tex/2312.16738v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/tex/2312.16738v1/manuscript_arxiv.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/references.json (deflated 51%)
#   adding: content/arxiv_scraper/data/papers/2312-16738/metadata.json (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v1/cas-refs.bib (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v1/doc/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v1/doc/glyphtounicode.tex (deflated 90%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v1/doc/elsdoc-cas.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v1/main.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/cas-refs.bib (deflated 71%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/cas-dc-template.tex (deflated 62%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/doc/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/doc/glyphtounicode.tex (deflated 90%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/doc/elsdoc-cas.tex (deflated 65%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/tex/2312.17042v2/main.tex (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/references.json (deflated 54%)
#   adding: content/arxiv_scraper/data/papers/2312-17042/metadata.json (deflated 49%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/tex/2312.16940v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/tex/2312.16940v1/My_Library.bib (deflated 72%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/tex/2312.16940v1/joint_graph_signal_ICASSP.tex (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/references.json (deflated 61%)
#   adding: content/arxiv_scraper/data/papers/2312-16940/metadata.json (deflated 47%)
#   adding: content/arxiv_scraper/data/papers/2401-02914/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02914/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02914/tex/2401.02914v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-02914/tex/2401.02914v1/v_f_arXiv.tex (deflated 68%)
#   adding: content/arxiv_scraper/data/papers/2401-02914/references.json (deflated 66%)
#   adding: content/arxiv_scraper/data/papers/2401-02914/metadata.json (deflated 53%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/tex/2312.16412v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/tex/2312.16412v1/main_icassp_v01.tex (deflated 70%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/tex/2312.16412v1/references.bib (deflated 69%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/references.json (deflated 58%)
#   adding: content/arxiv_scraper/data/papers/2312-16412/metadata.json (deflated 50%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/tex/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/tex/2401.00047v2/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/tex/2401.00047v2/ms_gaiden.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/tex/2401.00047v3/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/tex/2401.00047v3/ms_gaiden.tex (deflated 73%)
#   adding: content/arxiv_scraper/data/papers/2401-00047/tex/2401.00047v1/ (stored 0%)
#   adding: content/arxiv_scraper/data/papers/2401-00047